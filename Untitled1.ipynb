# %%
import operator
import matplotlib.pyplot as plt
import re

def add_unigram_to_list(token,case,main_word):  #unigrams_dict is of the form {token:[frequency,case satisfied,last word from which token generated]}
    if token not in unigrams_dict :
        unigrams_dict[token]=[1,"case:"+case,main_word]
    else :
        count=unigrams_dict[token][0]+1
        unigrams_dict[token]=[count,"case:"+case,main_word]        
        

def find_unigrams(token):
   # print token
    if len(token)==1:    #for single tokens like , . add token as it is
             add_unigram_to_list(token,"-1",token)

    elif re.match("[-+]*[0-9]+[\w\W]+",token) and not re.match('[-]*[0-9]*[,.][0-9]+',token) : # for separating units like px,km and commas and fulltop from end of numbers  
    #        print "case 0 "
            list0=re.findall(r"[\+\-']+", token)
            #print list0
            for word in list0:
                add_unigram_to_list(word,"0",token)
            list1= re.findall(r"[\d']+", token)
           # print list1
            for word in list1:
                add_unigram_to_list(word,"0",token)
            list2= re.findall(r"[^\d]+", token)
          #  print list2
            for word in list2:
                add_unigram_to_list(word,"0",token)
                
    elif re.match('[-]*[0-9]*[,.][0-9]*[\w\W]*',token):  #for keeping decimals and commas between numbers but separating units,commas,fullstop from end
           
            list0=re.findall(r"[\+\-']+", token)
            #print list0
            list1= re.findall(r"[0-9]*[,.][0-9]*", token) #number 
           # print list1
            prefix_length=0
            number_length=0
            if len(list0)>0:
                prefix_length+=len(list0[0])
            if len(list1)>0:
                number_length+=len(list1[0])
            prefix=token[0:prefix_length]
            number=token[prefix_length:(prefix_length+number_length)] 
           # print len(number)
            unit=token[(prefix_length+number_length):]
            if len(prefix)>0 :
               # print prefix
                add_unigram_to_list(prefix,"1",token)
            if len(number)>0 :
               # print number
                add_unigram_to_list(number,"1",token)
            if len(unit)>0:
               # print unit
                add_unigram_to_list(unit,"1",token)

          
    elif re.match('[$]([0-9]\?[,.])*',token):       #if numbers have currency $
         #   print "case 2 matched"
            add_unigram_to_list('$',"2",token)
            add_unigram_to_list(token[1:],"2",token)
        
    elif re.match('[0-9]{,2}[-/][0-9]{,2}[-/][0-9]{2,4}',token):  #dates like 18-12-1990
        #    print "case 3 matched"
            add_unigram_to_list(token,"3",token)
        
    elif re.match('[0-9]+\W',token):             #special characters have to be separated
        #    print "case 4 matched"
            #pattern =re.compile('\W')
            list1= re.findall(r"[\d']+", token)
            for word in list1:
                add_unigram_to_list(word,"4",token)
            list2= re.findall(r"[\W']+", token)
            for word in list2:
                add_unigram_to_list(word,"4",token)
        
    elif re.match('www.',token):                 #for urls
        #    print "case 5 matched"
            add_unigram_to_list(token,"5",token)
            
    elif re.match('[a-zA-Z._]+@[a-zA-Z]+\.[a-zA-Z]+',token): #for emails
        #    print "case 6 matched"
            add_unigram_to_list(token,"5",token)
            
    elif re.match("([A-Z][.])+",token):          #For words like U.S.A.
         #       print "case 7 matched"  
                add_unigram_to_list(token,"6",token)
                
    elif re.match("([A-Z][a-z][.])+",token):     #For words like Dr. ,Mr. ,Ph.D
        #        print "case 8 matched"
                add_unigram_to_list(token,"7",token)
    elif re.match("[\w][.,]",token):
             add_unigram_to_list(token,"7",token)
             
    #elif re.match("[\w]+'s\\b", token) :         #for words like Joe's
    elif re.match("[\w]+'s", token) :         #for words like Joe's

        list1=token.split("'s")
        if len(list1) >0 :
            add_unigram_to_list(list1[0],"8",token)
            add_unigram_to_list("'s","8",token)
            
        
        
    elif re.match("(\w*\W*)*",token):     #For any other special characters at end example (a)). will be broken into (, a,),) 
        list1= re.findall(r"[\w]+", token)
        for word in list1:
            add_unigram_to_list(word,"9",token)
        list2= re.findall(r"[{}().;,!\[\]*'\"/|\-\+%]+", token)
        for seq in list2:
            list_seq=list(seq)
            for word in list_seq:
                add_unigram_to_list(word,"9",token)
    else :
            add_unigram_to_list(token,"10",token)
            
    
def sort_descending(unigrams):
    return sorted(unigrams.items(), key=operator.itemgetter(1), reverse=True)
    
def plot(x,y):

    
    plt.plot(x, y)
    plt.xlabel('rank')
    plt.ylabel('frequency')
    #show plot
    plt.show()

def find_x_y_for_plotting(ranked_list,unigrams_dict):
    dict_plot={}
    f1=open("output.txt", "w")
    for i in range(len(ranked_list)):
     #  print i
        word=ranked_list[i][0]                #fetching the word string from ranked list
     #   print word
        dict_plot[i+1]=unigrams_dict[word][0] #finding the frequency of word from unigrams_dict
        f1.write(word+"\t\t:\t"+str(unigrams_dict[word][0])+"\n")
    
    f1.close()
    return dict_plot
            
    
if __name__ == "__main__": 
    f1=open("anime.txt","r") #file to read
    unigrams_dict={}                  #Dictionary to hold unigrams and its count
    dict_plot={}                      #x=key=rank,y=value=frequency
    i=1
    for line in f1:
        if i%1000==0:
            print i
        i=i+1
        tokens=line.rstrip().split()
        for token in tokens :
            find_unigrams(token)
    ranked_list=sort_descending(unigrams_dict)  #key=word,value=frequency
    dict_plot=find_x_y_for_plotting(ranked_list,unigrams_dict)
    plot(dict_plot.keys()[:50],dict_plot.values()[:50]) #display for only 50 ranks
    plt.show()
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000

# %%
def tokenise():
    input_file = open("anime.txt","r")
    file_content=input_file.readlines()
    corpus=[]

    for line in file_content:
        regex = re.compile('[a-zA-Z0-9]+')
        #regex = re.compile("http[s]?[\s]?:[\s]?//[a-zA-Z0-9/\.]+")
        line=re.sub('[^a-zA-Z0-9 ]', '', line)
        tokens=regex.findall(line)
        corpus.append(tokens)
    input_file.close()
    #print corpus
    return corpus

# %%
print tokenise()
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
tokenise()
# Out:
# [['because', 'she', 's', 'the', 'worst'],
#  ['i',
#   'am',
#   'referring',
#   'to',
#   'this',
#   'http',
#   'iimgurcom5srylmijpg',
#   'does',
#   'it',
#   'have',
#   'any',
#   'deeper',
#   'meaning',
#   'or',
#   'does',
#   'it',
#   'signify',
#   'anything',
#   'i',
#   'just',
#   'do',
#   'nt',
#   'get',
#   'it',
#   'why',
#   'she',
#   'd',
#   'do',
#   'that'],
#  ['cheating',
#   'but',
#   'zoldycks',
#   'must',
#   'have',
#   'a',
#   'great',
#   'time',
#   'at',
#   'thanksgiving'],
#  ['they', 'went', 'full', 'free', 'in', 'the', 'end'],
#  ['by',
#   'far',
#   'the',
#   'best',
#   'episode',
#   'of',
#   'this',
#   'show',
#   'this',
#   'was',
#   'pure',
#   'fun',
#   'to',
#   'watch',
#   'from',
#   'beginning',
#   'to',
#   'end'],
#  ['related',
#   'shounen',
#   'sarutobi',
#   'sasuke',
#   'aka',
#   'magic',
#   'boy',
#   'https',
#   'wwwyoutubecomwatch',
#   'v',
#   'yohgqmnskis'],
#  ['uchuu', 'senkan', 'yamato', 'looks', 'interesting'],
#  ['stop', 'abandoningtking', 'you', 'griefer'],
#  ['time',
#   'of',
#   'eve',
#   'http',
#   'myanimelistnetanime7465evenojikanmovie',
#   'has',
#   'a',
#   'very',
#   'similar',
#   'world',
#   'and',
#   'themes',
#   'to',
#   'ghost',
#   'in',
#   'the',
#   'shell',
#   'so',
#   'you',
#   'might',
#   'like',
#   'it',
#   'seirei',
#   'no',
#   'moribito',
#   'http',
#   'myanimelistnetanime1827seireinomoribito',
#   'is',
#   'made',
#   'by',
#   'the',
#   'same',
#   'director',
#   'as',
#   'the',
#   'ghost',
#   'in',
#   'the',
#   'shell',
#   'series',
#   'and',
#   'is',
#   'a',
#   'medieval',
#   'fantasy',
#   'just',
#   'like',
#   'berserk',
#   'but',
#   'not',
#   'dark',
#   'like',
#   'berserk',
#   'is',
#   'worth',
#   'trying',
#   'i',
#   'think',
#   'if',
#   'you',
#   'just',
#   'want',
#   'a',
#   'movie',
#   'sword',
#   'of',
#   'the',
#   'stranger',
#   'http',
#   'myanimelistnetanime2418strangermukouhadan',
#   'is',
#   'always',
#   'good',
#   'basically',
#   'a',
#   'movie',
#   'dedicated',
#   'to',
#   'showing',
#   'off',
#   'awesome',
#   'sword',
#   'fights',
#   'and',
#   'lots',
#   'of',
#   'blood'],
#  ['fatezero',
#   'also',
#   'gundam',
#   'ironblooded',
#   'orphans',
#   'is',
#   'currently',
#   'airing',
#   'and',
#   'it',
#   's',
#   'pretty',
#   'good',
#   'one',
#   'punch',
#   'man'],
#  ['puella',
#   'magi',
#   'madoka',
#   'magica',
#   'and',
#   'jojo',
#   's',
#   'bizarre',
#   'adventure',
#   'pmmm',
#   'only',
#   'has',
#   '12',
#   'eps',
#   'so',
#   'it',
#   's',
#   'easy',
#   'to',
#   'get',
#   'into',
#   'it',
#   's',
#   'a',
#   'masterpiece',
#   'give',
#   'it',
#   '3',
#   'eps',
#   'before',
#   'handing',
#   'down',
#   'your',
#   'judgment'],
#  ['darker', 'than', 'black', 'season', '1'],
#  ['12', 'kingdoms'],
#  ['i',
#   'think',
#   'you',
#   'd',
#   'enjoy',
#   'psychopass',
#   'http',
#   'myanimelistnetanime13601psychopass'],
#  ['you',
#   'will',
#   'probadly',
#   'like',
#   'gintama',
#   'it',
#   's',
#   'a',
#   'parody',
#   'comedy',
#   'action',
#   'clown',
#   'fiesta'],
#  ['watch',
#   'naoki',
#   'urasawa',
#   's',
#   'monster',
#   'http',
#   'myanimelistnetanime19monster'],
#  ['fullmetal',
#   'alchemist',
#   'welcome',
#   'to',
#   'the',
#   'nhk',
#   'baccano',
#   'hunter',
#   'x',
#   'hunter',
#   '2011',
#   'jojo',
#   's',
#   'bizarre',
#   'adventure',
#   'tv'],
#  ['ghost',
#   'in',
#   'the',
#   'shell',
#   'and',
#   'well',
#   'choreographed',
#   'action',
#   'scenes'],
#  [],
#  ['great',
#   'wt',
#   'samurai',
#   'champloo',
#   'is',
#   'one',
#   'of',
#   'my',
#   'absolute',
#   'favorite',
#   'shows',
#   'of',
#   'all',
#   'time',
#   'i',
#   'love',
#   'how',
#   'the',
#   'show',
#   'utilizes',
#   'hiphop',
#   'elements',
#   'to',
#   'show',
#   'how',
#   'out',
#   'of',
#   'place',
#   'everyone',
#   'feels',
#   'in',
#   'society',
#   'during',
#   'the',
#   'edo',
#   'period',
#   'everyone',
#   'should',
#   'definitely',
#   'check',
#   'it',
#   'out'],
#  ['favorite',
#   'hug',
#   'in',
#   'anime',
#   'http',
#   'iimgurcomoipxm9wgifv',
#   'favorite',
#   'hat',
#   'in',
#   'anime',
#   'http',
#   'iimgurcomv0dvelepng',
#   'favorite',
#   'glorious',
#   'display',
#   'of',
#   'physical',
#   'magnificence',
#   'in',
#   'anime',
#   'http',
#   'iimgurcomy8gzuxjgifv',
#   'favorite',
#   'kiss',
#   'in',
#   'anime',
#   'http',
#   'gfycatcombriefbewitcheddikdik',
#   'favorite',
#   'booty',
#   'shaking',
#   'gif',
#   'in',
#   'anime',
#   'http',
#   'iimgurcom7fg9on1gif',
#   'i',
#   'just',
#   'like',
#   'this',
#   'gif',
#   'http',
#   'iimgurcomebxcaw6gif',
#   'favorite',
#   'character',
#   'in',
#   'anime',
#   'http',
#   'iimgurcomvbfhfhtgif',
#   'bonus',
#   'http',
#   'iimgurcomrzcifaygifv'],
#  ['i',
#   'm',
#   'not',
#   'upset',
#   'at',
#   'all',
#   'http',
#   'eshuushuunetimages20150404724294jpeg'],
#  ['basically',
#   'the',
#   'entire',
#   'cast',
#   'of',
#   'legend',
#   'of',
#   'the',
#   'galactic',
#   'heroes',
#   'http',
#   'digitalconfederacycomimagesarticlesurrdayreviewsloghloghcharacterspng',
#   'and',
#   'pretty',
#   'much',
#   'everything',
#   'else',
#   'about',
#   'the',
#   'show'],
#  ['this',
#   'official',
#   'patlabor',
#   'art',
#   'https',
#   '61mediatumblrcom085c1da04a5c644a941d57d6823ab22atumblrmyo3ov1i7i1qbesk0o1500png'],
#  ['ariashachou', 'poinyaaa'],
#  ['yes',
#   'i',
#   'was',
#   'reading',
#   'this',
#   'and',
#   'i',
#   'love',
#   'it',
#   'and',
#   'i',
#   'love',
#   'anime',
#   'what',
#   'more',
#   'could',
#   'i',
#   'ask',
#   'for'],
#  ['any', 'news', 'on', 'when', 'it', 'll', 'air'],
#  ['got',
#   'ta',
#   'love',
#   'these',
#   'mashups',
#   'immediately',
#   'thought',
#   'of',
#   'everybody',
#   's',
#   'circulation',
#   'https',
#   'wwwyoutubecomwatch',
#   'v',
#   'f3igwltmyc'],
#  ['people',
#   'who',
#   'read',
#   'the',
#   'manga',
#   'should',
#   'i',
#   'be',
#   'hyped',
#   'or',
#   'not'],
#  ['holy',
#   'shit',
#   'i',
#   'did',
#   'nt',
#   'think',
#   'this',
#   'would',
#   'actually',
#   'happen'],
#  ['awesome',
#   'news',
#   'o',
#   'did',
#   'nt',
#   'think',
#   'it',
#   'would',
#   'happen',
#   'anymore',
#   'but',
#   'i',
#   'am',
#   'glad',
#   'it',
#   'is',
#   'nt',
#   'that',
#   'far',
#   'off',
#   'i',
#   'also',
#   'ca',
#   'nt',
#   'wait',
#   'to',
#   'watch',
#   'the',
#   'live',
#   'action',
#   'movie'],
#  ['would', 'nt', 'mind', 'more', 'time', 'travel', 'themed', 'anime'],
#  ['why',
#   'would',
#   'you',
#   'watch',
#   'a',
#   'recap',
#   'of',
#   'that',
#   'show',
#   'it',
#   's',
#   'episodic',
#   'i',
#   'guess',
#   'no',
#   'one',
#   'bothered',
#   'with',
#   'the',
#   'recap',
#   'thus',
#   'you',
#   'ca',
#   'nt',
#   'find',
#   'it',
#   'online'],
#  ['episode',
#   '7',
#   'of',
#   'seraphim',
#   'call',
#   'http',
#   'myanimelistnetanime2245seraphimcall',
#   'is',
#   'about',
#   'squaring',
#   'the',
#   'circle',
#   'https',
#   'enwikipediaorgwikisquaringthecircle',
#   'from',
#   'what',
#   'i',
#   'remember',
#   'and',
#   'invokes',
#   'one',
#   'of',
#   'g',
#   'del',
#   's',
#   'incompleteness',
#   'theorems',
#   'https',
#   'enwikipediaorgwikig',
#   'c3',
#   'b6delsincompletenesstheorems',
#   'at',
#   'some',
#   'point',
#   'it',
#   's',
#   'an',
#   'anthology',
#   'series',
#   'so',
#   'you',
#   'can',
#   'watch',
#   'that',
#   'episode',
#   'by',
#   'itself'],
#  ['i',
#   'knew',
#   'this',
#   'was',
#   'getting',
#   'an',
#   'anime',
#   'adaptation',
#   'sooner',
#   'or',
#   'later'],
#  [],
#  ['first',
#   'time',
#   'viewer',
#   'what',
#   'a',
#   'ride',
#   'this',
#   'was',
#   'my',
#   'first',
#   'gundam',
#   'that',
#   'i',
#   'completed',
#   'ibo',
#   'was',
#   'the',
#   'first',
#   'one',
#   'i',
#   'actually',
#   'started',
#   'watching',
#   'at',
#   'glad',
#   'i',
#   'stuck',
#   'through',
#   'this',
#   'and',
#   'ca',
#   'nt',
#   'wait',
#   'for',
#   'more',
#   'gundamu',
#   'i',
#   'got',
#   'over',
#   'the',
#   'animation',
#   'and',
#   'va',
#   'quality',
#   'by',
#   'episode',
#   '4',
#   'and',
#   'from',
#   'their',
#   'everything',
#   'just',
#   'kept',
#   'getting',
#   'better',
#   'char',
#   'is',
#   'god',
#   'among',
#   'memes',
#   'men',
#   'and',
#   'i',
#   'can',
#   'now',
#   'get',
#   'all',
#   'the',
#   'char',
#   'praise',
#   'i',
#   'ca',
#   'nt',
#   'wait',
#   'for',
#   'the',
#   'later',
#   'installments',
#   'with',
#   'better',
#   'animation',
#   'etc',
#   'with',
#   'the',
#   'character',
#   'and',
#   'story',
#   'quality',
#   'of',
#   'this',
#   'uspiranix',
#   'thank',
#   'you',
#   'for',
#   'starting',
#   'this',
#   'and',
#   'sticking',
#   'with',
#   'it'],
#  [],
#  ['hey',
#   'guys',
#   'i',
#   'wanted',
#   'to',
#   'make',
#   'a',
#   'tribute',
#   'to',
#   'the',
#   'animemanga',
#   'that',
#   'gave',
#   'me',
#   'so',
#   'much',
#   'joy',
#   'when',
#   'i',
#   'was',
#   'young',
#   'thank',
#   'you',
#   'for',
#   'all',
#   'of',
#   'your',
#   'feedback',
#   'on',
#   'previous',
#   'fanarts',
#   'that',
#   'i',
#   'submitted',
#   'amira',
#   'and',
#   'hanekawa',
#   'i',
#   'really',
#   'appreciate',
#   'it',
#   'http',
#   'madeleineinkdeviantartcomartsailormoon591282240'],
#  ['i',
#   'just',
#   'watched',
#   'the',
#   'second',
#   'half',
#   'of',
#   'episode',
#   '4',
#   'summer',
#   'vacation',
#   'started',
#   'the',
#   'scene',
#   'where',
#   'renge',
#   'makes',
#   'a',
#   'new',
#   'friend',
#   'absolutely',
#   'masterful',
#   'the',
#   'exploration',
#   'montage',
#   'was',
#   'great',
#   'and',
#   'later',
#   'the',
#   'commitment',
#   'to',
#   'the',
#   'close',
#   'up',
#   'on',
#   'renge',
#   's',
#   'face',
#   'for',
#   'such',
#   'a',
#   'prolonged',
#   'scene',
#   'was',
#   'amazing',
#   'i',
#   'need',
#   'crayons'],
#  [],
#  [],
#  ['somehow',
#   'i',
#   'feel',
#   'like',
#   'this',
#   'preview',
#   'would',
#   've',
#   'been',
#   'better',
#   'without',
#   'the',
#   'stereotypical',
#   'announcer',
#   'voice',
#   'but',
#   'that',
#   's',
#   'just',
#   'me'],
#  ['there',
#   'are',
#   'two',
#   'kinds',
#   'of',
#   'people',
#   'non',
#   'non',
#   'biyori',
#   'lovers',
#   'and',
#   'people',
#   'who',
#   'are',
#   'yet',
#   'to',
#   'watch',
#   'it',
#   'not',
#   'even',
#   'hitler',
#   'would',
#   'be',
#   'able',
#   'to',
#   'hate',
#   'that',
#   'anime'],
#  [],
#  ['fma', 'and', 'gosick'],
#  ['there',
#   'was',
#   'another',
#   'user',
#   'who',
#   'asked',
#   'the',
#   'same',
#   'question',
#   'https',
#   'wwwredditcomranimecomments44umyesteampunkstyledanime',
#   'about',
#   'a',
#   'week',
#   'ago',
#   'there',
#   'were',
#   'some',
#   'pretty',
#   'good',
#   'replies',
#   'in',
#   'that',
#   'thread'],
#  [],
#  ['here',
#   's',
#   'another',
#   'webm',
#   'of',
#   'awesome',
#   'opm',
#   'key',
#   'animation',
#   'https',
#   'sakugayshiorgpostshow20517effectsgengakeisukekojimaonepunchman'],
#  ['several',
#   'ghibli',
#   'movies',
#   'are',
#   'steampunkish',
#   'of',
#   'note',
#   'nausicaa',
#   'howl',
#   's',
#   'moving',
#   'castle',
#   'spirited',
#   'away',
#   'castle',
#   'in',
#   'the',
#   'sky',
#   'shows',
#   'that',
#   'are',
#   'steampunkish',
#   'simoun',
#   'moreso',
#   'the',
#   'enemy',
#   'factions',
#   'last',
#   'exile',
#   'full',
#   'metal',
#   'alchemist',
#   'and',
#   'fma',
#   'b',
#   'gosick'],
#  ['kabaneri',
#   'of',
#   'the',
#   'iron',
#   'fortress',
#   'http',
#   'myanimelistnetanime28623koutetsujounokabaneri',
#   'april',
#   '2016',
#   'looks',
#   'kind',
#   'of',
#   'steampunk'],
#  ['spy', 'kids', '3d', 'mal', 'http', 'wwwimdbcomtitlett0338459'],
#  ['miami', 'guns', 'http', 'myanimelistnetanime783miamiguns', 'maybe'],
#  ['lupin',
#   'iii',
#   'franchise',
#   'maybe',
#   'try',
#   'watching',
#   'jigen',
#   'daisuke',
#   's',
#   'gravestone',
#   'movie'],
#  ['more', 'please'],
#  ['that', 's', 'really', 'cool', 'where', 'did', 'you', 'find', 'this'],
#  ['no', 'release', 'date', 'announced'],
#  [],
#  ['the',
#   'monster',
#   'hunter',
#   'one',
#   'in',
#   'haganaiboku',
#   'wa',
#   'tomodachi',
#   'it',
#   's',
#   'almost',
#   'a',
#   'perfect',
#   'representation',
#   'of',
#   'every',
#   'group',
#   'i',
#   'ever',
#   'played',
#   'with',
#   'and',
#   'gameplay',
#   'and',
#   'animation',
#   'are',
#   'way',
#   'too',
#   'on',
#   'point'],
#  ['welcome',
#   'to',
#   'the',
#   'nhk',
#   's',
#   'beach',
#   'episode',
#   'this',
#   'is',
#   'one',
#   'of',
#   'my',
#   'favorite',
#   'shows',
#   'but',
#   'that',
#   'episode',
#   'specifically',
#   'resonated',
#   'with',
#   'me',
#   'and',
#   'hurt',
#   'me',
#   'to',
#   'watch',
#   'at',
#   'the',
#   'same',
#   'time',
#   'satou',
#   's',
#   's',
#   'break',
#   'down',
#   'at',
#   'the',
#   'end',
#   'of',
#   'it',
#   'was',
#   'just',
#   'chilling',
#   'no',
#   'other',
#   'episode',
#   'of',
#   'anime',
#   'has',
#   'ever',
#   'made',
#   'me',
#   'feel',
#   'that',
#   'before',
#   'or',
#   'since'],
#  ['space',
#   'dandy',
#   'season',
#   '2',
#   'episode',
#   '8',
#   'holy',
#   'shit',
#   'that',
#   'was',
#   'crazy',
#   'i',
#   'really',
#   'enjoyed',
#   'the',
#   'alternate',
#   'world',
#   'and',
#   'everything',
#   'from',
#   'the',
#   'beginning',
#   'to',
#   'the',
#   'end',
#   'was',
#   'fantastic',
#   'and',
#   'that',
#   'plot',
#   'twist',
#   'was',
#   'mind',
#   'blowing'],
#  ['episode',
#   '13',
#   'of',
#   'the',
#   'disappearance',
#   'of',
#   'yuki',
#   'nagato',
#   's',
#   'having',
#   'kyon',
#   'interact',
#   'with',
#   'kuudere',
#   'nagato',
#   'and',
#   'both',
#   'of',
#   'them',
#   'having',
#   'feelings',
#   'for',
#   'one',
#   'another',
#   'was',
#   'too',
#   'sweet'],
#  ['bakemonogatari',
#   'episode',
#   '12',
#   'spoilers',
#   's',
#   'koyomi',
#   's',
#   'car',
#   'ride',
#   'with',
#   'hitagi',
#   'and',
#   'her',
#   'father',
#   'laying',
#   'under',
#   'the',
#   'stars',
#   'the',
#   'connection',
#   'they',
#   'have',
#   'by',
#   'far',
#   'my',
#   'favorite',
#   'episode',
#   'of',
#   'that',
#   'show',
#   'and',
#   'maybethe',
#   'onlyonei',
#   'liked'],
#  ['first', 'and', 'last', 'episodes', 'of', 'plastic', 'memories'],
#  ['the',
#   'idol',
#   'episode',
#   'in',
#   'kyoukai',
#   'no',
#   'kanata',
#   'made',
#   'that',
#   'show',
#   'worth',
#   'watching'],
#  ['fatekaleid',
#   'episode',
#   '6',
#   'anyone',
#   'spoiler',
#   's',
#   'archer',
#   'illya',
#   'vs',
#   'saber',
#   'alter'],
#  [],
#  ['the',
#   'first',
#   'episode',
#   'of',
#   'zankou',
#   'no',
#   'terror',
#   'is',
#   'something',
#   'special'],
#  ['giant', 'robots', 'have', 'me', 'addicted', 'http', 'b1339cfqgxuvnrwebm'],
#  ['looking',
#   'for',
#   'an',
#   'anime',
#   'that',
#   'is',
#   'actually',
#   'scaryhorrorcreepydisturbing',
#   'i',
#   'prefer',
#   'psychological',
#   'horror',
#   'rather',
#   'than',
#   'cheap',
#   'jumpscares',
#   'and',
#   'mindless',
#   'gore'],
#  [],
#  ['that',
#   's',
#   'kendrick',
#   'lamar',
#   'never',
#   'heard',
#   'him',
#   'before',
#   'gon',
#   'na',
#   'check',
#   'him',
#   'out',
#   'now'],
#  ['doujinshi'],
#  ['they',
#   'turned',
#   'filthy',
#   '3d',
#   'live',
#   'action',
#   'into',
#   'an',
#   'anime',
#   'http',
#   'myanimelistnetanime4189wintersonata'],
#  ['overlord',
#   'is',
#   'so',
#   'far',
#   'the',
#   'best',
#   'of',
#   'the',
#   'bunch',
#   'i',
#   've',
#   'seen'],
#  ['he', 'was', 'prophesied'],
#  ['episode', '2', 'of', 'eureka', 'seven', 'ao', 'was', 'superb'],
#  ['angel',
#   'beats',
#   'https',
#   'smediacacheak0pinimgcomoriginals874f28874f28279f34de3bc97d5cd4903d1e6fgif',
#   'i',
#   'fucking',
#   'love',
#   'angel',
#   'beats',
#   'http',
#   'rs938pbsrccomalbumsad222kimberlyfarron23gifsangelbeatsescapegif',
#   'c200',
#   'and',
#   'sakura',
#   'chiyo',
#   'http',
#   '37mediatumblrcom6e8b0a4fe2ed73f321636c244764db2ctumblrnapwf1xq7o1smxh7ao2250gif',
#   'she',
#   'is',
#   'quite',
#   'possibly',
#   'one',
#   'the',
#   'most',
#   'lovable',
#   'http',
#   '33mediatumblrcom2ba4896bd4dd5542fb2210bd3354e817tumblrnbuzm0rxak1qdsh8vo1500gif',
#   'and',
#   'cutest',
#   'http',
#   '38mediatumblrcom8334a09c965f29de2b66c51cdb4093d7tumblrnccxi91gqc1qd16pfo1500gif',
#   'characters',
#   'i',
#   'know'],
#  ['post',
#   'your',
#   'anime',
#   'related',
#   'desktops',
#   'here',
#   'if',
#   'you',
#   'got',
#   'em',
#   'here',
#   'is',
#   'my',
#   'desktop',
#   'http',
#   'iimgurcomuukfphkpng',
#   'and',
#   'laptop',
#   'http',
#   'iimgurcomwnfbvbbpng'],
#  ['fanart',
#   'corner',
#   'post',
#   'your',
#   'favorite',
#   'anime',
#   'related',
#   'fanart'],
#  ['i', 'feel', 'pretty', 'normal', 'reading', 'this', 'thread'],
#  ['unintentionally',
#   'dressed',
#   'like',
#   'a',
#   'school',
#   'girl',
#   'for',
#   'work',
#   'no',
#   'one',
#   'tripped',
#   'and',
#   'grabbed',
#   'my',
#   'boobs',
#   'by',
#   'accident',
#   'though',
#   'so',
#   'it',
#   'could',
#   'be',
#   'a',
#   'lot',
#   'worse',
#   'more',
#   'weeb'],
#  ['upload', 'your', 'video', 'op'],
#  ['i',
#   'literally',
#   'posted',
#   'on',
#   'rjapan',
#   'for',
#   'the',
#   'first',
#   'time',
#   'ever',
#   'a',
#   'couple',
#   'of',
#   'hours',
#   'ago',
#   'here',
#   's',
#   'the',
#   'thread',
#   'https',
#   'wwwredditcomrjapancomments464491themythologybehindringulookingformovies'],
#  ['i',
#   'christened',
#   'my',
#   'new',
#   'ship',
#   'krenim',
#   'science',
#   'vessel',
#   'from',
#   'the',
#   'anniversary',
#   'event',
#   'in',
#   'star',
#   'trek',
#   'online',
#   'with',
#   'the',
#   'name',
#   'shirayuki',
#   'last',
#   'night',
#   'yes',
#   'the',
#   'nerd',
#   'is',
#   'strong',
#   'with',
#   'this',
#   'one'],
#  ['i', 'bought', 'a', 'terra', 'formars', 'figurine', 'prett', 'cool'],
#  [],
#  ['kurapika',
#   'out',
#   'https',
#   'pbstwimgcommediabznnxoucqaa7hkdpng',
#   'but',
#   'kirei',
#   'made',
#   'it',
#   'through',
#   'so',
#   'http',
#   'iimgurcomqlaggq2gifv'],
#  ['wow',
#   'kotomine',
#   'vs',
#   'armstrong',
#   'was',
#   'a',
#   'mere',
#   '20',
#   'vote',
#   'difference',
#   'every',
#   'vote',
#   'counts',
#   'people'],
#  ['vote',
#   'for',
#   'kougami',
#   'https',
#   'smediacacheak0pinimgcomoriginals20249c20249c8af59e48a8c723cf23ecc853b5gif',
#   'and',
#   'levi',
#   'http',
#   'orig15deviantartnet0faff20132601clevivsfemaletitangifbydillinghamd6mff2dgif',
#   'crushcirclejerks'],
#  ['ginchan', 'deserves', 'more', 'appreciation', 'for', 'his', 'work'],
#  [],
#  ['kuroko', 'no', 'basket', 'of', 'course'],
#  ['jojo', 's', 'bizarre', 'adventure'],
#  ['shokugeki', 'no', 'soma', 'sure', 'got', 'my', 'blood', 'pumping'],
#  ['baccano', 'and', 'birdy', 'the', 'mighty', 'decode'],
#  ['ponytails',
#   'http',
#   'iimgurcomse7dkctgif',
#   'ponytails',
#   'http',
#   'iimgurcomnh3eulhpng',
#   'ponytails',
#   'http',
#   'iimgurcomrzlkbx4jpg',
#   'ponytails',
#   'http',
#   'iimgurcomumvndzngifv'],
#  ['opai'],
#  ['no',
#   'gin',
#   'look',
#   'at',
#   'this',
#   'glorious',
#   'nose',
#   'gintamathispleasesme'],
#  ['i',
#   'just',
#   'started',
#   'watching',
#   'the',
#   'first',
#   'episode',
#   'yesterday',
#   'seems',
#   'interesting',
#   'enough',
#   'but',
#   'should',
#   'i',
#   'watch',
#   'it',
#   'in',
#   'dub',
#   'or',
#   'sub'],
#  ['i',
#   'am',
#   'so',
#   'excited',
#   'for',
#   'this',
#   'a',
#   'special',
#   'lady',
#   'recommended',
#   'me',
#   'this',
#   'manga',
#   'just',
#   'this',
#   'sunday',
#   'and',
#   'it',
#   'was',
#   'a',
#   'good',
#   'read',
#   'we',
#   're',
#   'both',
#   'excited',
#   'for',
#   'this',
#   'anime',
#   'and',
#   'the',
#   'live',
#   'action'],
#  ['so',
#   'my',
#   'friend',
#   'showed',
#   'me',
#   'an',
#   'image',
#   'from',
#   'some',
#   'anime',
#   'where',
#   'the',
#   'mc',
#   'had',
#   'done',
#   'some',
#   'integration',
#   'problems',
#   'on',
#   'his',
#   'book',
#   'i',
#   'was',
#   'wondering',
#   'if',
#   'there',
#   'were',
#   'any',
#   'other',
#   'scenes',
#   'in',
#   'different',
#   'anime',
#   'with',
#   'higher',
#   'math',
#   'involved'],
#  ['i',
#   'm',
#   'so',
#   'happy',
#   'they',
#   'kept',
#   'the',
#   'original',
#   'music',
#   'from',
#   'the',
#   'final',
#   'flash',
#   'scene'],
#  ['so',
#   'happy',
#   'to',
#   'see',
#   'new',
#   'episodes',
#   'arriving',
#   'sooner',
#   'these',
#   'days'],
#  ['not',
#   'sure',
#   'how',
#   'to',
#   'put',
#   'it',
#   'in',
#   'wording',
#   'but',
#   'examples',
#   'would',
#   'suffice',
#   'for',
#   'eg',
#   'nge',
#   's',
#   'anno',
#   'might',
#   'have',
#   'intented',
#   'asuka',
#   'to',
#   'be',
#   'a',
#   'symbol',
#   'of',
#   'what',
#   'really',
#   'goes',
#   'into',
#   'the',
#   'heads',
#   'of',
#   'a',
#   'tsundere',
#   'and',
#   'how',
#   'liking',
#   'such',
#   'characters',
#   'is',
#   'flawed',
#   'but',
#   'fans',
#   'ended',
#   'up',
#   'loving',
#   'her',
#   'paranoia',
#   'agent',
#   's',
#   'the',
#   'show',
#   'became',
#   'so',
#   'successful',
#   'that',
#   'you',
#   'can',
#   'actually',
#   'buy',
#   'maromi',
#   'merchandise',
#   'in',
#   'real',
#   'life'],
#  ['fall',
#   '2014',
#   'i',
#   'watched',
#   'a',
#   'lot',
#   'that',
#   'season',
#   'so',
#   'trinity',
#   'seven',
#   'shigatsu',
#   'psycho',
#   'pass',
#   '2',
#   'twintails',
#   'madan',
#   'no',
#   'ou',
#   'log',
#   '2',
#   'kiseijuu',
#   'gundam',
#   'build',
#   'fighters',
#   'try',
#   'gugure',
#   'kokkurisan',
#   'grisaia',
#   'no',
#   'kajitsu',
#   'fate',
#   'ubw',
#   'denkigai',
#   'danna',
#   'ga',
#   'cross',
#   'ange',
#   'amagi',
#   'brilliant',
#   'park',
#   'inou',
#   'battle',
#   'and',
#   'watched',
#   'shirobako',
#   'at',
#   'a',
#   'later',
#   'time'],
#  ['spring',
#   '2015',
#   'plastic',
#   'memories',
#   'danmachi',
#   'kekkai',
#   'sensen',
#   'only',
#   'one',
#   'of',
#   'those',
#   'i',
#   'liked'],
#  ['summer',
#   '2012',
#   'sword',
#   'art',
#   'online',
#   'dakara',
#   'boku',
#   'wa',
#   'h',
#   'ga',
#   'dekinai',
#   'campione',
#   'hagure',
#   'yuusha',
#   'no',
#   'aesthetica',
#   'muvluv',
#   'alternative',
#   'total',
#   'eclipse',
#   'my',
#   'tastes',
#   'back',
#   'then',
#   'werequestionable'],
#  ['fall',
#   '2014',
#   'with',
#   'fsn',
#   'ubw',
#   'parasyte',
#   'your',
#   'lie',
#   'in',
#   'april',
#   'log',
#   'horizon',
#   '2',
#   'twin',
#   'tails'],
#  ['gt',
#   'ops',
#   'and',
#   'eds',
#   'count',
#   'as',
#   'well',
#   'dat',
#   'clannad',
#   'after',
#   'story',
#   'ed',
#   'skipping',
#   'children',
#   'give',
#   'me',
#   'ptsd',
#   'attacks',
#   'now'],
#  ['that',
#   'one',
#   'time',
#   'when',
#   'kotourasan',
#   'and',
#   'friends',
#   'go',
#   'to',
#   'sing',
#   'karaoke',
#   'https',
#   'youtubecdjcuhuosci',
#   't',
#   '14s',
#   'and',
#   'she',
#   'tries',
#   'to',
#   'sing',
#   'her',
#   'own',
#   'op'],
#  ['the',
#   'awful',
#   'phantom',
#   'requiem',
#   'for',
#   'the',
#   'phantom',
#   '2nd',
#   'op',
#   'https',
#   'wwwyoutubecomwatch',
#   'v',
#   'xf2ynhaeqvk'],
#  ['maybe',
#   'this',
#   'op',
#   'will',
#   'be',
#   'beautibeautibeautiful',
#   'one',
#   'day',
#   'https',
#   'wwwyoutubecomwatch',
#   'v',
#   '8dkljqhcsoe',
#   'just',
#   'not',
#   'any',
#   'day',
#   'i',
#   'm',
#   'listening',
#   'to',
#   'it',
#   'worst',
#   'gintama',
#   'op',
#   'by',
#   'a',
#   'long',
#   'stretch'],
#  ['names', 'of', 'brandsmovieswhatever', 'else', 'you', 'come', 'up', 'with'],
#  ['for',
#   'me',
#   'it',
#   's',
#   'my',
#   'neighbor',
#   'pedoro',
#   'https',
#   'youtubewnkipydwzy'],
#  ['sudohbucks', 'http', 'iimgurcom83jsejpg', 'in', 'toradora'],
#  ['wacdonalds',
#   'is',
#   'always',
#   'a',
#   'favorite',
#   'of',
#   'mine',
#   'i',
#   'also',
#   'liked',
#   'dr',
#   'papper'],
#  ['all', 'the', 'different', 'name', 'versions', 'of', 'mcdonalds', 'lol'],
#  ['all',
#   'the',
#   'shinsengumi',
#   'in',
#   'gintama',
#   'are',
#   'based',
#   'on',
#   'historical',
#   'members',
#   'of',
#   'da',
#   'real',
#   'deal',
#   'shinsengumi'],
#  ['yohoo', 'in', 'durarara'],
#  ['eaten',
#   'natto',
#   'after',
#   'i',
#   'saw',
#   'micaela',
#   's',
#   'trick',
#   'i',
#   'eat',
#   'it',
#   'all',
#   'the',
#   'time',
#   'https',
#   'wwwyoutubecomwatch',
#   'v',
#   'lovfrcdnkny'],
#  ['looking',
#   'for',
#   'a',
#   'good',
#   'romance',
#   'that',
#   'is',
#   'nt',
#   'the',
#   'main',
#   'driving',
#   'force',
#   'i',
#   'liked',
#   'toradora',
#   'and',
#   'white',
#   'album',
#   '2',
#   'a',
#   'lot',
#   'but',
#   'i',
#   'guess',
#   'i',
#   'mean',
#   'something',
#   'more',
#   'like',
#   'gundam',
#   '08th',
#   'ms',
#   'team',
#   'where',
#   'there',
#   'was',
#   'a',
#   'greater',
#   'plot',
#   'going',
#   'on',
#   'and',
#   'the',
#   'romance',
#   'was',
#   'a',
#   'sub',
#   'plot',
#   'thank',
#   'you'],
#  ['visited', 'this', 'sub'],
#  ['all',
#   'these',
#   'random',
#   'fma',
#   'and',
#   'ubw',
#   'characters',
#   'are',
#   'killing',
#   'my',
#   'vibe',
#   'good',
#   'shows',
#   'but',
#   'variety',
#   'is',
#   'the',
#   'spice',
#   'of',
#   'life'],
#  ['went',
#   'to',
#   'the',
#   'movies',
#   'to',
#   'see',
#   'the',
#   'love',
#   'live',
#   'movie',
#   'stayed',
#   'afterward',
#   'for',
#   'pictures',
#   'of',
#   'the',
#   'cosplayers',
#   'and',
#   'talked',
#   'to',
#   'a',
#   'few',
#   'of',
#   'them'],
#  ['well',
#   'let',
#   's',
#   'see',
#   'laptop',
#   'wallpaper',
#   'http',
#   'prntscrcoma4a8mv',
#   'phone',
#   'background',
#   'http',
#   'prntscrcoma4aa4b',
#   'league',
#   'of',
#   'legends',
#   'name',
#   'http',
#   'prntscrcoma4aabe',
#   'xbox',
#   'live',
#   'name',
#   'http',
#   'prntscrcoma4aaj0'],
#  ['i', 'got', 'voteblocked', 'by', 'fate', '3', 'times', 'again', 'fml'],
#  ['bought',
#   'a',
#   'kuroyukihime',
#   'figure',
#   'not',
#   'a',
#   'cheap',
#   'one',
#   'either'],
#  ['so', 'goku', 'can', 'dodge'],
#  ['make',
#   'my',
#   'discord',
#   'chat',
#   'have',
#   'a',
#   'full',
#   'blown',
#   'weeb',
#   'hour',
#   'every',
#   'week',
#   'at',
#   '4am',
#   'its',
#   'for',
#   'euros',
#   'and',
#   'im',
#   'american'],
#  ['i',
#   'did',
#   'nt',
#   'watch',
#   'the',
#   'superbowl',
#   'because',
#   'the',
#   'last',
#   'match',
#   'in',
#   'the',
#   'first',
#   'season',
#   'of',
#   'haikyuu',
#   'was',
#   'too',
#   'intense'],
#  ['i',
#   'm',
#   'looking',
#   'for',
#   'a',
#   'more',
#   'polarizing',
#   'anime',
#   'to',
#   'review',
#   'any',
#   'suggestions'],
#  ['that', 'ending', 'the', 'horror'],
#  ['hyperdimensional', 'neptunia', 'is', 'awesome', 'that', 'is', 'all'],
#  ['unravel', 'kukuku'],
#  ['trinity',
#   'seven',
#   'has',
#   'some',
#   'of',
#   'the',
#   'worst',
#   'sound',
#   'mixing',
#   'and',
#   'background',
#   'tracks',
#   'i',
#   've',
#   'ever',
#   'heard',
#   'a',
#   'lot',
#   'of',
#   'whispering',
#   'does',
#   'not',
#   'make',
#   'it',
#   'mysterious',
#   'and',
#   'cool',
#   'and',
#   'good',
#   'granted',
#   'i',
#   'can',
#   'be',
#   'super',
#   'nitpicking',
#   'in',
#   'terms',
#   'of',
#   'audio',
#   'mixing',
#   'but',
#   'holy',
#   'fudge',
#   'it',
#   'was',
#   'beyond',
#   'redemption',
#   'and',
#   'not',
#   'fit',
#   'for',
#   'human',
#   'ears',
#   'in',
#   'the',
#   'later',
#   'episodes',
#   'no',
#   'comment',
#   'about',
#   'the',
#   'op',
#   'and',
#   'ed',
#   'since',
#   'i',
#   'already',
#   'forget',
#   'what',
#   'they',
#   'are'],
#  ['summer',
#   '2009',
#   'that',
#   's',
#   'also',
#   'when',
#   'i',
#   'started',
#   'to',
#   'watch',
#   'anime',
#   'with',
#   'english',
#   'subtitles',
#   'because',
#   'they',
#   'came',
#   'out',
#   'faster',
#   'and',
#   'i',
#   'was',
#   'really',
#   'hyped',
#   'for',
#   'umineko',
#   'because',
#   'i',
#   'was',
#   'a',
#   'huge',
#   'higurashi',
#   'fan',
#   'i',
#   'watched',
#   'umineko',
#   'and',
#   'tried',
#   'to',
#   'watch',
#   'bakemonogatari',
#   'but',
#   'my',
#   'english',
#   'was',
#   'nt',
#   'good',
#   'enough',
#   'in',
#   'the',
#   'end',
#   'umineko',
#   'was',
#   'shit',
#   'but',
#   'the',
#   'oped',
#   'were',
#   'excellent'],
#  ['looks',
#   'like',
#   'this',
#   'will',
#   'turn',
#   'out',
#   'to',
#   'be',
#   'a',
#   'fateoff',
#   'i',
#   'll',
#   'let',
#   'myself',
#   'out',
#   'now'],
#  ['i', 'put', 'some', 'gintama', 'wallpapers', 'on', 'my', 'laptop'],
#  ['2013',
#   'winter',
#   'mondaijitachi',
#   'ga',
#   'isekai',
#   'kara',
#   'kuru',
#   'sou',
#   'desu',
#   'yo',
#   'boku',
#   'wa',
#   'tomodachi',
#   'ga',
#   'sukunai',
#   'next',
#   'cuticle',
#   'tantei',
#   'inaba',
#   'maoyuu',
#   'maou',
#   'yuusha',
#   'ore',
#   'no',
#   'kanojo',
#   'to',
#   'osananajimi',
#   'ga',
#   'shuraba',
#   'sugiru',
#   'sasamisan',
#   'ganbaranai',
#   'vividred',
#   'operation',
#   'senran',
#   'kagura',
#   'amnesia',
#   'hakkenden',
#   'touhou',
#   'hakken',
#   'ibun',
#   'at',
#   'the',
#   'time',
#   'i',
#   'did',
#   'nt',
#   'know',
#   'what',
#   'to',
#   'expect',
#   'and',
#   'just',
#   'went',
#   'with',
#   'most',
#   'of',
#   'the',
#   'things',
#   'that',
#   'season',
#   'after',
#   'that',
#   'season',
#   'i',
#   'had',
#   'some',
#   'regrets',
#   'but',
#   'continuing',
#   'to',
#   'watch',
#   'anime',
#   'seasonally'],
#  ['i',
#   'just',
#   'finished',
#   'season',
#   '1',
#   'and',
#   'started',
#   'repeat',
#   'such',
#   'a',
#   'great',
#   'show',
#   'niichan',
#   'is',
#   'my',
#   'hero'],
#  ['just',
#   'saw',
#   'the',
#   'diving',
#   'in',
#   'the',
#   'river',
#   'episode',
#   'of',
#   'repeat',
#   'that',
#   'picture',
#   'renge',
#   'took',
#   'on',
#   'the',
#   'cell',
#   'phone',
#   'was',
#   'funny',
#   'as',
#   'heck'],
#  ['that',
#   'would',
#   'just',
#   'serve',
#   'to',
#   'confuse',
#   'ms',
#   'suzumiya',
#   'https',
#   'youtubeoh9b1uy4tcu'],
#  ['acdc'],
#  ['dack', 'janiels', 'heireken'],
#  ['sern', 'dk', 'pepper'],
#  ['the', 'classic', 'wcdonalds'],
#  ['girugameshi',
#   'of',
#   'course',
#   'it',
#   'is',
#   'derived',
#   'from',
#   'gilgamesh',
#   'but',
#   'more',
#   'meshi',
#   's'],
#  ['pino', 'co', 'lada', 'from', 'gate'],
#  ['white', 'album', '2', 'amagami', 'ss', 'has', 'two', 'defrostings'],
#  ['angel',
#   'beats',
#   'http',
#   'myanimelistnetanime6547angelbeats',
#   'seems',
#   'to',
#   'be',
#   'the',
#   'obvious',
#   'entry',
#   'missing',
#   'from',
#   'your',
#   'list'],
#  ['angel', 'beats', 'is', 'a', 'good', 'one', 'd'],
#  ['oniai'],
#  ['i',
#   'think',
#   'you',
#   'forgot',
#   'about',
#   'best',
#   'girl',
#   'hana',
#   'http',
#   'cdnmyanimelistnetscommonuploadedfiles1443544738ceca3f6530f906e3f13e6ba3458b37ccjpeg'],
#  ['lol',
#   'of',
#   'course',
#   'they',
#   'have',
#   'the',
#   'mira',
#   'fanservice',
#   'shot',
#   'at',
#   'the',
#   'end'],
#  ['desert', 'punk', 'is', 'a', 'bit'],
#  ['sometimes',
#   'being',
#   'too',
#   'mainstream',
#   'can',
#   'be',
#   'pass',
#   'what',
#   'is',
#   'your',
#   'favorite',
#   'underground',
#   'anime',
#   'and',
#   'why'],
#  ['the',
#   'empire',
#   'of',
#   'corpse',
#   'movie',
#   'that',
#   'just',
#   'released',
#   'is',
#   'steampunk'],
#  ['kaworu',
#   'nagisa',
#   'https',
#   'wwwanimecharactersdatabasecomuploadschars5092242321200jpg'],
#  ['nanamihug'],
#  ['izaya', 'he', 's', 'ma', 'boi', 'best', 'part', 'of', 'durararayawn'],
#  ['i',
#   'm',
#   'not',
#   'a',
#   'fan',
#   'of',
#   'hellsing',
#   'ultimate',
#   'but',
#   'holy',
#   'shit',
#   'is',
#   'alucard',
#   'one',
#   'hell',
#   'of',
#   'a',
#   'fuckmothering',
#   'vampire'],
#  ['kuronekoruri', 'gokou'],
#  ['meruem'],
#  ['char',
#   'http',
#   '49mediatumblrcomf9d2f812a20f7847e1d7611c753cbe2etumblrmu4eked3kt1s5f9ado1500gif',
#   'and',
#   'http',
#   '25mediatumblrcom6eff46cde1adfa8bd3242e52b892db0ctumblrmw83opmqmh1r5rnoxo1500gif',
#   'laura',
#   'https',
#   '45mediatumblrcom298585422f9d7304e65f7a1d507e1d10tumblrnbowokk6aj1slfw0xo1500gif',
#   'my',
#   'love',
#   'for',
#   'char',
#   'is',
#   'only',
#   'matched',
#   'by',
#   'my',
#   'resentment',
#   'of',
#   'the',
#   'show',
#   'as',
#   'a',
#   'whole'],
#  ['tsubasa',
#   'chronicles',
#   'kurogane',
#   'he',
#   'is',
#   'an',
#   'awesome',
#   'character',
#   'however',
#   'i',
#   'hate',
#   'the',
#   'show',
#   'it',
#   'makes',
#   'little',
#   'sense',
#   'and',
#   'it',
#   's',
#   'confusing',
#   'it',
#   'even',
#   'turns',
#   'out',
#   'the',
#   'mc',
#   'is',
#   'nt',
#   'even',
#   'the',
#   'main',
#   'character'],
#  ['kamina', 'from', 'ttgl'],
#  ['rokka', 'no', 'yuusha', 'fremy', 'speeddraw'],
#  ['intensely',
#   'views',
#   'thread',
#   'for',
#   'more',
#   'kuuderes',
#   'kuudere',
#   'best',
#   'dere',
#   'i',
#   'see',
#   'oregairu',
#   'being',
#   'recommended',
#   'and',
#   'i',
#   'second',
#   'to',
#   'that',
#   'statement'],
#  ['toradora'],
#  ['gt',
#   'but',
#   'hanekowa',
#   'is',
#   'bg',
#   'op',
#   'i',
#   'think',
#   'you',
#   'misspelled',
#   'shinobu'],
#  ['melancholy',
#   'of',
#   'haruhi',
#   'suzumiya',
#   'main',
#   'series',
#   'into',
#   'the',
#   'disappearance',
#   'movie'],
#  ['would', 'nt', 'hinazuki', 'from', 'bokudake', 'count', 'as', 'kuudere'],
#  ['oreshura',
#   'best',
#   'girl',
#   'http',
#   'mdzanimemewpcontentuploads201302124jpg',
#   'kuudere',
#   'shares',
#   'the',
#   'same',
#   'voice',
#   'actor',
#   'as',
#   'hitagi',
#   'edit',
#   'she',
#   'sounds',
#   'like',
#   'senjougahara',
#   'xd'],
#  ['boko', 'no', 'piku'],
#  ['honey',
#   'amp',
#   'clover',
#   'http',
#   'myanimelistnetanime16hachimitsutoclover',
#   'is',
#   'pretty',
#   'heavy',
#   'on',
#   'the',
#   'drama',
#   'so',
#   'is',
#   'kids',
#   'on',
#   'the',
#   'slope',
#   'http',
#   'myanimelistnetanime12531sakamichinoapollon'],
#  ['itazura', 'na', 'kiss'],
#  ['senjougahara'],
#  ['here',
#   'is',
#   'the',
#   'easiest',
#   'argument',
#   'to',
#   'make',
#   's',
#   'chocolate',
#   'cornets',
#   'are',
#   'shaped',
#   'like',
#   'dicks'],
#  ['kongou',
#   'is',
#   'pretty',
#   'awesome',
#   'too',
#   'bad',
#   'her',
#   'show',
#   'sucks',
#   'kantai',
#   'collection'],
#  ['tk', 'from', 'angel', 'beats'],
#  ['kurumi',
#   'from',
#   'date',
#   'a',
#   'live',
#   'she',
#   'even',
#   'has',
#   'the',
#   'only',
#   'meaningful',
#   'dialogues',
#   'in',
#   'a',
#   'retarded',
#   'show'],
#  ['for',
#   'example',
#   'i',
#   'ca',
#   'nt',
#   'browse',
#   'twitter',
#   'in',
#   'public',
#   'anymore',
#   'you',
#   'can',
#   'guess',
#   'why',
#   'but',
#   'i',
#   'can',
#   'differ',
#   'japanese',
#   'now',
#   'from',
#   'chinese',
#   'or',
#   'korean',
#   'might',
#   'be',
#   'helpful',
#   'someday'],
#  ['kaneki', 'from', 'tokyo', 'ghoul'],
#  ['athrun', 'and', 'cagalli', 'from', 'gundam', 'seed', 'destiny'],
#  ['mitsuki', 'nase', 'from', 'kyoukai', 'no', 'kanata'],
#  ['ami', 'from', 'toradora', 'http', 'iimgurcom8hgrkzejpg'],
#  ['this', 'naruto', 'joke', 'link', 'http', 'imgurcomk8sjgwg'],
#  ['comes', 'close', 'to', 'camera', 'your', 'waifu', 'is', 'shit'],
#  ['killua', 'from', 'hunter', 'x', 'hunter'],
#  ['i',
#   'would',
#   'recommend',
#   'sore',
#   'ga',
#   'seiyuu',
#   'http',
#   'myanimelistnetanime29163soregaseiyuu',
#   'for',
#   'some',
#   'insight'],
#  ['gilgamesh', 'from', 'fsn', 'ubw'],
#  ['mayumi',
#   'my',
#   'arch',
#   'enemies',
#   'know',
#   'which',
#   'anime',
#   'i',
#   'm',
#   'referring',
#   'to'],
#  ['nanami', 'aoyama'],
#  ['asuna', 'from', 'sao'],
#  ['akagami',
#   'no',
#   'shirayukihime',
#   'is',
#   'very',
#   'good',
#   'in',
#   'my',
#   'opinion',
#   'plus',
#   'you',
#   'get',
#   'based',
#   'god',
#   'mitsuhide'],
#  ['right',
#   'in',
#   'the',
#   'middle',
#   'of',
#   'finals',
#   'but',
#   '100',
#   'worth',
#   'it',
#   'looking',
#   'forward',
#   'to',
#   'this'],
#  ['what', 's', 'this', 'show', 'about', 'i', 'm', 'too', 'lazy'],
#  ['getting', 'ready', 'for', 'season', '3'],
#  ['i',
#   've',
#   'been',
#   'meaning',
#   'to',
#   'watch',
#   'this',
#   'for',
#   'a',
#   'while',
#   'now',
#   'i',
#   'll',
#   'probably',
#   'join',
#   'in'],
#  ['it',
#   's',
#   'the',
#   'only',
#   'thing',
#   'about',
#   'spice',
#   'and',
#   'wolf',
#   'that',
#   'would',
#   'be',
#   'announced',
#   'soon',
#   'lol'],
#  ['i',
#   've',
#   'had',
#   'the',
#   'full',
#   'collection',
#   'for',
#   'samp',
#   'w',
#   'since',
#   'christmas',
#   'but',
#   'have',
#   'nt',
#   'gotten',
#   'around',
#   'to',
#   'watching',
#   'it',
#   'so',
#   'this',
#   'would',
#   'be',
#   'nice'],
#  ['i',
#   'll',
#   'probably',
#   'be',
#   'too',
#   'busy',
#   'to',
#   'watch',
#   'again',
#   'but',
#   'i',
#   'can',
#   'repost',
#   'my',
#   'ln',
#   'comparisons',
#   'from',
#   'last',
#   'year',
#   'if',
#   'anyone',
#   's',
#   'interested'],
#  ['he',
#   'd',
#   'talk',
#   'about',
#   'how',
#   'similar',
#   'his',
#   'show',
#   'seems',
#   'to',
#   'gintama'],
#  ['what',
#   'references',
#   'would',
#   'he',
#   'make',
#   'to',
#   'other',
#   'anime',
#   'how',
#   'would',
#   'he',
#   'break',
#   'the',
#   'fourth',
#   'wall',
#   'in',
#   'an',
#   'animated',
#   'world',
#   'other',
#   'kinds',
#   'of',
#   'jokes',
#   'that',
#   'i',
#   'have',
#   'nt',
#   'thought',
#   'of'],
#  ['watch',
#   'the',
#   'episode',
#   'of',
#   'marvel',
#   's',
#   'disk',
#   'avengers',
#   'where',
#   'he',
#   'appeared',
#   'in'],
#  ['he', 'll', 'start', 'by', 'sleeping', 'with', 'everyone'],
#  ['wat'],
#  ['episode',
#   '10',
#   'of',
#   'madoka',
#   'magica',
#   'episode',
#   '23',
#   'of',
#   'shinsekai',
#   'yori'],
#  ['there',
#   'are',
#   'some',
#   'great',
#   'nanohadeadpool',
#   'fan',
#   'comics',
#   'nsfw',
#   '1',
#   'http',
#   'evilrickdeviantartcomartdeadpoolandnanohaissue2210631066',
#   '2',
#   'http',
#   'evilrickdeviantartcomartdeadpoolandnanohaissue5257345047',
#   '3',
#   'http',
#   'evilrickdeviantartcomartdeadpoolandnanohaissue4244327742'],
#  ['please', 'elaborate', 'your', 'answer'],
#  ['they',
#   'only',
#   'record',
#   'separately',
#   'for',
#   'anime',
#   'dubbing',
#   'iirc',
#   'many',
#   'western',
#   'animated',
#   'series',
#   'still',
#   'record',
#   'together'],
#  ['goddammit',
#   'every',
#   'rewatch',
#   'happens',
#   'right',
#   'after',
#   'i',
#   'finish',
#   'a',
#   'show'],
#  ['but', 'i', 'just', 'started', 'second', 'season'],
#  ['excited',
#   'for',
#   'this',
#   'can',
#   'never',
#   'have',
#   'enough',
#   'holo',
#   'in',
#   'my',
#   'life'],
#  ['remindme',
#   '1',
#   'month',
#   'spice',
#   'and',
#   'wolf',
#   'rewatch',
#   'lets',
#   'see',
#   'if',
#   'that',
#   'works'],
#  ['gt',
#   'mine',
#   'would',
#   'be',
#   'the',
#   'knowledge',
#   'from',
#   'conan',
#   'gt',
#   'because',
#   'knowledge',
#   'is',
#   'power',
#   'here',
#   'in',
#   'my',
#   'garaaaage',
#   'the',
#   'best',
#   'power',
#   'is',
#   'the',
#   'ability',
#   'to',
#   'have',
#   'a',
#   'harem',
#   'full',
#   'of',
#   'cute',
#   'anime',
#   'girls'],
#  ['mystic',
#   'eyes',
#   'of',
#   'death',
#   'perception',
#   'the',
#   'power',
#   'to',
#   'bring',
#   'the',
#   'world',
#   'revolution',
#   'penguindrum'],
#  ['imagine',
#   'breaker',
#   'whatever',
#   'is',
#   'inside',
#   'imagine',
#   'breaker',
#   'unlimited',
#   'blade',
#   'works',
#   'i',
#   'like',
#   'swords'],
#  ['oh',
#   'the',
#   'rewatch',
#   'starts',
#   'on',
#   'my',
#   'birthday',
#   'well',
#   'i',
#   've',
#   'been',
#   'meaning',
#   'to',
#   'watch',
#   'this',
#   'for',
#   'quite',
#   'a',
#   'while',
#   'so',
#   'i',
#   'm',
#   'probably',
#   'going',
#   'to',
#   'join',
#   'as',
#   'a',
#   'first',
#   'time',
#   'watcher'],
#  ['tenjou', 'tenge', 'episode', '2'],
#  ['which',
#   'is',
#   'the',
#   'best',
#   'anime',
#   'character',
#   'power',
#   'based',
#   'on',
#   'what',
#   'you',
#   've',
#   'watched',
#   'try',
#   'to',
#   'be',
#   'descriptive',
#   'and',
#   'explain',
#   'mine',
#   'would',
#   'be',
#   'the',
#   'knowledge',
#   'from',
#   'conan',
#   'detective',
#   'conan',
#   'because',
#   'knowledge',
#   'is',
#   'power'],
#  ['i', 'like', 'kotoha', 's', 'powerspeak'],
#  ['gt',
#   'mine',
#   'would',
#   'be',
#   'the',
#   'knowledge',
#   'from',
#   'conan',
#   'detective',
#   'conan',
#   'because',
#   'knowledge',
#   'is',
#   'power',
#   'but',
#   'then',
#   'there',
#   's',
#   'saitama',
#   's',
#   'punch'],
#  ['diamond',
#   'no',
#   'ace',
#   'its',
#   'as',
#   'good',
#   'as',
#   'haikyuu',
#   'and',
#   'not',
#   'even',
#   'close',
#   'to',
#   'as',
#   'popular',
#   'i',
#   'love',
#   'them',
#   'both',
#   'equally'],
#  ['nope',
#   'http',
#   'imgurcomgalleryj5sbp',
#   'also',
#   'anime',
#   'need',
#   'less',
#   'boring',
#   'flashy',
#   'super',
#   'powered',
#   'teenagers',
#   'playing',
#   'in',
#   'shitty',
#   'tournaments',
#   'and',
#   'needs',
#   'more',
#   'interesting',
#   'political',
#   'and',
#   'conspiracy',
#   'driven',
#   'shows',
#   'make',
#   'me',
#   'a',
#   'house',
#   'of',
#   'cards',
#   'esque',
#   'anime',
#   'show',
#   'and',
#   'i',
#   'would',
#   'be',
#   'happy'],
#  ['so',
#   'this',
#   'kid',
#   'goes',
#   'to',
#   'a',
#   'school',
#   'that',
#   'is',
#   'mostly',
#   'full',
#   'of',
#   'girls',
#   'gains',
#   'some',
#   'magic',
#   'power',
#   'or',
#   'some',
#   'shit',
#   '6',
#   'girls',
#   'want',
#   'to',
#   'have',
#   'sex',
#   'with',
#   'him',
#   'pretty',
#   'original',
#   'and',
#   'unique'],
#  ['cute', 'guys', 'doing', 'cute', 'things'],
#  ['a',
#   'narrative',
#   'anime',
#   'in',
#   'the',
#   'eyes',
#   'of',
#   'a',
#   'baby',
#   'something',
#   'like',
#   'rugrats',
#   'except',
#   'the',
#   'baby',
#   'tackles',
#   'thoughts',
#   'of',
#   'existentialism',
#   'and',
#   'the',
#   'meaning',
#   'of',
#   'life',
#   'comedysol'],
#  ['nonhentai',
#   'anime',
#   'either',
#   'about',
#   'cute',
#   'milfscakesols',
#   'doing',
#   'cute',
#   'things',
#   'or',
#   'romcomdrama',
#   'harem',
#   'with',
#   'milfscakesols'],
#  ['startide',
#   'rising',
#   'https',
#   'enwikipediaorgwikistartiderising',
#   'the',
#   'uplift',
#   'https',
#   'enwikipediaorgwikibrightnessreef',
#   'storm',
#   'https',
#   'enwikipediaorgwikiinfinitysshore',
#   'trilogy',
#   'https',
#   'enwikipediaorgwikiheavensreach',
#   'may',
#   'be',
#   'a',
#   'bit',
#   'more',
#   'accessible',
#   'with',
#   'the',
#   'kid',
#   's',
#   'storyline',
#   'though',
#   'it',
#   'may',
#   'seem',
#   'a',
#   'bit',
#   'random',
#   'without',
#   'the',
#   'context',
#   'of',
#   'startide',
#   'rising'],
#  [],
#  ['the', 'whole', 'lupin', 'iii', 'franchise'],
#  ['goat', 'simulator', 'the', 'anime'],
#  ['pepe',
#   's',
#   'bizarre',
#   'adventure',
#   'i',
#   'do',
#   'nt',
#   'think',
#   'i',
#   'need',
#   'to',
#   'explain',
#   'more'],
#  ['breakfast',
#   'cereals',
#   'are',
#   'cute',
#   'girls',
#   'that',
#   'go',
#   'to',
#   'high',
#   'school'],
#  ['http',
#   'imgurcomah4yii',
#   'still',
#   'watching',
#   'my',
#   'head',
#   'for',
#   'signs',
#   'of',
#   'hair',
#   'loss',
#   'check',
#   'out',
#   'my',
#   'tumblr',
#   'http',
#   'gsculpttumblrcom',
#   'for',
#   'more',
#   'sculptures'],
#  ['um',
#   'woah',
#   'we',
#   'do',
#   'nt',
#   'see',
#   'fucking',
#   'sculptures',
#   'fanart',
#   'that',
#   'often',
#   'sekkou',
#   'saitama'],
#  ['wow', 'that', 's', 'ridiculously', 'awesome', 'nice', 'job', 'helmetbro'],
#  ['clap', 'clap', 'clap', 'bravo'],
#  ['sekkou',
#   'boys',
#   'can',
#   'someone',
#   'shop',
#   'saitma',
#   'into',
#   'the',
#   'group',
#   'xd'],
#  ['what', 'the', 'shit'],
#  ['desert', 'punk'],
#  ['anime',
#   'suggestions',
#   'for',
#   'deadpan',
#   'humor',
#   'or',
#   'characters',
#   'with',
#   'deadpan',
#   'humor'],
#  ['do', 'you', 'do', 'offland', 'shipments'],
#  ['ummmmho', 'lee', 'shet', 'that', 's', 'amazing'],
#  ['only', '82', 'i', 'bet', 'you', 'can', 'sell', 'quite', 'a', 'few'],
#  ['down', 'voted', 'because', 'no', 'banana', 'for', 'scale'],
#  ['this', 'is', 'fucking', 'glorious'],
#  ['wow',
#   'a',
#   'sekko',
#   'saitama',
#   'now',
#   'there',
#   'needs',
#   'to',
#   'be',
#   'a',
#   'opm',
#   'and',
#   'sekko',
#   'boys',
#   'collaboration',
#   'outstanding',
#   'job'],
#  ['you', 'made', 'this', 'i', 'made', 'this'],
#  ['good', 'job', 'sensei'],
#  [],
#  ['i',
#   'started',
#   'my',
#   'first',
#   'visual',
#   'novel',
#   'and',
#   'i',
#   'had',
#   'to',
#   'set',
#   'my',
#   'pc',
#   'to',
#   'japanese',
#   'to',
#   'install',
#   'it',
#   'it',
#   's',
#   'too',
#   'addicting',
#   'send',
#   'help',
#   'pls'],
#  ['i',
#   'started',
#   'watching',
#   'the',
#   'love',
#   'live',
#   'dub',
#   'today',
#   'i',
#   'never',
#   'thought',
#   'that',
#   'my',
#   'best',
#   'girl',
#   'could',
#   'change',
#   'by',
#   'a',
#   'dub',
#   'because',
#   'honoka',
#   's',
#   'voice',
#   'is',
#   'fantastic'],
#  ['i',
#   'bought',
#   'a',
#   'can',
#   'of',
#   'yuzu',
#   'fruit',
#   'juice',
#   'to',
#   'see',
#   'what',
#   'it',
#   'tastes',
#   'like',
#   'it',
#   'tastes',
#   'like',
#   'white',
#   'grape',
#   'juice',
#   'i',
#   'feel',
#   'like',
#   'it',
#   'was',
#   'a',
#   'waste',
#   'of',
#   'an',
#   'experiment'],
#  ['this', 'is', 'some', 'nextlevel', 'meta', 'comfy'],
#  ['what', 'happened', 'to', 'jordy'],
#  ['i',
#   'typed',
#   'up',
#   'new',
#   'subtitles',
#   'for',
#   'episode',
#   '1',
#   'of',
#   'anohana',
#   'first',
#   'time',
#   'and',
#   'it',
#   'took',
#   'almost',
#   'a',
#   'day',
#   'starting',
#   'on',
#   'episode',
#   '2',
#   'over',
#   'the',
#   'weekend'],
#  [],
#  ['what',
#   'about',
#   'noses',
#   'in',
#   'black',
#   'jack',
#   'http',
#   'cdnmyanimelistnetimagescharacters1482769jpg'],
#  ['vote', 'gon', 'that', 'is', 'all'],
#  ['less',
#   'than',
#   'three',
#   'months',
#   'since',
#   'the',
#   'last',
#   'episode',
#   'this',
#   'ca',
#   'nt',
#   'be',
#   'right',
#   'that',
#   's',
#   'too',
#   'soon'],
#  ['darker',
#   'than',
#   'black',
#   'i',
#   'll',
#   'be',
#   'really',
#   'suprised',
#   'if',
#   'someone',
#   'does',
#   'nt',
#   'get',
#   'hyped',
#   'just',
#   'from',
#   'now',
#   'i',
#   've',
#   'lost',
#   'it',
#   'i',
#   'know',
#   'i',
#   'can',
#   'kill',
#   'the',
#   'truth',
#   'exists',
#   'beyond',
#   'the',
#   'gate'],
#  ['1',
#   'his',
#   'meta',
#   'jokes',
#   'are',
#   'hilarious',
#   'every',
#   'time',
#   '2',
#   'fun',
#   'fact',
#   'the',
#   'tone',
#   'when',
#   'the',
#   'green',
#   'light',
#   'shot',
#   'up',
#   'at',
#   'the',
#   'end',
#   'of',
#   'the',
#   'card',
#   'game',
#   'was',
#   'your',
#   'character',
#   'popping',
#   'a',
#   'soul',
#   'item',
#   'in',
#   'dark',
#   'souls'],
#  ['gurren', 'lagann', 'for', 'sure'],
#  ['what', 'is', 'going', 'on', 'with', 'his', 'voice'],
#  ['lovable', 'as', 'always'],
#  ['i',
#   'started',
#   'winter',
#   '2013',
#   'and',
#   'watched',
#   'oreshura',
#   'it',
#   'was',
#   'pretty',
#   'fun',
#   'that',
#   'reminds',
#   'me',
#   'that',
#   'i',
#   'have',
#   'to',
#   'read',
#   'the',
#   'ln',
#   'i',
#   'want',
#   'to',
#   'know',
#   'who',
#   's',
#   'winning',
#   'but',
#   'i',
#   'm',
#   'sure',
#   'it',
#   's',
#   'masuzu'],
#  ['perfect',
#   'cell',
#   's',
#   'va',
#   'is',
#   'fantastic',
#   'and',
#   'i',
#   'need',
#   'him',
#   'to',
#   'say',
#   'more',
#   'things',
#   'now',
#   'please'],
#  ['summer',
#   '2010',
#   'i',
#   'watched',
#   'hyakka',
#   'ryouran',
#   'samurai',
#   'girls',
#   'ookamisan',
#   'to',
#   'shichinin',
#   'no',
#   'nakamura',
#   'seitokia',
#   'yakuindomoi',
#   'i',
#   'feel',
#   'like',
#   'i',
#   'started',
#   'even',
#   'earlier',
#   'than',
#   'this',
#   'with',
#   'kaichou',
#   'wa',
#   'maidsama',
#   'the',
#   'previous',
#   'season',
#   'but',
#   'i',
#   'do',
#   'nt',
#   'know',
#   'that',
#   'for',
#   'sure'],
#  ['this',
#   'ed',
#   'from',
#   'kaminomi',
#   'right',
#   'here',
#   'https',
#   'wwwyoutubecomwatch',
#   'v',
#   'vxinraldqhk',
#   'edit',
#   'spelling'],
#  ['summer', '2014', 'watched', 'free', 'eternal', 'summer', 'love', 'stage'],
#  ['https',
#   'wwwyoutubecomwatch',
#   'v',
#   'fjtxqvevuwy',
#   'if',
#   'you',
#   'want',
#   'a',
#   'prime',
#   'example',
#   'of',
#   'unfitting',
#   'music',
#   'mars',
#   'of',
#   'destruction'],
#  ['in',
#   'spring',
#   '2015',
#   'i',
#   'started',
#   'to',
#   'follow',
#   'what',
#   'was',
#   'currently',
#   'airing',
#   'chances',
#   'are',
#   'high',
#   'that',
#   'i',
#   'watched',
#   'a',
#   'show',
#   'that',
#   'was',
#   'currently',
#   'airing',
#   'prior',
#   'to',
#   'that',
#   'but',
#   'probably',
#   'was',
#   'nt',
#   'aware',
#   'of',
#   'that',
#   'at',
#   'the',
#   'time',
#   'kamisama',
#   'hajimemashita',
#   'kuroko',
#   'no',
#   'basket',
#   '3rd',
#   'season',
#   'plastic',
#   'memories',
#   'may',
#   'or',
#   'may',
#   'not',
#   'started',
#   'it',
#   'right',
#   'after',
#   'it',
#   'stopped',
#   'airing',
#   'shokugeki',
#   'no',
#   'souma',
#   'yamadakun',
#   'to',
#   '7nin',
#   'no',
#   'majo'],
#  ['alnoahzero',
#   'ep',
#   '1',
#   'is',
#   'better',
#   'than',
#   'the',
#   'rest',
#   'of',
#   'the',
#   'show',
#   'combined',
#   'mushroom',
#   'samba',
#   'from',
#   'cowboy',
#   'bebop'],
#  ['tokyo', 'ghoul', 'roota', 's', 'op', 'was', 'awful'],
#  ['goodle',
#   'and',
#   'mewtube',
#   'http',
#   'iimgurcomjsstpjpg',
#   'from',
#   'steins',
#   'gate'],
#  ['illyasviel'],
#  ['macrosoft',
#   'winding',
#   'xo',
#   'http',
#   'images6fanpopcomimagephotos32200000windingangelbeatsanime322649601366768jpg'],
#  ['donquixote', 'rosinante', 'seriously'],
#  ['pizza', 'hut'],
#  ['bokura', 'wa', 'minna', 'kawaisou'],
#  ['lt', 'kore', 'wa', 'zombie', 'desu', 'ka', 'gt', 'eu'],
#  ['grisaia',
#   'series',
#   'with',
#   'yumiko',
#   'as',
#   'the',
#   'frost',
#   'queen',
#   'both',
#   'her',
#   'ark',
#   'in',
#   'kajitsu',
#   'and',
#   'in',
#   'general',
#   'in',
#   'rakuen',
#   'even',
#   'more',
#   'so',
#   'if',
#   'you',
#   'play',
#   'the',
#   'visual',
#   'novel'],
#  ['am',
#   'i',
#   'the',
#   'only',
#   'one',
#   'that',
#   'hates',
#   'nanamin',
#   'mashiro',
#   'is',
#   'bg'],
#  ['so',
#   'many',
#   'shows',
#   'in',
#   'the',
#   'thread',
#   'only',
#   'one',
#   'show',
#   'i',
#   'have',
#   'nt',
#   'seen'],
#  ['mysterious',
#   'girlfriend',
#   'x',
#   'http',
#   'myanimelistnetanime12467nazonokanojox',
#   'has',
#   'quite',
#   'an',
#   'interesting',
#   'kuudere'],
#  ['sinon',
#   'was',
#   'cool',
#   'then',
#   'kirito',
#   's',
#   'and',
#   'sao',
#   'had',
#   'to',
#   'come',
#   'in',
#   'and',
#   'fk',
#   'up',
#   'her',
#   'character'],
#  ['basically',
#   'everyone',
#   'from',
#   'hanamonogatari',
#   'except',
#   'the',
#   'devil',
#   'girl'],
#  ['bunny',
#   'sensei',
#   'http',
#   'iimgurcom1uaiqiojpg',
#   'from',
#   'absolute',
#   'duo',
#   'i',
#   'usually',
#   'enjoy',
#   'the',
#   'generic',
#   'harem',
#   'but',
#   'found',
#   'this',
#   'one',
#   'meh'],
#  ['plastic', 'memories', 'anohana', 'do', 'it'],
#  ['you',
#   'think',
#   'i',
#   'm',
#   'going',
#   'to',
#   'be',
#   'one',
#   'of',
#   'those',
#   'dense',
#   'mcs',
#   'that',
#   'never',
#   'gets',
#   'any',
#   'i',
#   've',
#   'slept',
#   'with',
#   'my',
#   'entire',
#   'harem',
#   'already'],
#  ['gt',
#   'sophistication',
#   'and',
#   'femininity',
#   'are',
#   'not',
#   'related',
#   'at',
#   'all',
#   'neither',
#   'are',
#   'sexuality',
#   'and',
#   'masculinity'],
#  ['i',
#   'actually',
#   'have',
#   'nt',
#   'watched',
#   'the',
#   'second',
#   'season',
#   'yet',
#   'and',
#   'it',
#   's',
#   'been',
#   'about',
#   'a',
#   'year',
#   'and',
#   'a',
#   'half',
#   'since',
#   'i',
#   'watched',
#   'the',
#   'first',
#   'season',
#   'so',
#   'this',
#   'is',
#   'good',
#   'for',
#   'me'],
#  ['finally', 'i', 'am', 'excited'],
#  ['did', 'nt', 'we', 'have', 'one', 'relatively', 'recently'],
#  ['deadpool',
#   'will',
#   'do',
#   'that',
#   'and',
#   'more',
#   'it',
#   'd',
#   'be',
#   'fun',
#   'to',
#   'see',
#   'him',
#   'break',
#   'the',
#   '4th',
#   'wall',
#   'so',
#   'hard',
#   'that',
#   'he',
#   'ends',
#   'up',
#   'in',
#   'actual',
#   'japan',
#   'or',
#   'even',
#   'in',
#   'other',
#   'anime',
#   'entirely'],
#  ['it',
#   's',
#   'supposed',
#   'to',
#   'be',
#   'one',
#   'of',
#   'her',
#   'cute',
#   'character',
#   'quirks'],
#  ['just',
#   'got',
#   'through',
#   'most',
#   'of',
#   'it',
#   'a',
#   'few',
#   'days',
#   'ago',
#   'but',
#   'for',
#   'some',
#   'reason',
#   'i',
#   've',
#   'been',
#   'holding',
#   'off',
#   'the',
#   'last',
#   'episode',
#   'of',
#   'season',
#   'two',
#   'i',
#   'guess',
#   'i',
#   'just',
#   'hate',
#   'that',
#   'there',
#   'will',
#   'likely',
#   'never',
#   'be',
#   'a',
#   'season',
#   'three',
#   'and',
#   'i',
#   'do',
#   'nt',
#   'want',
#   'the',
#   'story',
#   'to',
#   'end',
#   'with',
#   'the',
#   'rewatch',
#   'happening',
#   'i',
#   'guess',
#   'i',
#   'll',
#   'finish',
#   'it',
#   'tonight',
#   'and',
#   'watch',
#   'the',
#   'specials',
# ...
#   'saolog',
#   'horizon',
#   'then',
#   'the',
#   'twist',
#   'comes',
#   'about',
#   'once',
#   'the',
#   'players',
#   'realize',
#   'that',
#   'the',
#   'characters',
#   'they',
#   'are',
#   'playing',
#   'are',
#   'actually',
#   'real',
#   'and',
#   'sentient',
#   'and',
#   'it',
#   's',
#   'up',
#   'to',
#   'their',
#   'choices',
#   'and',
#   'decisions',
#   'to',
#   'save',
#   'them',
#   'lot',
#   'of',
#   'theological',
#   'amp',
#   'philosophical',
#   'questions',
#   'while',
#   'also',
#   'watching',
#   'cute',
#   'girls',
#   'play',
#   'damp',
#   'd'],
#  ['mizore', 'best', 'girl'],
#  ['i',
#   'd',
#   'go',
#   'so',
#   'far',
#   'as',
#   'to',
#   'single',
#   'out',
#   'the',
#   'final',
#   'five',
#   'minutes',
#   'of',
#   'the',
#   'first',
#   'episode',
#   'of',
#   'aldnoah',
#   'zero',
#   'season',
#   '1',
#   'its',
#   'just',
#   'perfect',
#   'and',
#   'i',
#   've',
#   'watched',
#   'it',
#   'multiple',
#   'times',
#   'even',
#   'if',
#   'i',
#   'do',
#   'not',
#   'greatly',
#   'like',
#   'the',
#   'series',
#   'as',
#   'a',
#   'whole'],
#  ['captain', 'earth', 'last', 'episode'],
#  ['what', 'are', 'some', 'good', 'mystery', 'anime'],
#  ['i',
#   'love',
#   'girls',
#   'that',
#   'insult',
#   'the',
#   'main',
#   'character',
#   'with',
#   'a',
#   'straight',
#   'face',
#   'they',
#   're',
#   'always',
#   'the',
#   'best',
#   'girls',
#   'in',
#   'their',
#   'given',
#   'anime',
#   'i',
#   'also',
#   'love',
#   'traps',
#   'they',
#   're',
#   'neither',
#   'male',
#   'nor',
#   'female',
#   'trap',
#   'is',
#   'a',
#   'whole',
#   'other',
#   'gender',
#   'i',
#   'm',
#   'the',
#   'reason',
#   'anime',
#   'was',
#   'a',
#   'mistake'],
#  ['best',
#   'girl',
#   'makes',
#   'me',
#   'happy',
#   'http',
#   'iimgurcomdnzh9fmjpg',
#   'maybe',
#   'she',
#   'll',
#   'be',
#   'animated',
#   'someday',
#   'elsieqq',
#   'other',
#   'anime',
#   'things',
#   'i',
#   'love',
#   '1',
#   'the',
#   'acchi',
#   'kocchi',
#   'op',
#   'https',
#   'wwwyoutubecomwatch',
#   'v',
#   '0bmjtnnsa6y',
#   '1',
#   'final',
#   'scene',
#   'of',
#   'medaka',
#   'box',
#   'abnormal',
#   'https',
#   'wwwyoutubecomwatch',
#   'v',
#   '3rmwobkyiae',
#   '1',
#   'the',
#   'beginner',
#   'insert',
#   'song',
#   'scene',
#   'https',
#   'streamablecomu1qv',
#   'in',
#   'akb0048',
#   '2',
#   'the',
#   'achannel',
#   'ed',
#   'https',
#   'wwwyoutubecomwatch',
#   'v',
#   'lfj4il2qh8',
#   'nonanime',
#   'things',
#   'i',
#   'love',
#   'that',
#   'i',
#   'also',
#   'want',
#   'to',
#   'share',
#   '1',
#   'tfs',
#   's',
#   'drunklstiltskin',
#   'streams',
#   'where',
#   'they',
#   'try',
#   'and',
#   'play',
#   'bloodborne',
#   'and',
#   'drink',
#   'when',
#   'they',
#   'die',
#   'you',
#   'get',
#   'moments',
#   'like',
#   '1',
#   'duel',
#   'of',
#   'the',
#   'drunks',
#   'https',
#   'wwwyoutubecomwatch',
#   'v',
#   'stzk3ksxg18',
#   '2',
#   'bird',
#   'pit',
#   'https',
#   'wwwyoutubecomwatch',
#   'v',
#   'xao3a7omlwkamp',
#   't',
#   '136m35s',
#   '3',
#   'dogs',
#   'and',
#   'doors',
#   'https',
#   'wwwyoutubecomwatch',
#   'v',
#   '49ft439lsl4amp',
#   't',
#   '16m25s',
#   '4',
#   'the',
#   'elevator',
#   'boss',
#   'watch',
#   'this',
#   'one',
#   'for',
#   'a',
#   'while',
#   'it',
#   'just',
#   'gets',
#   'better',
#   'and',
#   'better',
#   'https',
#   'wwwyoutubecomwatch',
#   'v',
#   '0zrooeft8gwamp',
#   't',
#   '125m40s',
#   '2',
#   'ricky',
#   'gervais',
#   'and',
#   'steve',
#   'merchant',
#   'discuss',
#   'polar',
#   'bears',
#   'and',
#   'nighttime',
#   'https',
#   'wwwyoutubecomwatch',
#   'v',
#   'r8wvzeauheamp',
#   't',
#   '10m7s'],
#  ['kisaragi',
#   'chihaya',
#   'http',
#   'staticzerochannetkisaragichihayafull1495321jpg',
#   'chihaya',
#   'singing',
#   'http',
#   '33mediatumblrcom73689550908fc0f5cf5b2196b40a303ftumblrncc58pjefp1s4qvrdo1500gif',
#   'chihaya',
#   'badass',
#   'http',
#   'pa1narviicom566679015a133badba46e68c61d76d719ebb25477a59hqgif',
#   'chihaya',
#   'gaming',
#   'http',
#   '38mediatumblrcome8bb0f17f565d4d3259bfaf9bf30f853tumblrn7p6ta3ils1rifd3ao1250gif',
#   'chihaya',
#   'drinking',
#   'https',
#   'uboachannetotsrc1404236701828png',
#   'edit',
#   'the',
#   'idolm',
#   'ster',
#   'spoilers',
#   'yakusoku',
#   'https',
#   'mymixtapemoegzwdxfwebm'],
#  ['holo', 'and', 'winter', 'http', 'iimgurcomrs9w2ujjpg'],
#  ['steins', 'gate', 'http', 'staticzerochannetsteins', '3bgatefull513912jpg'],
#  ['haruhi',
#   'and',
#   'nagato',
#   'rocking',
#   'out',
#   'with',
#   'god',
#   'knows',
#   'https',
#   'youtubewwb01iumvza'],
#  ['the', 'best', 'nnb', 'character', 'http', 'imgurcomgmcjbgp'],
#  ['a', 'certain', 'tiger'],
#  ['naruto', 'and', 'really', 'original', 'anime', 'ideas', 'like', 'rakugo'],
#  ['do',
#   'nt',
#   'really',
#   'know',
#   'what',
#   'it',
#   's',
#   'called',
#   'but',
#   'i',
#   'love',
#   'the',
#   'cutesmall',
#   'characters',
#   'being',
#   'stronger',
#   'then',
#   'they',
#   'look',
#   'to',
#   'be',
#   'ex',
#   'shiro',
#   'http',
#   'myanimelistnetcharacter82525shiro',
#   'chamo',
#   'http',
#   'myanimelistnetcharacter88653chamorosso',
#   'koneko',
#   'http',
#   'myanimelistnetcharacter51343konekotoujou',
#   'there',
#   's',
#   'other',
#   'better',
#   'examples',
#   'even',
#   'some',
#   'males',
#   'i',
#   'just',
#   'have',
#   'bad',
#   'memory',
#   'and',
#   'the',
#   'above',
#   'are',
#   'the',
#   'only',
#   'ones',
#   'on',
#   'my',
#   'mal',
#   'another',
#   'would',
#   'be',
#   'the',
#   'female',
#   'dressingacting',
#   'male',
#   'for',
#   'reasons',
#   'ex',
#   'yukimura',
#   'http',
#   'myanimelistnetcharacter38941yukimurakusunoki',
#   'konoe',
#   'http',
#   'myanimelistnetcharacter41374subarukonoe',
#   'tsugumi',
#   'http',
#   'myanimelistnetcharacter58885seishiroutsugumi'],
#  ['moe', 'lt', '3', 'https', 'wwwyoutubecomwatch', 'v', '2ac7gnuuy80'],
#  ['random',
#   'stuff',
#   'f',
#   'https',
#   'wwwredditcomranimecomments3pzb6fspoilerwhatflclmeansforme',
#   'l',
#   'https',
#   'wwwyoutubecomwatch',
#   'v',
#   'umutbscxux8',
#   'c',
#   'https',
#   'wwwyoutubecomwatch',
#   'v',
#   'g6nxzbvt0oo',
#   'l',
#   'https',
#   'wwwyoutubecomwatch',
#   'v',
#   'vxqgnxlgona',
#   'lt',
#   'spoilers',
#   'in',
#   'every',
#   'link',
#   'except',
#   'for',
#   'the',
#   'third',
#   'hiroyuki',
#   'imaishi',
#   's',
#   'animation',
#   'https',
#   'wwwyoutubecomwatch',
#   'v',
#   'scnfi4p8uc0',
#   'lt',
#   'expect',
#   'spoilers',
#   'for',
#   'various',
#   'series',
#   'this',
#   'ttgl',
#   'review',
#   'http',
#   'myanimelistnetreviewsphp',
#   'id',
#   '207124',
#   'heats',
#   'https',
#   'wwwyoutubecomwatch',
#   'v',
#   'ehoptvbfpgm',
#   'some',
#   'of',
#   'watanabe',
#   'keisuke',
#   's',
#   'animation',
#   'https',
#   'wwwyoutubecomwatch',
#   'v',
#   'xsf3qibkbssamp',
#   't',
#   '1m43s',
#   'lt',
#   'expect',
#   'spoilers',
#   'for',
#   'various',
#   'series',
#   'ngebohemian',
#   'rhapsody',
#   'spoilers',
#   'https',
#   'wwwyoutubecomwatch',
#   'v',
#   'ryjv3amydme',
#   'memetic',
#   'developments',
#   'infernocopu',
#   'the',
#   'amazing',
#   'garzey',
#   's',
#   'wing',
#   'dub',
#   'https',
#   'wwwyoutubecomwatch',
#   'v',
#   'nwru5o07ji',
#   'porn',
#   'sakamoto',
#   's',
#   'character',
#   'song',
#   'https',
#   'wwwyoutubecomwatch',
#   'v',
#   'dmtdllzhduw',
#   'baccano',
#   's',
#   'theme',
#   'https',
#   'wwwyoutubecomwatch',
#   'v',
#   'si76ws6tlks',
#   'this',
#   'fucking',
#   'ed',
#   'https',
#   'wwwyoutubecomwatch',
#   'v',
#   'lfuwtqbam28',
#   'ranime',
#   's',
#   'lm',
#   'a',
#   's',
#   'o'],
#  ['erased', 'meets', 'steins', 'gate', 'meets', 'shoujo'],
#  ['wow',
#   'this',
#   'is',
#   'great',
#   'i',
#   'never',
#   'finished',
#   'the',
#   'manga',
#   'i',
#   'think',
#   'it',
#   'was',
#   'nt',
#   'finished',
#   'yet',
#   'when',
#   'i',
#   'was',
#   'reading',
#   'it',
#   'but',
#   'i',
#   'm',
#   'super',
#   'excited',
#   'for',
#   'this'],
#  ['o',
#   'r',
#   'a',
#   'n',
#   'g',
#   'e',
#   'r',
#   'a',
#   'n',
#   'g',
#   'e',
#   'h',
#   'y',
#   'p',
#   'e',
#   'y',
#   'p',
#   'e'],
#  ['i', 'm', 'ready', 'to', 'cry', 'my', 'fucking', 'eyes', 'out'],
#  ['now', 'i', 'can', 'die', 'in', 'peace'],
#  ['holy',
#   'shit',
#   'yes',
#   'this',
#   'manga',
#   'is',
#   'to',
#   'good',
#   'to',
#   'not',
#   'get',
#   'a',
#   'anime'],
#  ['savinganimeexe'],
#  ['hype',
#   'i',
#   'thought',
#   'it',
#   'would',
#   'never',
#   'happen',
#   'considering',
#   'there',
#   'was',
#   'a',
#   'live',
#   'action',
#   'adaptation',
#   'released',
#   'already'],
#  ['it', 's', 'about', 'time', 'orangekun', 'got', 'his', 'own', 'anime'],
#  ['get', 'ready', 'for', 'feel', 'train'],
#  ['isnt',
#   'this',
#   'higher',
#   'ranked',
#   'than',
#   'boku',
#   'dake',
#   's',
#   'manga',
#   'seems',
#   'like',
#   'another',
#   'challenger',
#   'for',
#   'mal',
#   's',
#   '1',
#   'throne',
#   'has',
#   'appeared',
#   'the',
#   'only',
#   'question',
#   'is',
#   'how',
#   'well',
#   'this',
#   'candidate',
#   'fares'],
#  ['hype',
#   'is',
#   'real',
#   'i',
#   'was',
#   'hoping',
#   'this',
#   'would',
#   'get',
#   'an',
#   'adaption'],
#  ['yaaay',
#   'lt',
#   '3',
#   'omfg',
#   'i',
#   'ca',
#   'nt',
#   'believe',
#   'this',
#   'is',
#   'happening',
#   'i',
#   'm',
#   'about',
#   'to',
#   'cry',
#   'tttt',
#   'orange',
#   'manga',
#   'is',
#   'being',
#   'adapted',
#   'd'],
#  ['orange', 'boy', 'has', 'arrived', 'loyalty', 'or', 'death'],
#  ['time', 'travel', 'udastales', 'will', 'hate', 'it'],
#  ['did',
#   'anyone',
#   'see',
#   'the',
#   'live',
#   'action',
#   'film',
#   'for',
#   'this',
#   'was',
#   'it',
#   'any',
#   'good',
#   'and',
#   'how',
#   'much',
#   'of',
#   'the',
#   'manga',
#   'did',
#   'it',
#   'cover'],
#  ['oreun', 'ji', 'no', 'ni', 'hayaku'],
#  ['what', 'is', 'this', 'anime', 'even', 'about'],
#  ['sypnosis', 'sounds', 'interesting'],
#  ['i',
#   'just',
#   'bought',
#   'the',
#   'first',
#   'volume',
#   'from',
#   'japan',
#   'that',
#   '3',
#   'year',
#   'hiatus',
#   'was',
#   'the',
#   'death',
#   'of',
#   'me'],
#  ['it',
#   's',
#   'one',
#   'of',
#   'my',
#   '1010s',
#   'too',
#   'and',
#   'i',
#   'think',
#   'the',
#   'biggest',
#   'difference',
#   'for',
#   'why',
#   'i',
#   'loved',
#   'it',
#   'when',
#   'cowboy',
#   'bebop',
#   'was',
#   'so',
#   'mediocre',
#   'to',
#   'me',
#   'is',
#   'because',
#   'while',
#   'they',
#   're',
#   'both',
#   'extremely',
#   'episodic',
#   'to',
#   'the',
#   'point',
#   'where',
#   'some',
#   'episodes',
#   'leave',
#   '0',
#   'consequenceszombies',
#   'for',
#   'the',
#   'next',
#   'one',
#   'samurai',
#   'champloo',
#   'at',
#   'least',
#   'had',
#   'this',
#   'meandering',
#   'direction',
#   'to',
#   'it',
#   'which',
#   'kept',
#   'me',
#   'invested',
#   'spike',
#   'is',
#   'a',
#   'great',
#   'character',
#   'but',
#   'it',
#   'took',
#   'me',
#   'forever',
#   'to',
#   'complete',
#   'the',
#   'show',
#   'because',
#   'i',
#   'just',
#   'did',
#   'nt',
#   'care',
#   'about',
#   'the',
#   'situations',
#   'he',
#   'was',
#   'placed',
#   'in'],
#  ['champloo',
#   'is',
#   'also',
#   'one',
#   'of',
#   'my',
#   '1010s',
#   'and',
#   'in',
#   'my',
#   'top',
#   '3',
#   'shows',
#   'ever',
#   'it',
#   'just',
#   'did',
#   'everything',
#   'so',
#   'right'],
#  ['this',
#   'might',
#   'be',
#   'interesting',
#   'to',
#   'you',
#   'https',
#   'wikipuellamaginetmathematicsofmadokamagica'],
#  ['does',
#   'this',
#   'count',
#   'paranoia',
#   'agent',
#   'https',
#   'wwwyoutubecomwatch',
#   'v',
#   's94zvlhnyha'],
#  ['i',
#   've',
#   'been',
#   'trying',
#   'to',
#   'look',
#   'for',
#   'this',
#   'anime',
#   'for',
#   'a',
#   'while',
#   'now',
#   'and',
#   'i',
#   've',
#   'come',
#   'across',
#   'nothing',
#   'even',
#   'when',
#   'i',
#   'try',
#   'and',
#   'search',
#   'for',
#   'it',
#   'in',
#   'japanese',
#   'all',
#   'that',
#   'seems',
#   'to',
#   'exist',
#   'of',
#   'this',
#   'is',
#   'the',
#   'page',
#   'on',
#   'mal',
#   'that',
#   'has',
#   'been',
#   'created',
#   'http',
#   'myanimelistnetanime22055gakkounokaidanrecaps',
#   'anyone',
#   'have',
#   'any',
#   'idea',
#   'of',
#   'its',
#   'existence',
#   'or',
#   'is',
#   'this',
#   'a',
#   'made',
#   'up',
#   'title'],
#  ['after',
#   'finishing',
#   'part',
#   '4',
#   'i',
#   'now',
#   'realize',
#   'why',
#   'part',
#   '4',
#   'stand',
#   'name',
#   's',
#   'super',
#   'fly',
#   'had',
#   'that',
#   'name'],
#  ['woot', 'its', 'happening'],
#  ['roy',
#   'and',
#   'riza',
#   'spoilers',
#   'for',
#   'fma',
#   'brotherhood',
#   'i',
#   'guess',
#   'http',
#   'imgurcomzvxthzi'],
#  ['these',
#   'were',
#   'made',
#   'on',
#   'a',
#   'a',
#   'few',
#   'years',
#   'ago',
#   'gaijinkun',
#   'http',
#   'imgurcomaskpmf',
#   'it',
#   's',
#   'about',
#   'an',
#   'american',
#   'exchange',
#   'student',
#   'who',
#   'comes',
#   'to',
#   'japan',
#   'does',
#   'it',
#   'even',
#   'need',
#   'any',
#   'pitching'],
#  ['the',
#   'whole',
#   'thing',
#   'with',
#   'amuro',
#   'and',
#   'char',
#   'this',
#   'episode',
#   'was',
#   'a',
#   'little',
#   'confusing',
#   'i',
#   'do',
#   'nt',
#   'really',
#   'see',
#   'what',
#   'the',
#   'encounter',
#   'was',
#   'trying',
#   'to',
#   'accomplish',
#   'i',
#   'really',
#   'loved',
#   'when',
#   'char',
#   'blew',
#   'up',
#   'the',
#   'last',
#   'zabi',
#   'for',
#   'garma',
#   'heh',
#   'rip',
#   'white',
#   'base',
#   'the',
#   'kids',
#   'lt',
#   '333',
#   'i',
#   'love',
#   'those',
#   'little',
#   'rascals',
#   'it',
#   'was',
#   'a',
#   'fun',
#   'ride',
#   'watching',
#   'the',
#   'series',
#   'with',
#   'all',
#   'the',
#   'participants',
#   'it',
#   'did',
#   'nt',
#   'end',
#   'as',
#   'expected',
#   'but',
#   'it',
#   'was',
#   'still',
#   'a',
#   'satisfying',
#   'ending',
#   'looking',
#   'forward',
#   'to',
#   'the',
#   'rest',
#   'of',
#   'the',
#   'rewatch'],
#  ['what',
#   'if',
#   'you',
#   'took',
#   'all',
#   'of',
#   'the',
#   'good',
#   'standout',
#   'characters',
#   'from',
#   'otherwise',
#   'bad',
#   'shows',
#   'and',
#   'put',
#   'them',
#   'into',
#   'their',
#   'own',
#   'show',
#   'what',
#   'would',
#   'happen'],
#  ['what', 'tripleq', 'got', 'axed', 'when', 'did', 'this', 'happen', 'what'],
#  ['now', 'do', 'one', 'with', 'his', 'goofy', 'face'],
#  ['are', 'you', 'same', 'person', 'that', 'did', 'the', 'tf2', 'busts'],
#  ['one',
#   'of',
#   'my',
#   'favorite',
#   'shows',
#   'ever',
#   'just',
#   'wait',
#   'till',
#   'episode',
#   '4',
#   'of',
#   'the',
#   'repeat',
#   'the',
#   'repeat',
#   'in',
#   'general',
#   'is',
#   'even',
#   'better',
#   'than',
#   'the',
#   'original',
#   'series'],
#  ['yeah',
#   'i',
#   'really',
#   'liked',
#   'that',
#   'anime',
#   'i',
#   'never',
#   'watched',
#   'repeat',
#   'though'],
#  ['well', 'unzips'],
#  ['a', 'news', 'app', 'http', 'myanimelistnetanime30721hackadolltheanimation'],
#  ['wow',
#   'this',
#   'amv',
#   'is',
#   'amazing',
#   'the',
#   'sync',
#   'is',
#   'on',
#   'point',
#   'and',
#   'the',
#   'ending',
#   'is',
#   'exuberating'],
#  ['that', 'was', 'awesome'],
#  ['let',
#   's',
#   'get',
#   'the',
#   'monogatari',
#   'hype',
#   'train',
#   'on',
#   'the',
#   'road'],
#  ['can',
#   'someone',
#   'who',
#   's',
#   'seen',
#   'terra',
#   'etowards',
#   'the',
#   'terra',
#   'give',
#   'me',
#   'their',
#   'opinion',
#   'on',
#   'it'],
#  ['at', 'least', 'steampunkish', 'or', 'steampunk', 'influenced', 'also'],
#  ['http', 'iimgurcom4yfewbapng'],
#  ['could',
#   'valkyrie',
#   'chronicles',
#   'count',
#   'it',
#   's',
#   'more',
#   'of',
#   'an',
#   'alternate',
#   'ww1'],
#  ['this',
#   'was',
#   'posted',
#   'over',
#   'at',
#   'rstarvstheforcesofevil',
#   'and',
#   'i',
#   'thought',
#   'ranime',
#   'might',
#   'like',
#   'it',
#   'link',
#   'http',
#   'illeitydeviantartcomarthappyvalentinesdaystarbutterfly591063220'],
#  [],
#  ['amazing',
#   'article',
#   'a',
#   'lot',
#   'of',
#   'the',
#   'points',
#   'are',
#   'the',
#   'reasons',
#   'why',
#   'i',
#   'love',
#   'one',
#   'piece',
#   'so',
#   'much'],
#  ['i',
#   'was',
#   'in',
#   'a',
#   'skype',
#   'call',
#   'with',
#   'a',
#   'few',
#   'friends',
#   'whilst',
#   'applying',
#   'for',
#   'jobs',
#   'and',
#   'one',
#   'of',
#   'the',
#   'questions',
#   'in',
#   'the',
#   'application',
#   'was',
#   'asking',
#   'about',
#   'fluency',
#   'in',
#   'other',
#   'languages',
#   'i',
#   'then',
#   'proceeded',
#   'to',
#   'proclaim',
#   'to',
#   'my',
#   'friends',
#   'that',
#   'i',
#   'was',
#   'fluent',
#   'in',
#   'japanese',
#   'because',
#   'i',
#   'watch',
#   'anime',
#   'i',
#   'outweebed',
#   'myself',
#   'that',
#   'day'],
#  ['i',
#   'do',
#   'nt',
#   'know',
#   'if',
#   'this',
#   'counts',
#   'but',
#   'i',
#   'was',
#   'really',
#   'thinking',
#   'about',
#   'buying',
#   'the',
#   'lelouch',
#   'figure',
#   'for',
#   'either',
#   '200',
#   'or',
#   '350',
#   'it',
#   's',
#   'way',
#   'too',
#   'much',
#   'money',
#   'for',
#   'a',
#   'plastic',
#   'figure',
#   'and',
#   'i',
#   've',
#   'never',
#   'bought',
#   'anything',
#   'like',
#   'that',
#   'before',
#   'but',
#   'it',
#   'looks',
#   'so',
#   'damn',
#   'good'],
#  ['you',
#   'mean',
#   'besides',
#   'singing',
#   'all',
#   'the',
#   'jojo',
#   'openings',
#   'while',
#   'washing',
#   'dishes',
#   'and',
#   'doing',
#   'jojo',
#   'poses',
#   'every',
#   'chance',
#   'i',
#   'get'],
#  ['buy', 'a', 'santa', 'super', 'sonico', 'figure', 'no', 'ragrets'],
#  ['made', 'a', 'magical', 'girl', 'team', 'in', 'xcom', '2', 'i', 'guess'],
#  ...]

# %%
print tokenise()
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
corpus = tokenise()

# %%
corpus
# Out:
# [['because', 'she', 's', 'the', 'worst'],
#  ['i',
#   'am',
#   'referring',
#   'to',
#   'this',
#   'http',
#   'iimgurcom5srylmijpg',
#   'does',
#   'it',
#   'have',
#   'any',
#   'deeper',
#   'meaning',
#   'or',
#   'does',
#   'it',
#   'signify',
#   'anything',
#   'i',
#   'just',
#   'do',
#   'nt',
#   'get',
#   'it',
#   'why',
#   'she',
#   'd',
#   'do',
#   'that'],
#  ['cheating',
#   'but',
#   'zoldycks',
#   'must',
#   'have',
#   'a',
#   'great',
#   'time',
#   'at',
#   'thanksgiving'],
#  ['they', 'went', 'full', 'free', 'in', 'the', 'end'],
#  ['by',
#   'far',
#   'the',
#   'best',
#   'episode',
#   'of',
#   'this',
#   'show',
#   'this',
#   'was',
#   'pure',
#   'fun',
#   'to',
#   'watch',
#   'from',
#   'beginning',
#   'to',
#   'end'],
#  ['related',
#   'shounen',
#   'sarutobi',
#   'sasuke',
#   'aka',
#   'magic',
#   'boy',
#   'https',
#   'wwwyoutubecomwatch',
#   'v',
#   'yohgqmnskis'],
#  ['uchuu', 'senkan', 'yamato', 'looks', 'interesting'],
#  ['stop', 'abandoningtking', 'you', 'griefer'],
#  ['time',
#   'of',
#   'eve',
#   'http',
#   'myanimelistnetanime7465evenojikanmovie',
#   'has',
#   'a',
#   'very',
#   'similar',
#   'world',
#   'and',
#   'themes',
#   'to',
#   'ghost',
#   'in',
#   'the',
#   'shell',
#   'so',
#   'you',
#   'might',
#   'like',
#   'it',
#   'seirei',
#   'no',
#   'moribito',
#   'http',
#   'myanimelistnetanime1827seireinomoribito',
#   'is',
#   'made',
#   'by',
#   'the',
#   'same',
#   'director',
#   'as',
#   'the',
#   'ghost',
#   'in',
#   'the',
#   'shell',
#   'series',
#   'and',
#   'is',
#   'a',
#   'medieval',
#   'fantasy',
#   'just',
#   'like',
#   'berserk',
#   'but',
#   'not',
#   'dark',
#   'like',
#   'berserk',
#   'is',
#   'worth',
#   'trying',
#   'i',
#   'think',
#   'if',
#   'you',
#   'just',
#   'want',
#   'a',
#   'movie',
#   'sword',
#   'of',
#   'the',
#   'stranger',
#   'http',
#   'myanimelistnetanime2418strangermukouhadan',
#   'is',
#   'always',
#   'good',
#   'basically',
#   'a',
#   'movie',
#   'dedicated',
#   'to',
#   'showing',
#   'off',
#   'awesome',
#   'sword',
#   'fights',
#   'and',
#   'lots',
#   'of',
#   'blood'],
#  ['fatezero',
#   'also',
#   'gundam',
#   'ironblooded',
#   'orphans',
#   'is',
#   'currently',
#   'airing',
#   'and',
#   'it',
#   's',
#   'pretty',
#   'good',
#   'one',
#   'punch',
#   'man'],
#  ['puella',
#   'magi',
#   'madoka',
#   'magica',
#   'and',
#   'jojo',
#   's',
#   'bizarre',
#   'adventure',
#   'pmmm',
#   'only',
#   'has',
#   '12',
#   'eps',
#   'so',
#   'it',
#   's',
#   'easy',
#   'to',
#   'get',
#   'into',
#   'it',
#   's',
#   'a',
#   'masterpiece',
#   'give',
#   'it',
#   '3',
#   'eps',
#   'before',
#   'handing',
#   'down',
#   'your',
#   'judgment'],
#  ['darker', 'than', 'black', 'season', '1'],
#  ['12', 'kingdoms'],
#  ['i',
#   'think',
#   'you',
#   'd',
#   'enjoy',
#   'psychopass',
#   'http',
#   'myanimelistnetanime13601psychopass'],
#  ['you',
#   'will',
#   'probadly',
#   'like',
#   'gintama',
#   'it',
#   's',
#   'a',
#   'parody',
#   'comedy',
#   'action',
#   'clown',
#   'fiesta'],
#  ['watch',
#   'naoki',
#   'urasawa',
#   's',
#   'monster',
#   'http',
#   'myanimelistnetanime19monster'],
#  ['fullmetal',
#   'alchemist',
#   'welcome',
#   'to',
#   'the',
#   'nhk',
#   'baccano',
#   'hunter',
#   'x',
#   'hunter',
#   '2011',
#   'jojo',
#   's',
#   'bizarre',
#   'adventure',
#   'tv'],
#  ['ghost',
#   'in',
#   'the',
#   'shell',
#   'and',
#   'well',
#   'choreographed',
#   'action',
#   'scenes'],
#  [],
#  ['great',
#   'wt',
#   'samurai',
#   'champloo',
#   'is',
#   'one',
#   'of',
#   'my',
#   'absolute',
#   'favorite',
#   'shows',
#   'of',
#   'all',
#   'time',
#   'i',
#   'love',
#   'how',
#   'the',
#   'show',
#   'utilizes',
#   'hiphop',
#   'elements',
#   'to',
#   'show',
#   'how',
#   'out',
#   'of',
#   'place',
#   'everyone',
#   'feels',
#   'in',
#   'society',
#   'during',
#   'the',
#   'edo',
#   'period',
#   'everyone',
#   'should',
#   'definitely',
#   'check',
#   'it',
#   'out'],
#  ['favorite',
#   'hug',
#   'in',
#   'anime',
#   'http',
#   'iimgurcomoipxm9wgifv',
#   'favorite',
#   'hat',
#   'in',
#   'anime',
#   'http',
#   'iimgurcomv0dvelepng',
#   'favorite',
#   'glorious',
#   'display',
#   'of',
#   'physical',
#   'magnificence',
#   'in',
#   'anime',
#   'http',
#   'iimgurcomy8gzuxjgifv',
#   'favorite',
#   'kiss',
#   'in',
#   'anime',
#   'http',
#   'gfycatcombriefbewitcheddikdik',
#   'favorite',
#   'booty',
#   'shaking',
#   'gif',
#   'in',
#   'anime',
#   'http',
#   'iimgurcom7fg9on1gif',
#   'i',
#   'just',
#   'like',
#   'this',
#   'gif',
#   'http',
#   'iimgurcomebxcaw6gif',
#   'favorite',
#   'character',
#   'in',
#   'anime',
#   'http',
#   'iimgurcomvbfhfhtgif',
#   'bonus',
#   'http',
#   'iimgurcomrzcifaygifv'],
#  ['i',
#   'm',
#   'not',
#   'upset',
#   'at',
#   'all',
#   'http',
#   'eshuushuunetimages20150404724294jpeg'],
#  ['basically',
#   'the',
#   'entire',
#   'cast',
#   'of',
#   'legend',
#   'of',
#   'the',
#   'galactic',
#   'heroes',
#   'http',
#   'digitalconfederacycomimagesarticlesurrdayreviewsloghloghcharacterspng',
#   'and',
#   'pretty',
#   'much',
#   'everything',
#   'else',
#   'about',
#   'the',
#   'show'],
#  ['this',
#   'official',
#   'patlabor',
#   'art',
#   'https',
#   '61mediatumblrcom085c1da04a5c644a941d57d6823ab22atumblrmyo3ov1i7i1qbesk0o1500png'],
#  ['ariashachou', 'poinyaaa'],
#  ['yes',
#   'i',
#   'was',
#   'reading',
#   'this',
#   'and',
#   'i',
#   'love',
#   'it',
#   'and',
#   'i',
#   'love',
#   'anime',
#   'what',
#   'more',
#   'could',
#   'i',
#   'ask',
#   'for'],
#  ['any', 'news', 'on', 'when', 'it', 'll', 'air'],
#  ['got',
#   'ta',
#   'love',
#   'these',
#   'mashups',
#   'immediately',
#   'thought',
#   'of',
#   'everybody',
#   's',
#   'circulation',
#   'https',
#   'wwwyoutubecomwatch',
#   'v',
#   'f3igwltmyc'],
#  ['people',
#   'who',
#   'read',
#   'the',
#   'manga',
#   'should',
#   'i',
#   'be',
#   'hyped',
#   'or',
#   'not'],
#  ['holy',
#   'shit',
#   'i',
#   'did',
#   'nt',
#   'think',
#   'this',
#   'would',
#   'actually',
#   'happen'],
#  ['awesome',
#   'news',
#   'o',
#   'did',
#   'nt',
#   'think',
#   'it',
#   'would',
#   'happen',
#   'anymore',
#   'but',
#   'i',
#   'am',
#   'glad',
#   'it',
#   'is',
#   'nt',
#   'that',
#   'far',
#   'off',
#   'i',
#   'also',
#   'ca',
#   'nt',
#   'wait',
#   'to',
#   'watch',
#   'the',
#   'live',
#   'action',
#   'movie'],
#  ['would', 'nt', 'mind', 'more', 'time', 'travel', 'themed', 'anime'],
#  ['why',
#   'would',
#   'you',
#   'watch',
#   'a',
#   'recap',
#   'of',
#   'that',
#   'show',
#   'it',
#   's',
#   'episodic',
#   'i',
#   'guess',
#   'no',
#   'one',
#   'bothered',
#   'with',
#   'the',
#   'recap',
#   'thus',
#   'you',
#   'ca',
#   'nt',
#   'find',
#   'it',
#   'online'],
#  ['episode',
#   '7',
#   'of',
#   'seraphim',
#   'call',
#   'http',
#   'myanimelistnetanime2245seraphimcall',
#   'is',
#   'about',
#   'squaring',
#   'the',
#   'circle',
#   'https',
#   'enwikipediaorgwikisquaringthecircle',
#   'from',
#   'what',
#   'i',
#   'remember',
#   'and',
#   'invokes',
#   'one',
#   'of',
#   'g',
#   'del',
#   's',
#   'incompleteness',
#   'theorems',
#   'https',
#   'enwikipediaorgwikig',
#   'c3',
#   'b6delsincompletenesstheorems',
#   'at',
#   'some',
#   'point',
#   'it',
#   's',
#   'an',
#   'anthology',
#   'series',
#   'so',
#   'you',
#   'can',
#   'watch',
#   'that',
#   'episode',
#   'by',
#   'itself'],
#  ['i',
#   'knew',
#   'this',
#   'was',
#   'getting',
#   'an',
#   'anime',
#   'adaptation',
#   'sooner',
#   'or',
#   'later'],
#  [],
#  ['first',
#   'time',
#   'viewer',
#   'what',
#   'a',
#   'ride',
#   'this',
#   'was',
#   'my',
#   'first',
#   'gundam',
#   'that',
#   'i',
#   'completed',
#   'ibo',
#   'was',
#   'the',
#   'first',
#   'one',
#   'i',
#   'actually',
#   'started',
#   'watching',
#   'at',
#   'glad',
#   'i',
#   'stuck',
#   'through',
#   'this',
#   'and',
#   'ca',
#   'nt',
#   'wait',
#   'for',
#   'more',
#   'gundamu',
#   'i',
#   'got',
#   'over',
#   'the',
#   'animation',
#   'and',
#   'va',
#   'quality',
#   'by',
#   'episode',
#   '4',
#   'and',
#   'from',
#   'their',
#   'everything',
#   'just',
#   'kept',
#   'getting',
#   'better',
#   'char',
#   'is',
#   'god',
#   'among',
#   'memes',
#   'men',
#   'and',
#   'i',
#   'can',
#   'now',
#   'get',
#   'all',
#   'the',
#   'char',
#   'praise',
#   'i',
#   'ca',
#   'nt',
#   'wait',
#   'for',
#   'the',
#   'later',
#   'installments',
#   'with',
#   'better',
#   'animation',
#   'etc',
#   'with',
#   'the',
#   'character',
#   'and',
#   'story',
#   'quality',
#   'of',
#   'this',
#   'uspiranix',
#   'thank',
#   'you',
#   'for',
#   'starting',
#   'this',
#   'and',
#   'sticking',
#   'with',
#   'it'],
#  [],
#  ['hey',
#   'guys',
#   'i',
#   'wanted',
#   'to',
#   'make',
#   'a',
#   'tribute',
#   'to',
#   'the',
#   'animemanga',
#   'that',
#   'gave',
#   'me',
#   'so',
#   'much',
#   'joy',
#   'when',
#   'i',
#   'was',
#   'young',
#   'thank',
#   'you',
#   'for',
#   'all',
#   'of',
#   'your',
#   'feedback',
#   'on',
#   'previous',
#   'fanarts',
#   'that',
#   'i',
#   'submitted',
#   'amira',
#   'and',
#   'hanekawa',
#   'i',
#   'really',
#   'appreciate',
#   'it',
#   'http',
#   'madeleineinkdeviantartcomartsailormoon591282240'],
#  ['i',
#   'just',
#   'watched',
#   'the',
#   'second',
#   'half',
#   'of',
#   'episode',
#   '4',
#   'summer',
#   'vacation',
#   'started',
#   'the',
#   'scene',
#   'where',
#   'renge',
#   'makes',
#   'a',
#   'new',
#   'friend',
#   'absolutely',
#   'masterful',
#   'the',
#   'exploration',
#   'montage',
#   'was',
#   'great',
#   'and',
#   'later',
#   'the',
#   'commitment',
#   'to',
#   'the',
#   'close',
#   'up',
#   'on',
#   'renge',
#   's',
#   'face',
#   'for',
#   'such',
#   'a',
#   'prolonged',
#   'scene',
#   'was',
#   'amazing',
#   'i',
#   'need',
#   'crayons'],
#  [],
#  [],
#  ['somehow',
#   'i',
#   'feel',
#   'like',
#   'this',
#   'preview',
#   'would',
#   've',
#   'been',
#   'better',
#   'without',
#   'the',
#   'stereotypical',
#   'announcer',
#   'voice',
#   'but',
#   'that',
#   's',
#   'just',
#   'me'],
#  ['there',
#   'are',
#   'two',
#   'kinds',
#   'of',
#   'people',
#   'non',
#   'non',
#   'biyori',
#   'lovers',
#   'and',
#   'people',
#   'who',
#   'are',
#   'yet',
#   'to',
#   'watch',
#   'it',
#   'not',
#   'even',
#   'hitler',
#   'would',
#   'be',
#   'able',
#   'to',
#   'hate',
#   'that',
#   'anime'],
#  [],
#  ['fma', 'and', 'gosick'],
#  ['there',
#   'was',
#   'another',
#   'user',
#   'who',
#   'asked',
#   'the',
#   'same',
#   'question',
#   'https',
#   'wwwredditcomranimecomments44umyesteampunkstyledanime',
#   'about',
#   'a',
#   'week',
#   'ago',
#   'there',
#   'were',
#   'some',
#   'pretty',
#   'good',
#   'replies',
#   'in',
#   'that',
#   'thread'],
#  [],
#  ['here',
#   's',
#   'another',
#   'webm',
#   'of',
#   'awesome',
#   'opm',
#   'key',
#   'animation',
#   'https',
#   'sakugayshiorgpostshow20517effectsgengakeisukekojimaonepunchman'],
#  ['several',
#   'ghibli',
#   'movies',
#   'are',
#   'steampunkish',
#   'of',
#   'note',
#   'nausicaa',
#   'howl',
#   's',
#   'moving',
#   'castle',
#   'spirited',
#   'away',
#   'castle',
#   'in',
#   'the',
#   'sky',
#   'shows',
#   'that',
#   'are',
#   'steampunkish',
#   'simoun',
#   'moreso',
#   'the',
#   'enemy',
#   'factions',
#   'last',
#   'exile',
#   'full',
#   'metal',
#   'alchemist',
#   'and',
#   'fma',
#   'b',
#   'gosick'],
#  ['kabaneri',
#   'of',
#   'the',
#   'iron',
#   'fortress',
#   'http',
#   'myanimelistnetanime28623koutetsujounokabaneri',
#   'april',
#   '2016',
#   'looks',
#   'kind',
#   'of',
#   'steampunk'],
#  ['spy', 'kids', '3d', 'mal', 'http', 'wwwimdbcomtitlett0338459'],
#  ['miami', 'guns', 'http', 'myanimelistnetanime783miamiguns', 'maybe'],
#  ['lupin',
#   'iii',
#   'franchise',
#   'maybe',
#   'try',
#   'watching',
#   'jigen',
#   'daisuke',
#   's',
#   'gravestone',
#   'movie'],
#  ['more', 'please'],
#  ['that', 's', 'really', 'cool', 'where', 'did', 'you', 'find', 'this'],
#  ['no', 'release', 'date', 'announced'],
#  [],
#  ['the',
#   'monster',
#   'hunter',
#   'one',
#   'in',
#   'haganaiboku',
#   'wa',
#   'tomodachi',
#   'it',
#   's',
#   'almost',
#   'a',
#   'perfect',
#   'representation',
#   'of',
#   'every',
#   'group',
#   'i',
#   'ever',
#   'played',
#   'with',
#   'and',
#   'gameplay',
#   'and',
#   'animation',
#   'are',
#   'way',
#   'too',
#   'on',
#   'point'],
#  ['welcome',
#   'to',
#   'the',
#   'nhk',
#   's',
#   'beach',
#   'episode',
#   'this',
#   'is',
#   'one',
#   'of',
#   'my',
#   'favorite',
#   'shows',
#   'but',
#   'that',
#   'episode',
#   'specifically',
#   'resonated',
#   'with',
#   'me',
#   'and',
#   'hurt',
#   'me',
#   'to',
#   'watch',
#   'at',
#   'the',
#   'same',
#   'time',
#   'satou',
#   's',
#   's',
#   'break',
#   'down',
#   'at',
#   'the',
#   'end',
#   'of',
#   'it',
#   'was',
#   'just',
#   'chilling',
#   'no',
#   'other',
#   'episode',
#   'of',
#   'anime',
#   'has',
#   'ever',
#   'made',
#   'me',
#   'feel',
#   'that',
#   'before',
#   'or',
#   'since'],
#  ['space',
#   'dandy',
#   'season',
#   '2',
#   'episode',
#   '8',
#   'holy',
#   'shit',
#   'that',
#   'was',
#   'crazy',
#   'i',
#   'really',
#   'enjoyed',
#   'the',
#   'alternate',
#   'world',
#   'and',
#   'everything',
#   'from',
#   'the',
#   'beginning',
#   'to',
#   'the',
#   'end',
#   'was',
#   'fantastic',
#   'and',
#   'that',
#   'plot',
#   'twist',
#   'was',
#   'mind',
#   'blowing'],
#  ['episode',
#   '13',
#   'of',
#   'the',
#   'disappearance',
#   'of',
#   'yuki',
#   'nagato',
#   's',
#   'having',
#   'kyon',
#   'interact',
#   'with',
#   'kuudere',
#   'nagato',
#   'and',
#   'both',
#   'of',
#   'them',
#   'having',
#   'feelings',
#   'for',
#   'one',
#   'another',
#   'was',
#   'too',
#   'sweet'],
#  ['bakemonogatari',
#   'episode',
#   '12',
#   'spoilers',
#   's',
#   'koyomi',
#   's',
#   'car',
#   'ride',
#   'with',
#   'hitagi',
#   'and',
#   'her',
#   'father',
#   'laying',
#   'under',
#   'the',
#   'stars',
#   'the',
#   'connection',
#   'they',
#   'have',
#   'by',
#   'far',
#   'my',
#   'favorite',
#   'episode',
#   'of',
#   'that',
#   'show',
#   'and',
#   'maybethe',
#   'onlyonei',
#   'liked'],
#  ['first', 'and', 'last', 'episodes', 'of', 'plastic', 'memories'],
#  ['the',
#   'idol',
#   'episode',
#   'in',
#   'kyoukai',
#   'no',
#   'kanata',
#   'made',
#   'that',
#   'show',
#   'worth',
#   'watching'],
#  ['fatekaleid',
#   'episode',
#   '6',
#   'anyone',
#   'spoiler',
#   's',
#   'archer',
#   'illya',
#   'vs',
#   'saber',
#   'alter'],
#  [],
#  ['the',
#   'first',
#   'episode',
#   'of',
#   'zankou',
#   'no',
#   'terror',
#   'is',
#   'something',
#   'special'],
#  ['giant', 'robots', 'have', 'me', 'addicted', 'http', 'b1339cfqgxuvnrwebm'],
#  ['looking',
#   'for',
#   'an',
#   'anime',
#   'that',
#   'is',
#   'actually',
#   'scaryhorrorcreepydisturbing',
#   'i',
#   'prefer',
#   'psychological',
#   'horror',
#   'rather',
#   'than',
#   'cheap',
#   'jumpscares',
#   'and',
#   'mindless',
#   'gore'],
#  [],
#  ['that',
#   's',
#   'kendrick',
#   'lamar',
#   'never',
#   'heard',
#   'him',
#   'before',
#   'gon',
#   'na',
#   'check',
#   'him',
#   'out',
#   'now'],
#  ['doujinshi'],
#  ['they',
#   'turned',
#   'filthy',
#   '3d',
#   'live',
#   'action',
#   'into',
#   'an',
#   'anime',
#   'http',
#   'myanimelistnetanime4189wintersonata'],
#  ['overlord',
#   'is',
#   'so',
#   'far',
#   'the',
#   'best',
#   'of',
#   'the',
#   'bunch',
#   'i',
#   've',
#   'seen'],
#  ['he', 'was', 'prophesied'],
#  ['episode', '2', 'of', 'eureka', 'seven', 'ao', 'was', 'superb'],
#  ['angel',
#   'beats',
#   'https',
#   'smediacacheak0pinimgcomoriginals874f28874f28279f34de3bc97d5cd4903d1e6fgif',
#   'i',
#   'fucking',
#   'love',
#   'angel',
#   'beats',
#   'http',
#   'rs938pbsrccomalbumsad222kimberlyfarron23gifsangelbeatsescapegif',
#   'c200',
#   'and',
#   'sakura',
#   'chiyo',
#   'http',
#   '37mediatumblrcom6e8b0a4fe2ed73f321636c244764db2ctumblrnapwf1xq7o1smxh7ao2250gif',
#   'she',
#   'is',
#   'quite',
#   'possibly',
#   'one',
#   'the',
#   'most',
#   'lovable',
#   'http',
#   '33mediatumblrcom2ba4896bd4dd5542fb2210bd3354e817tumblrnbuzm0rxak1qdsh8vo1500gif',
#   'and',
#   'cutest',
#   'http',
#   '38mediatumblrcom8334a09c965f29de2b66c51cdb4093d7tumblrnccxi91gqc1qd16pfo1500gif',
#   'characters',
#   'i',
#   'know'],
#  ['post',
#   'your',
#   'anime',
#   'related',
#   'desktops',
#   'here',
#   'if',
#   'you',
#   'got',
#   'em',
#   'here',
#   'is',
#   'my',
#   'desktop',
#   'http',
#   'iimgurcomuukfphkpng',
#   'and',
#   'laptop',
#   'http',
#   'iimgurcomwnfbvbbpng'],
#  ['fanart',
#   'corner',
#   'post',
#   'your',
#   'favorite',
#   'anime',
#   'related',
#   'fanart'],
#  ['i', 'feel', 'pretty', 'normal', 'reading', 'this', 'thread'],
#  ['unintentionally',
#   'dressed',
#   'like',
#   'a',
#   'school',
#   'girl',
#   'for',
#   'work',
#   'no',
#   'one',
#   'tripped',
#   'and',
#   'grabbed',
#   'my',
#   'boobs',
#   'by',
#   'accident',
#   'though',
#   'so',
#   'it',
#   'could',
#   'be',
#   'a',
#   'lot',
#   'worse',
#   'more',
#   'weeb'],
#  ['upload', 'your', 'video', 'op'],
#  ['i',
#   'literally',
#   'posted',
#   'on',
#   'rjapan',
#   'for',
#   'the',
#   'first',
#   'time',
#   'ever',
#   'a',
#   'couple',
#   'of',
#   'hours',
#   'ago',
#   'here',
#   's',
#   'the',
#   'thread',
#   'https',
#   'wwwredditcomrjapancomments464491themythologybehindringulookingformovies'],
#  ['i',
#   'christened',
#   'my',
#   'new',
#   'ship',
#   'krenim',
#   'science',
#   'vessel',
#   'from',
#   'the',
#   'anniversary',
#   'event',
#   'in',
#   'star',
#   'trek',
#   'online',
#   'with',
#   'the',
#   'name',
#   'shirayuki',
#   'last',
#   'night',
#   'yes',
#   'the',
#   'nerd',
#   'is',
#   'strong',
#   'with',
#   'this',
#   'one'],
#  ['i', 'bought', 'a', 'terra', 'formars', 'figurine', 'prett', 'cool'],
#  [],
#  ['kurapika',
#   'out',
#   'https',
#   'pbstwimgcommediabznnxoucqaa7hkdpng',
#   'but',
#   'kirei',
#   'made',
#   'it',
#   'through',
#   'so',
#   'http',
#   'iimgurcomqlaggq2gifv'],
#  ['wow',
#   'kotomine',
#   'vs',
#   'armstrong',
#   'was',
#   'a',
#   'mere',
#   '20',
#   'vote',
#   'difference',
#   'every',
#   'vote',
#   'counts',
#   'people'],
#  ['vote',
#   'for',
#   'kougami',
#   'https',
#   'smediacacheak0pinimgcomoriginals20249c20249c8af59e48a8c723cf23ecc853b5gif',
#   'and',
#   'levi',
#   'http',
#   'orig15deviantartnet0faff20132601clevivsfemaletitangifbydillinghamd6mff2dgif',
#   'crushcirclejerks'],
#  ['ginchan', 'deserves', 'more', 'appreciation', 'for', 'his', 'work'],
#  [],
#  ['kuroko', 'no', 'basket', 'of', 'course'],
#  ['jojo', 's', 'bizarre', 'adventure'],
#  ['shokugeki', 'no', 'soma', 'sure', 'got', 'my', 'blood', 'pumping'],
#  ['baccano', 'and', 'birdy', 'the', 'mighty', 'decode'],
#  ['ponytails',
#   'http',
#   'iimgurcomse7dkctgif',
#   'ponytails',
#   'http',
#   'iimgurcomnh3eulhpng',
#   'ponytails',
#   'http',
#   'iimgurcomrzlkbx4jpg',
#   'ponytails',
#   'http',
#   'iimgurcomumvndzngifv'],
#  ['opai'],
#  ['no',
#   'gin',
#   'look',
#   'at',
#   'this',
#   'glorious',
#   'nose',
#   'gintamathispleasesme'],
#  ['i',
#   'just',
#   'started',
#   'watching',
#   'the',
#   'first',
#   'episode',
#   'yesterday',
#   'seems',
#   'interesting',
#   'enough',
#   'but',
#   'should',
#   'i',
#   'watch',
#   'it',
#   'in',
#   'dub',
#   'or',
#   'sub'],
#  ['i',
#   'am',
#   'so',
#   'excited',
#   'for',
#   'this',
#   'a',
#   'special',
#   'lady',
#   'recommended',
#   'me',
#   'this',
#   'manga',
#   'just',
#   'this',
#   'sunday',
#   'and',
#   'it',
#   'was',
#   'a',
#   'good',
#   'read',
#   'we',
#   're',
#   'both',
#   'excited',
#   'for',
#   'this',
#   'anime',
#   'and',
#   'the',
#   'live',
#   'action'],
#  ['so',
#   'my',
#   'friend',
#   'showed',
#   'me',
#   'an',
#   'image',
#   'from',
#   'some',
#   'anime',
#   'where',
#   'the',
#   'mc',
#   'had',
#   'done',
#   'some',
#   'integration',
#   'problems',
#   'on',
#   'his',
#   'book',
#   'i',
#   'was',
#   'wondering',
#   'if',
#   'there',
#   'were',
#   'any',
#   'other',
#   'scenes',
#   'in',
#   'different',
#   'anime',
#   'with',
#   'higher',
#   'math',
#   'involved'],
#  ['i',
#   'm',
#   'so',
#   'happy',
#   'they',
#   'kept',
#   'the',
#   'original',
#   'music',
#   'from',
#   'the',
#   'final',
#   'flash',
#   'scene'],
#  ['so',
#   'happy',
#   'to',
#   'see',
#   'new',
#   'episodes',
#   'arriving',
#   'sooner',
#   'these',
#   'days'],
#  ['not',
#   'sure',
#   'how',
#   'to',
#   'put',
#   'it',
#   'in',
#   'wording',
#   'but',
#   'examples',
#   'would',
#   'suffice',
#   'for',
#   'eg',
#   'nge',
#   's',
#   'anno',
#   'might',
#   'have',
#   'intented',
#   'asuka',
#   'to',
#   'be',
#   'a',
#   'symbol',
#   'of',
#   'what',
#   'really',
#   'goes',
#   'into',
#   'the',
#   'heads',
#   'of',
#   'a',
#   'tsundere',
#   'and',
#   'how',
#   'liking',
#   'such',
#   'characters',
#   'is',
#   'flawed',
#   'but',
#   'fans',
#   'ended',
#   'up',
#   'loving',
#   'her',
#   'paranoia',
#   'agent',
#   's',
#   'the',
#   'show',
#   'became',
#   'so',
#   'successful',
#   'that',
#   'you',
#   'can',
#   'actually',
#   'buy',
#   'maromi',
#   'merchandise',
#   'in',
#   'real',
#   'life'],
#  ['fall',
#   '2014',
#   'i',
#   'watched',
#   'a',
#   'lot',
#   'that',
#   'season',
#   'so',
#   'trinity',
#   'seven',
#   'shigatsu',
#   'psycho',
#   'pass',
#   '2',
#   'twintails',
#   'madan',
#   'no',
#   'ou',
#   'log',
#   '2',
#   'kiseijuu',
#   'gundam',
#   'build',
#   'fighters',
#   'try',
#   'gugure',
#   'kokkurisan',
#   'grisaia',
#   'no',
#   'kajitsu',
#   'fate',
#   'ubw',
#   'denkigai',
#   'danna',
#   'ga',
#   'cross',
#   'ange',
#   'amagi',
#   'brilliant',
#   'park',
#   'inou',
#   'battle',
#   'and',
#   'watched',
#   'shirobako',
#   'at',
#   'a',
#   'later',
#   'time'],
#  ['spring',
#   '2015',
#   'plastic',
#   'memories',
#   'danmachi',
#   'kekkai',
#   'sensen',
#   'only',
#   'one',
#   'of',
#   'those',
#   'i',
#   'liked'],
#  ['summer',
#   '2012',
#   'sword',
#   'art',
#   'online',
#   'dakara',
#   'boku',
#   'wa',
#   'h',
#   'ga',
#   'dekinai',
#   'campione',
#   'hagure',
#   'yuusha',
#   'no',
#   'aesthetica',
#   'muvluv',
#   'alternative',
#   'total',
#   'eclipse',
#   'my',
#   'tastes',
#   'back',
#   'then',
#   'werequestionable'],
#  ['fall',
#   '2014',
#   'with',
#   'fsn',
#   'ubw',
#   'parasyte',
#   'your',
#   'lie',
#   'in',
#   'april',
#   'log',
#   'horizon',
#   '2',
#   'twin',
#   'tails'],
#  ['gt',
#   'ops',
#   'and',
#   'eds',
#   'count',
#   'as',
#   'well',
#   'dat',
#   'clannad',
#   'after',
#   'story',
#   'ed',
#   'skipping',
#   'children',
#   'give',
#   'me',
#   'ptsd',
#   'attacks',
#   'now'],
#  ['that',
#   'one',
#   'time',
#   'when',
#   'kotourasan',
#   'and',
#   'friends',
#   'go',
#   'to',
#   'sing',
#   'karaoke',
#   'https',
#   'youtubecdjcuhuosci',
#   't',
#   '14s',
#   'and',
#   'she',
#   'tries',
#   'to',
#   'sing',
#   'her',
#   'own',
#   'op'],
#  ['the',
#   'awful',
#   'phantom',
#   'requiem',
#   'for',
#   'the',
#   'phantom',
#   '2nd',
#   'op',
#   'https',
#   'wwwyoutubecomwatch',
#   'v',
#   'xf2ynhaeqvk'],
#  ['maybe',
#   'this',
#   'op',
#   'will',
#   'be',
#   'beautibeautibeautiful',
#   'one',
#   'day',
#   'https',
#   'wwwyoutubecomwatch',
#   'v',
#   '8dkljqhcsoe',
#   'just',
#   'not',
#   'any',
#   'day',
#   'i',
#   'm',
#   'listening',
#   'to',
#   'it',
#   'worst',
#   'gintama',
#   'op',
#   'by',
#   'a',
#   'long',
#   'stretch'],
#  ['names', 'of', 'brandsmovieswhatever', 'else', 'you', 'come', 'up', 'with'],
#  ['for',
#   'me',
#   'it',
#   's',
#   'my',
#   'neighbor',
#   'pedoro',
#   'https',
#   'youtubewnkipydwzy'],
#  ['sudohbucks', 'http', 'iimgurcom83jsejpg', 'in', 'toradora'],
#  ['wacdonalds',
#   'is',
#   'always',
#   'a',
#   'favorite',
#   'of',
#   'mine',
#   'i',
#   'also',
#   'liked',
#   'dr',
#   'papper'],
#  ['all', 'the', 'different', 'name', 'versions', 'of', 'mcdonalds', 'lol'],
#  ['all',
#   'the',
#   'shinsengumi',
#   'in',
#   'gintama',
#   'are',
#   'based',
#   'on',
#   'historical',
#   'members',
#   'of',
#   'da',
#   'real',
#   'deal',
#   'shinsengumi'],
#  ['yohoo', 'in', 'durarara'],
#  ['eaten',
#   'natto',
#   'after',
#   'i',
#   'saw',
#   'micaela',
#   's',
#   'trick',
#   'i',
#   'eat',
#   'it',
#   'all',
#   'the',
#   'time',
#   'https',
#   'wwwyoutubecomwatch',
#   'v',
#   'lovfrcdnkny'],
#  ['looking',
#   'for',
#   'a',
#   'good',
#   'romance',
#   'that',
#   'is',
#   'nt',
#   'the',
#   'main',
#   'driving',
#   'force',
#   'i',
#   'liked',
#   'toradora',
#   'and',
#   'white',
#   'album',
#   '2',
#   'a',
#   'lot',
#   'but',
#   'i',
#   'guess',
#   'i',
#   'mean',
#   'something',
#   'more',
#   'like',
#   'gundam',
#   '08th',
#   'ms',
#   'team',
#   'where',
#   'there',
#   'was',
#   'a',
#   'greater',
#   'plot',
#   'going',
#   'on',
#   'and',
#   'the',
#   'romance',
#   'was',
#   'a',
#   'sub',
#   'plot',
#   'thank',
#   'you'],
#  ['visited', 'this', 'sub'],
#  ['all',
#   'these',
#   'random',
#   'fma',
#   'and',
#   'ubw',
#   'characters',
#   'are',
#   'killing',
#   'my',
#   'vibe',
#   'good',
#   'shows',
#   'but',
#   'variety',
#   'is',
#   'the',
#   'spice',
#   'of',
#   'life'],
#  ['went',
#   'to',
#   'the',
#   'movies',
#   'to',
#   'see',
#   'the',
#   'love',
#   'live',
#   'movie',
#   'stayed',
#   'afterward',
#   'for',
#   'pictures',
#   'of',
#   'the',
#   'cosplayers',
#   'and',
#   'talked',
#   'to',
#   'a',
#   'few',
#   'of',
#   'them'],
#  ['well',
#   'let',
#   's',
#   'see',
#   'laptop',
#   'wallpaper',
#   'http',
#   'prntscrcoma4a8mv',
#   'phone',
#   'background',
#   'http',
#   'prntscrcoma4aa4b',
#   'league',
#   'of',
#   'legends',
#   'name',
#   'http',
#   'prntscrcoma4aabe',
#   'xbox',
#   'live',
#   'name',
#   'http',
#   'prntscrcoma4aaj0'],
#  ['i', 'got', 'voteblocked', 'by', 'fate', '3', 'times', 'again', 'fml'],
#  ['bought',
#   'a',
#   'kuroyukihime',
#   'figure',
#   'not',
#   'a',
#   'cheap',
#   'one',
#   'either'],
#  ['so', 'goku', 'can', 'dodge'],
#  ['make',
#   'my',
#   'discord',
#   'chat',
#   'have',
#   'a',
#   'full',
#   'blown',
#   'weeb',
#   'hour',
#   'every',
#   'week',
#   'at',
#   '4am',
#   'its',
#   'for',
#   'euros',
#   'and',
#   'im',
#   'american'],
#  ['i',
#   'did',
#   'nt',
#   'watch',
#   'the',
#   'superbowl',
#   'because',
#   'the',
#   'last',
#   'match',
#   'in',
#   'the',
#   'first',
#   'season',
#   'of',
#   'haikyuu',
#   'was',
#   'too',
#   'intense'],
#  ['i',
#   'm',
#   'looking',
#   'for',
#   'a',
#   'more',
#   'polarizing',
#   'anime',
#   'to',
#   'review',
#   'any',
#   'suggestions'],
#  ['that', 'ending', 'the', 'horror'],
#  ['hyperdimensional', 'neptunia', 'is', 'awesome', 'that', 'is', 'all'],
#  ['unravel', 'kukuku'],
#  ['trinity',
#   'seven',
#   'has',
#   'some',
#   'of',
#   'the',
#   'worst',
#   'sound',
#   'mixing',
#   'and',
#   'background',
#   'tracks',
#   'i',
#   've',
#   'ever',
#   'heard',
#   'a',
#   'lot',
#   'of',
#   'whispering',
#   'does',
#   'not',
#   'make',
#   'it',
#   'mysterious',
#   'and',
#   'cool',
#   'and',
#   'good',
#   'granted',
#   'i',
#   'can',
#   'be',
#   'super',
#   'nitpicking',
#   'in',
#   'terms',
#   'of',
#   'audio',
#   'mixing',
#   'but',
#   'holy',
#   'fudge',
#   'it',
#   'was',
#   'beyond',
#   'redemption',
#   'and',
#   'not',
#   'fit',
#   'for',
#   'human',
#   'ears',
#   'in',
#   'the',
#   'later',
#   'episodes',
#   'no',
#   'comment',
#   'about',
#   'the',
#   'op',
#   'and',
#   'ed',
#   'since',
#   'i',
#   'already',
#   'forget',
#   'what',
#   'they',
#   'are'],
#  ['summer',
#   '2009',
#   'that',
#   's',
#   'also',
#   'when',
#   'i',
#   'started',
#   'to',
#   'watch',
#   'anime',
#   'with',
#   'english',
#   'subtitles',
#   'because',
#   'they',
#   'came',
#   'out',
#   'faster',
#   'and',
#   'i',
#   'was',
#   'really',
#   'hyped',
#   'for',
#   'umineko',
#   'because',
#   'i',
#   'was',
#   'a',
#   'huge',
#   'higurashi',
#   'fan',
#   'i',
#   'watched',
#   'umineko',
#   'and',
#   'tried',
#   'to',
#   'watch',
#   'bakemonogatari',
#   'but',
#   'my',
#   'english',
#   'was',
#   'nt',
#   'good',
#   'enough',
#   'in',
#   'the',
#   'end',
#   'umineko',
#   'was',
#   'shit',
#   'but',
#   'the',
#   'oped',
#   'were',
#   'excellent'],
#  ['looks',
#   'like',
#   'this',
#   'will',
#   'turn',
#   'out',
#   'to',
#   'be',
#   'a',
#   'fateoff',
#   'i',
#   'll',
#   'let',
#   'myself',
#   'out',
#   'now'],
#  ['i', 'put', 'some', 'gintama', 'wallpapers', 'on', 'my', 'laptop'],
#  ['2013',
#   'winter',
#   'mondaijitachi',
#   'ga',
#   'isekai',
#   'kara',
#   'kuru',
#   'sou',
#   'desu',
#   'yo',
#   'boku',
#   'wa',
#   'tomodachi',
#   'ga',
#   'sukunai',
#   'next',
#   'cuticle',
#   'tantei',
#   'inaba',
#   'maoyuu',
#   'maou',
#   'yuusha',
#   'ore',
#   'no',
#   'kanojo',
#   'to',
#   'osananajimi',
#   'ga',
#   'shuraba',
#   'sugiru',
#   'sasamisan',
#   'ganbaranai',
#   'vividred',
#   'operation',
#   'senran',
#   'kagura',
#   'amnesia',
#   'hakkenden',
#   'touhou',
#   'hakken',
#   'ibun',
#   'at',
#   'the',
#   'time',
#   'i',
#   'did',
#   'nt',
#   'know',
#   'what',
#   'to',
#   'expect',
#   'and',
#   'just',
#   'went',
#   'with',
#   'most',
#   'of',
#   'the',
#   'things',
#   'that',
#   'season',
#   'after',
#   'that',
#   'season',
#   'i',
#   'had',
#   'some',
#   'regrets',
#   'but',
#   'continuing',
#   'to',
#   'watch',
#   'anime',
#   'seasonally'],
#  ['i',
#   'just',
#   'finished',
#   'season',
#   '1',
#   'and',
#   'started',
#   'repeat',
#   'such',
#   'a',
#   'great',
#   'show',
#   'niichan',
#   'is',
#   'my',
#   'hero'],
#  ['just',
#   'saw',
#   'the',
#   'diving',
#   'in',
#   'the',
#   'river',
#   'episode',
#   'of',
#   'repeat',
#   'that',
#   'picture',
#   'renge',
#   'took',
#   'on',
#   'the',
#   'cell',
#   'phone',
#   'was',
#   'funny',
#   'as',
#   'heck'],
#  ['that',
#   'would',
#   'just',
#   'serve',
#   'to',
#   'confuse',
#   'ms',
#   'suzumiya',
#   'https',
#   'youtubeoh9b1uy4tcu'],
#  ['acdc'],
#  ['dack', 'janiels', 'heireken'],
#  ['sern', 'dk', 'pepper'],
#  ['the', 'classic', 'wcdonalds'],
#  ['girugameshi',
#   'of',
#   'course',
#   'it',
#   'is',
#   'derived',
#   'from',
#   'gilgamesh',
#   'but',
#   'more',
#   'meshi',
#   's'],
#  ['pino', 'co', 'lada', 'from', 'gate'],
#  ['white', 'album', '2', 'amagami', 'ss', 'has', 'two', 'defrostings'],
#  ['angel',
#   'beats',
#   'http',
#   'myanimelistnetanime6547angelbeats',
#   'seems',
#   'to',
#   'be',
#   'the',
#   'obvious',
#   'entry',
#   'missing',
#   'from',
#   'your',
#   'list'],
#  ['angel', 'beats', 'is', 'a', 'good', 'one', 'd'],
#  ['oniai'],
#  ['i',
#   'think',
#   'you',
#   'forgot',
#   'about',
#   'best',
#   'girl',
#   'hana',
#   'http',
#   'cdnmyanimelistnetscommonuploadedfiles1443544738ceca3f6530f906e3f13e6ba3458b37ccjpeg'],
#  ['lol',
#   'of',
#   'course',
#   'they',
#   'have',
#   'the',
#   'mira',
#   'fanservice',
#   'shot',
#   'at',
#   'the',
#   'end'],
#  ['desert', 'punk', 'is', 'a', 'bit'],
#  ['sometimes',
#   'being',
#   'too',
#   'mainstream',
#   'can',
#   'be',
#   'pass',
#   'what',
#   'is',
#   'your',
#   'favorite',
#   'underground',
#   'anime',
#   'and',
#   'why'],
#  ['the',
#   'empire',
#   'of',
#   'corpse',
#   'movie',
#   'that',
#   'just',
#   'released',
#   'is',
#   'steampunk'],
#  ['kaworu',
#   'nagisa',
#   'https',
#   'wwwanimecharactersdatabasecomuploadschars5092242321200jpg'],
#  ['nanamihug'],
#  ['izaya', 'he', 's', 'ma', 'boi', 'best', 'part', 'of', 'durararayawn'],
#  ['i',
#   'm',
#   'not',
#   'a',
#   'fan',
#   'of',
#   'hellsing',
#   'ultimate',
#   'but',
#   'holy',
#   'shit',
#   'is',
#   'alucard',
#   'one',
#   'hell',
#   'of',
#   'a',
#   'fuckmothering',
#   'vampire'],
#  ['kuronekoruri', 'gokou'],
#  ['meruem'],
#  ['char',
#   'http',
#   '49mediatumblrcomf9d2f812a20f7847e1d7611c753cbe2etumblrmu4eked3kt1s5f9ado1500gif',
#   'and',
#   'http',
#   '25mediatumblrcom6eff46cde1adfa8bd3242e52b892db0ctumblrmw83opmqmh1r5rnoxo1500gif',
#   'laura',
#   'https',
#   '45mediatumblrcom298585422f9d7304e65f7a1d507e1d10tumblrnbowokk6aj1slfw0xo1500gif',
#   'my',
#   'love',
#   'for',
#   'char',
#   'is',
#   'only',
#   'matched',
#   'by',
#   'my',
#   'resentment',
#   'of',
#   'the',
#   'show',
#   'as',
#   'a',
#   'whole'],
#  ['tsubasa',
#   'chronicles',
#   'kurogane',
#   'he',
#   'is',
#   'an',
#   'awesome',
#   'character',
#   'however',
#   'i',
#   'hate',
#   'the',
#   'show',
#   'it',
#   'makes',
#   'little',
#   'sense',
#   'and',
#   'it',
#   's',
#   'confusing',
#   'it',
#   'even',
#   'turns',
#   'out',
#   'the',
#   'mc',
#   'is',
#   'nt',
#   'even',
#   'the',
#   'main',
#   'character'],
#  ['kamina', 'from', 'ttgl'],
#  ['rokka', 'no', 'yuusha', 'fremy', 'speeddraw'],
#  ['intensely',
#   'views',
#   'thread',
#   'for',
#   'more',
#   'kuuderes',
#   'kuudere',
#   'best',
#   'dere',
#   'i',
#   'see',
#   'oregairu',
#   'being',
#   'recommended',
#   'and',
#   'i',
#   'second',
#   'to',
#   'that',
#   'statement'],
#  ['toradora'],
#  ['gt',
#   'but',
#   'hanekowa',
#   'is',
#   'bg',
#   'op',
#   'i',
#   'think',
#   'you',
#   'misspelled',
#   'shinobu'],
#  ['melancholy',
#   'of',
#   'haruhi',
#   'suzumiya',
#   'main',
#   'series',
#   'into',
#   'the',
#   'disappearance',
#   'movie'],
#  ['would', 'nt', 'hinazuki', 'from', 'bokudake', 'count', 'as', 'kuudere'],
#  ['oreshura',
#   'best',
#   'girl',
#   'http',
#   'mdzanimemewpcontentuploads201302124jpg',
#   'kuudere',
#   'shares',
#   'the',
#   'same',
#   'voice',
#   'actor',
#   'as',
#   'hitagi',
#   'edit',
#   'she',
#   'sounds',
#   'like',
#   'senjougahara',
#   'xd'],
#  ['boko', 'no', 'piku'],
#  ['honey',
#   'amp',
#   'clover',
#   'http',
#   'myanimelistnetanime16hachimitsutoclover',
#   'is',
#   'pretty',
#   'heavy',
#   'on',
#   'the',
#   'drama',
#   'so',
#   'is',
#   'kids',
#   'on',
#   'the',
#   'slope',
#   'http',
#   'myanimelistnetanime12531sakamichinoapollon'],
#  ['itazura', 'na', 'kiss'],
#  ['senjougahara'],
#  ['here',
#   'is',
#   'the',
#   'easiest',
#   'argument',
#   'to',
#   'make',
#   's',
#   'chocolate',
#   'cornets',
#   'are',
#   'shaped',
#   'like',
#   'dicks'],
#  ['kongou',
#   'is',
#   'pretty',
#   'awesome',
#   'too',
#   'bad',
#   'her',
#   'show',
#   'sucks',
#   'kantai',
#   'collection'],
#  ['tk', 'from', 'angel', 'beats'],
#  ['kurumi',
#   'from',
#   'date',
#   'a',
#   'live',
#   'she',
#   'even',
#   'has',
#   'the',
#   'only',
#   'meaningful',
#   'dialogues',
#   'in',
#   'a',
#   'retarded',
#   'show'],
#  ['for',
#   'example',
#   'i',
#   'ca',
#   'nt',
#   'browse',
#   'twitter',
#   'in',
#   'public',
#   'anymore',
#   'you',
#   'can',
#   'guess',
#   'why',
#   'but',
#   'i',
#   'can',
#   'differ',
#   'japanese',
#   'now',
#   'from',
#   'chinese',
#   'or',
#   'korean',
#   'might',
#   'be',
#   'helpful',
#   'someday'],
#  ['kaneki', 'from', 'tokyo', 'ghoul'],
#  ['athrun', 'and', 'cagalli', 'from', 'gundam', 'seed', 'destiny'],
#  ['mitsuki', 'nase', 'from', 'kyoukai', 'no', 'kanata'],
#  ['ami', 'from', 'toradora', 'http', 'iimgurcom8hgrkzejpg'],
#  ['this', 'naruto', 'joke', 'link', 'http', 'imgurcomk8sjgwg'],
#  ['comes', 'close', 'to', 'camera', 'your', 'waifu', 'is', 'shit'],
#  ['killua', 'from', 'hunter', 'x', 'hunter'],
#  ['i',
#   'would',
#   'recommend',
#   'sore',
#   'ga',
#   'seiyuu',
#   'http',
#   'myanimelistnetanime29163soregaseiyuu',
#   'for',
#   'some',
#   'insight'],
#  ['gilgamesh', 'from', 'fsn', 'ubw'],
#  ['mayumi',
#   'my',
#   'arch',
#   'enemies',
#   'know',
#   'which',
#   'anime',
#   'i',
#   'm',
#   'referring',
#   'to'],
#  ['nanami', 'aoyama'],
#  ['asuna', 'from', 'sao'],
#  ['akagami',
#   'no',
#   'shirayukihime',
#   'is',
#   'very',
#   'good',
#   'in',
#   'my',
#   'opinion',
#   'plus',
#   'you',
#   'get',
#   'based',
#   'god',
#   'mitsuhide'],
#  ['right',
#   'in',
#   'the',
#   'middle',
#   'of',
#   'finals',
#   'but',
#   '100',
#   'worth',
#   'it',
#   'looking',
#   'forward',
#   'to',
#   'this'],
#  ['what', 's', 'this', 'show', 'about', 'i', 'm', 'too', 'lazy'],
#  ['getting', 'ready', 'for', 'season', '3'],
#  ['i',
#   've',
#   'been',
#   'meaning',
#   'to',
#   'watch',
#   'this',
#   'for',
#   'a',
#   'while',
#   'now',
#   'i',
#   'll',
#   'probably',
#   'join',
#   'in'],
#  ['it',
#   's',
#   'the',
#   'only',
#   'thing',
#   'about',
#   'spice',
#   'and',
#   'wolf',
#   'that',
#   'would',
#   'be',
#   'announced',
#   'soon',
#   'lol'],
#  ['i',
#   've',
#   'had',
#   'the',
#   'full',
#   'collection',
#   'for',
#   'samp',
#   'w',
#   'since',
#   'christmas',
#   'but',
#   'have',
#   'nt',
#   'gotten',
#   'around',
#   'to',
#   'watching',
#   'it',
#   'so',
#   'this',
#   'would',
#   'be',
#   'nice'],
#  ['i',
#   'll',
#   'probably',
#   'be',
#   'too',
#   'busy',
#   'to',
#   'watch',
#   'again',
#   'but',
#   'i',
#   'can',
#   'repost',
#   'my',
#   'ln',
#   'comparisons',
#   'from',
#   'last',
#   'year',
#   'if',
#   'anyone',
#   's',
#   'interested'],
#  ['he',
#   'd',
#   'talk',
#   'about',
#   'how',
#   'similar',
#   'his',
#   'show',
#   'seems',
#   'to',
#   'gintama'],
#  ['what',
#   'references',
#   'would',
#   'he',
#   'make',
#   'to',
#   'other',
#   'anime',
#   'how',
#   'would',
#   'he',
#   'break',
#   'the',
#   'fourth',
#   'wall',
#   'in',
#   'an',
#   'animated',
#   'world',
#   'other',
#   'kinds',
#   'of',
#   'jokes',
#   'that',
#   'i',
#   'have',
#   'nt',
#   'thought',
#   'of'],
#  ['watch',
#   'the',
#   'episode',
#   'of',
#   'marvel',
#   's',
#   'disk',
#   'avengers',
#   'where',
#   'he',
#   'appeared',
#   'in'],
#  ['he', 'll', 'start', 'by', 'sleeping', 'with', 'everyone'],
#  ['wat'],
#  ['episode',
#   '10',
#   'of',
#   'madoka',
#   'magica',
#   'episode',
#   '23',
#   'of',
#   'shinsekai',
#   'yori'],
#  ['there',
#   'are',
#   'some',
#   'great',
#   'nanohadeadpool',
#   'fan',
#   'comics',
#   'nsfw',
#   '1',
#   'http',
#   'evilrickdeviantartcomartdeadpoolandnanohaissue2210631066',
#   '2',
#   'http',
#   'evilrickdeviantartcomartdeadpoolandnanohaissue5257345047',
#   '3',
#   'http',
#   'evilrickdeviantartcomartdeadpoolandnanohaissue4244327742'],
#  ['please', 'elaborate', 'your', 'answer'],
#  ['they',
#   'only',
#   'record',
#   'separately',
#   'for',
#   'anime',
#   'dubbing',
#   'iirc',
#   'many',
#   'western',
#   'animated',
#   'series',
#   'still',
#   'record',
#   'together'],
#  ['goddammit',
#   'every',
#   'rewatch',
#   'happens',
#   'right',
#   'after',
#   'i',
#   'finish',
#   'a',
#   'show'],
#  ['but', 'i', 'just', 'started', 'second', 'season'],
#  ['excited',
#   'for',
#   'this',
#   'can',
#   'never',
#   'have',
#   'enough',
#   'holo',
#   'in',
#   'my',
#   'life'],
#  ['remindme',
#   '1',
#   'month',
#   'spice',
#   'and',
#   'wolf',
#   'rewatch',
#   'lets',
#   'see',
#   'if',
#   'that',
#   'works'],
#  ['gt',
#   'mine',
#   'would',
#   'be',
#   'the',
#   'knowledge',
#   'from',
#   'conan',
#   'gt',
#   'because',
#   'knowledge',
#   'is',
#   'power',
#   'here',
#   'in',
#   'my',
#   'garaaaage',
#   'the',
#   'best',
#   'power',
#   'is',
#   'the',
#   'ability',
#   'to',
#   'have',
#   'a',
#   'harem',
#   'full',
#   'of',
#   'cute',
#   'anime',
#   'girls'],
#  ['mystic',
#   'eyes',
#   'of',
#   'death',
#   'perception',
#   'the',
#   'power',
#   'to',
#   'bring',
#   'the',
#   'world',
#   'revolution',
#   'penguindrum'],
#  ['imagine',
#   'breaker',
#   'whatever',
#   'is',
#   'inside',
#   'imagine',
#   'breaker',
#   'unlimited',
#   'blade',
#   'works',
#   'i',
#   'like',
#   'swords'],
#  ['oh',
#   'the',
#   'rewatch',
#   'starts',
#   'on',
#   'my',
#   'birthday',
#   'well',
#   'i',
#   've',
#   'been',
#   'meaning',
#   'to',
#   'watch',
#   'this',
#   'for',
#   'quite',
#   'a',
#   'while',
#   'so',
#   'i',
#   'm',
#   'probably',
#   'going',
#   'to',
#   'join',
#   'as',
#   'a',
#   'first',
#   'time',
#   'watcher'],
#  ['tenjou', 'tenge', 'episode', '2'],
#  ['which',
#   'is',
#   'the',
#   'best',
#   'anime',
#   'character',
#   'power',
#   'based',
#   'on',
#   'what',
#   'you',
#   've',
#   'watched',
#   'try',
#   'to',
#   'be',
#   'descriptive',
#   'and',
#   'explain',
#   'mine',
#   'would',
#   'be',
#   'the',
#   'knowledge',
#   'from',
#   'conan',
#   'detective',
#   'conan',
#   'because',
#   'knowledge',
#   'is',
#   'power'],
#  ['i', 'like', 'kotoha', 's', 'powerspeak'],
#  ['gt',
#   'mine',
#   'would',
#   'be',
#   'the',
#   'knowledge',
#   'from',
#   'conan',
#   'detective',
#   'conan',
#   'because',
#   'knowledge',
#   'is',
#   'power',
#   'but',
#   'then',
#   'there',
#   's',
#   'saitama',
#   's',
#   'punch'],
#  ['diamond',
#   'no',
#   'ace',
#   'its',
#   'as',
#   'good',
#   'as',
#   'haikyuu',
#   'and',
#   'not',
#   'even',
#   'close',
#   'to',
#   'as',
#   'popular',
#   'i',
#   'love',
#   'them',
#   'both',
#   'equally'],
#  ['nope',
#   'http',
#   'imgurcomgalleryj5sbp',
#   'also',
#   'anime',
#   'need',
#   'less',
#   'boring',
#   'flashy',
#   'super',
#   'powered',
#   'teenagers',
#   'playing',
#   'in',
#   'shitty',
#   'tournaments',
#   'and',
#   'needs',
#   'more',
#   'interesting',
#   'political',
#   'and',
#   'conspiracy',
#   'driven',
#   'shows',
#   'make',
#   'me',
#   'a',
#   'house',
#   'of',
#   'cards',
#   'esque',
#   'anime',
#   'show',
#   'and',
#   'i',
#   'would',
#   'be',
#   'happy'],
#  ['so',
#   'this',
#   'kid',
#   'goes',
#   'to',
#   'a',
#   'school',
#   'that',
#   'is',
#   'mostly',
#   'full',
#   'of',
#   'girls',
#   'gains',
#   'some',
#   'magic',
#   'power',
#   'or',
#   'some',
#   'shit',
#   '6',
#   'girls',
#   'want',
#   'to',
#   'have',
#   'sex',
#   'with',
#   'him',
#   'pretty',
#   'original',
#   'and',
#   'unique'],
#  ['cute', 'guys', 'doing', 'cute', 'things'],
#  ['a',
#   'narrative',
#   'anime',
#   'in',
#   'the',
#   'eyes',
#   'of',
#   'a',
#   'baby',
#   'something',
#   'like',
#   'rugrats',
#   'except',
#   'the',
#   'baby',
#   'tackles',
#   'thoughts',
#   'of',
#   'existentialism',
#   'and',
#   'the',
#   'meaning',
#   'of',
#   'life',
#   'comedysol'],
#  ['nonhentai',
#   'anime',
#   'either',
#   'about',
#   'cute',
#   'milfscakesols',
#   'doing',
#   'cute',
#   'things',
#   'or',
#   'romcomdrama',
#   'harem',
#   'with',
#   'milfscakesols'],
#  ['startide',
#   'rising',
#   'https',
#   'enwikipediaorgwikistartiderising',
#   'the',
#   'uplift',
#   'https',
#   'enwikipediaorgwikibrightnessreef',
#   'storm',
#   'https',
#   'enwikipediaorgwikiinfinitysshore',
#   'trilogy',
#   'https',
#   'enwikipediaorgwikiheavensreach',
#   'may',
#   'be',
#   'a',
#   'bit',
#   'more',
#   'accessible',
#   'with',
#   'the',
#   'kid',
#   's',
#   'storyline',
#   'though',
#   'it',
#   'may',
#   'seem',
#   'a',
#   'bit',
#   'random',
#   'without',
#   'the',
#   'context',
#   'of',
#   'startide',
#   'rising'],
#  [],
#  ['the', 'whole', 'lupin', 'iii', 'franchise'],
#  ['goat', 'simulator', 'the', 'anime'],
#  ['pepe',
#   's',
#   'bizarre',
#   'adventure',
#   'i',
#   'do',
#   'nt',
#   'think',
#   'i',
#   'need',
#   'to',
#   'explain',
#   'more'],
#  ['breakfast',
#   'cereals',
#   'are',
#   'cute',
#   'girls',
#   'that',
#   'go',
#   'to',
#   'high',
#   'school'],
#  ['http',
#   'imgurcomah4yii',
#   'still',
#   'watching',
#   'my',
#   'head',
#   'for',
#   'signs',
#   'of',
#   'hair',
#   'loss',
#   'check',
#   'out',
#   'my',
#   'tumblr',
#   'http',
#   'gsculpttumblrcom',
#   'for',
#   'more',
#   'sculptures'],
#  ['um',
#   'woah',
#   'we',
#   'do',
#   'nt',
#   'see',
#   'fucking',
#   'sculptures',
#   'fanart',
#   'that',
#   'often',
#   'sekkou',
#   'saitama'],
#  ['wow', 'that', 's', 'ridiculously', 'awesome', 'nice', 'job', 'helmetbro'],
#  ['clap', 'clap', 'clap', 'bravo'],
#  ['sekkou',
#   'boys',
#   'can',
#   'someone',
#   'shop',
#   'saitma',
#   'into',
#   'the',
#   'group',
#   'xd'],
#  ['what', 'the', 'shit'],
#  ['desert', 'punk'],
#  ['anime',
#   'suggestions',
#   'for',
#   'deadpan',
#   'humor',
#   'or',
#   'characters',
#   'with',
#   'deadpan',
#   'humor'],
#  ['do', 'you', 'do', 'offland', 'shipments'],
#  ['ummmmho', 'lee', 'shet', 'that', 's', 'amazing'],
#  ['only', '82', 'i', 'bet', 'you', 'can', 'sell', 'quite', 'a', 'few'],
#  ['down', 'voted', 'because', 'no', 'banana', 'for', 'scale'],
#  ['this', 'is', 'fucking', 'glorious'],
#  ['wow',
#   'a',
#   'sekko',
#   'saitama',
#   'now',
#   'there',
#   'needs',
#   'to',
#   'be',
#   'a',
#   'opm',
#   'and',
#   'sekko',
#   'boys',
#   'collaboration',
#   'outstanding',
#   'job'],
#  ['you', 'made', 'this', 'i', 'made', 'this'],
#  ['good', 'job', 'sensei'],
#  [],
#  ['i',
#   'started',
#   'my',
#   'first',
#   'visual',
#   'novel',
#   'and',
#   'i',
#   'had',
#   'to',
#   'set',
#   'my',
#   'pc',
#   'to',
#   'japanese',
#   'to',
#   'install',
#   'it',
#   'it',
#   's',
#   'too',
#   'addicting',
#   'send',
#   'help',
#   'pls'],
#  ['i',
#   'started',
#   'watching',
#   'the',
#   'love',
#   'live',
#   'dub',
#   'today',
#   'i',
#   'never',
#   'thought',
#   'that',
#   'my',
#   'best',
#   'girl',
#   'could',
#   'change',
#   'by',
#   'a',
#   'dub',
#   'because',
#   'honoka',
#   's',
#   'voice',
#   'is',
#   'fantastic'],
#  ['i',
#   'bought',
#   'a',
#   'can',
#   'of',
#   'yuzu',
#   'fruit',
#   'juice',
#   'to',
#   'see',
#   'what',
#   'it',
#   'tastes',
#   'like',
#   'it',
#   'tastes',
#   'like',
#   'white',
#   'grape',
#   'juice',
#   'i',
#   'feel',
#   'like',
#   'it',
#   'was',
#   'a',
#   'waste',
#   'of',
#   'an',
#   'experiment'],
#  ['this', 'is', 'some', 'nextlevel', 'meta', 'comfy'],
#  ['what', 'happened', 'to', 'jordy'],
#  ['i',
#   'typed',
#   'up',
#   'new',
#   'subtitles',
#   'for',
#   'episode',
#   '1',
#   'of',
#   'anohana',
#   'first',
#   'time',
#   'and',
#   'it',
#   'took',
#   'almost',
#   'a',
#   'day',
#   'starting',
#   'on',
#   'episode',
#   '2',
#   'over',
#   'the',
#   'weekend'],
#  [],
#  ['what',
#   'about',
#   'noses',
#   'in',
#   'black',
#   'jack',
#   'http',
#   'cdnmyanimelistnetimagescharacters1482769jpg'],
#  ['vote', 'gon', 'that', 'is', 'all'],
#  ['less',
#   'than',
#   'three',
#   'months',
#   'since',
#   'the',
#   'last',
#   'episode',
#   'this',
#   'ca',
#   'nt',
#   'be',
#   'right',
#   'that',
#   's',
#   'too',
#   'soon'],
#  ['darker',
#   'than',
#   'black',
#   'i',
#   'll',
#   'be',
#   'really',
#   'suprised',
#   'if',
#   'someone',
#   'does',
#   'nt',
#   'get',
#   'hyped',
#   'just',
#   'from',
#   'now',
#   'i',
#   've',
#   'lost',
#   'it',
#   'i',
#   'know',
#   'i',
#   'can',
#   'kill',
#   'the',
#   'truth',
#   'exists',
#   'beyond',
#   'the',
#   'gate'],
#  ['1',
#   'his',
#   'meta',
#   'jokes',
#   'are',
#   'hilarious',
#   'every',
#   'time',
#   '2',
#   'fun',
#   'fact',
#   'the',
#   'tone',
#   'when',
#   'the',
#   'green',
#   'light',
#   'shot',
#   'up',
#   'at',
#   'the',
#   'end',
#   'of',
#   'the',
#   'card',
#   'game',
#   'was',
#   'your',
#   'character',
#   'popping',
#   'a',
#   'soul',
#   'item',
#   'in',
#   'dark',
#   'souls'],
#  ['gurren', 'lagann', 'for', 'sure'],
#  ['what', 'is', 'going', 'on', 'with', 'his', 'voice'],
#  ['lovable', 'as', 'always'],
#  ['i',
#   'started',
#   'winter',
#   '2013',
#   'and',
#   'watched',
#   'oreshura',
#   'it',
#   'was',
#   'pretty',
#   'fun',
#   'that',
#   'reminds',
#   'me',
#   'that',
#   'i',
#   'have',
#   'to',
#   'read',
#   'the',
#   'ln',
#   'i',
#   'want',
#   'to',
#   'know',
#   'who',
#   's',
#   'winning',
#   'but',
#   'i',
#   'm',
#   'sure',
#   'it',
#   's',
#   'masuzu'],
#  ['perfect',
#   'cell',
#   's',
#   'va',
#   'is',
#   'fantastic',
#   'and',
#   'i',
#   'need',
#   'him',
#   'to',
#   'say',
#   'more',
#   'things',
#   'now',
#   'please'],
#  ['summer',
#   '2010',
#   'i',
#   'watched',
#   'hyakka',
#   'ryouran',
#   'samurai',
#   'girls',
#   'ookamisan',
#   'to',
#   'shichinin',
#   'no',
#   'nakamura',
#   'seitokia',
#   'yakuindomoi',
#   'i',
#   'feel',
#   'like',
#   'i',
#   'started',
#   'even',
#   'earlier',
#   'than',
#   'this',
#   'with',
#   'kaichou',
#   'wa',
#   'maidsama',
#   'the',
#   'previous',
#   'season',
#   'but',
#   'i',
#   'do',
#   'nt',
#   'know',
#   'that',
#   'for',
#   'sure'],
#  ['this',
#   'ed',
#   'from',
#   'kaminomi',
#   'right',
#   'here',
#   'https',
#   'wwwyoutubecomwatch',
#   'v',
#   'vxinraldqhk',
#   'edit',
#   'spelling'],
#  ['summer', '2014', 'watched', 'free', 'eternal', 'summer', 'love', 'stage'],
#  ['https',
#   'wwwyoutubecomwatch',
#   'v',
#   'fjtxqvevuwy',
#   'if',
#   'you',
#   'want',
#   'a',
#   'prime',
#   'example',
#   'of',
#   'unfitting',
#   'music',
#   'mars',
#   'of',
#   'destruction'],
#  ['in',
#   'spring',
#   '2015',
#   'i',
#   'started',
#   'to',
#   'follow',
#   'what',
#   'was',
#   'currently',
#   'airing',
#   'chances',
#   'are',
#   'high',
#   'that',
#   'i',
#   'watched',
#   'a',
#   'show',
#   'that',
#   'was',
#   'currently',
#   'airing',
#   'prior',
#   'to',
#   'that',
#   'but',
#   'probably',
#   'was',
#   'nt',
#   'aware',
#   'of',
#   'that',
#   'at',
#   'the',
#   'time',
#   'kamisama',
#   'hajimemashita',
#   'kuroko',
#   'no',
#   'basket',
#   '3rd',
#   'season',
#   'plastic',
#   'memories',
#   'may',
#   'or',
#   'may',
#   'not',
#   'started',
#   'it',
#   'right',
#   'after',
#   'it',
#   'stopped',
#   'airing',
#   'shokugeki',
#   'no',
#   'souma',
#   'yamadakun',
#   'to',
#   '7nin',
#   'no',
#   'majo'],
#  ['alnoahzero',
#   'ep',
#   '1',
#   'is',
#   'better',
#   'than',
#   'the',
#   'rest',
#   'of',
#   'the',
#   'show',
#   'combined',
#   'mushroom',
#   'samba',
#   'from',
#   'cowboy',
#   'bebop'],
#  ['tokyo', 'ghoul', 'roota', 's', 'op', 'was', 'awful'],
#  ['goodle',
#   'and',
#   'mewtube',
#   'http',
#   'iimgurcomjsstpjpg',
#   'from',
#   'steins',
#   'gate'],
#  ['illyasviel'],
#  ['macrosoft',
#   'winding',
#   'xo',
#   'http',
#   'images6fanpopcomimagephotos32200000windingangelbeatsanime322649601366768jpg'],
#  ['donquixote', 'rosinante', 'seriously'],
#  ['pizza', 'hut'],
#  ['bokura', 'wa', 'minna', 'kawaisou'],
#  ['lt', 'kore', 'wa', 'zombie', 'desu', 'ka', 'gt', 'eu'],
#  ['grisaia',
#   'series',
#   'with',
#   'yumiko',
#   'as',
#   'the',
#   'frost',
#   'queen',
#   'both',
#   'her',
#   'ark',
#   'in',
#   'kajitsu',
#   'and',
#   'in',
#   'general',
#   'in',
#   'rakuen',
#   'even',
#   'more',
#   'so',
#   'if',
#   'you',
#   'play',
#   'the',
#   'visual',
#   'novel'],
#  ['am',
#   'i',
#   'the',
#   'only',
#   'one',
#   'that',
#   'hates',
#   'nanamin',
#   'mashiro',
#   'is',
#   'bg'],
#  ['so',
#   'many',
#   'shows',
#   'in',
#   'the',
#   'thread',
#   'only',
#   'one',
#   'show',
#   'i',
#   'have',
#   'nt',
#   'seen'],
#  ['mysterious',
#   'girlfriend',
#   'x',
#   'http',
#   'myanimelistnetanime12467nazonokanojox',
#   'has',
#   'quite',
#   'an',
#   'interesting',
#   'kuudere'],
#  ['sinon',
#   'was',
#   'cool',
#   'then',
#   'kirito',
#   's',
#   'and',
#   'sao',
#   'had',
#   'to',
#   'come',
#   'in',
#   'and',
#   'fk',
#   'up',
#   'her',
#   'character'],
#  ['basically',
#   'everyone',
#   'from',
#   'hanamonogatari',
#   'except',
#   'the',
#   'devil',
#   'girl'],
#  ['bunny',
#   'sensei',
#   'http',
#   'iimgurcom1uaiqiojpg',
#   'from',
#   'absolute',
#   'duo',
#   'i',
#   'usually',
#   'enjoy',
#   'the',
#   'generic',
#   'harem',
#   'but',
#   'found',
#   'this',
#   'one',
#   'meh'],
#  ['plastic', 'memories', 'anohana', 'do', 'it'],
#  ['you',
#   'think',
#   'i',
#   'm',
#   'going',
#   'to',
#   'be',
#   'one',
#   'of',
#   'those',
#   'dense',
#   'mcs',
#   'that',
#   'never',
#   'gets',
#   'any',
#   'i',
#   've',
#   'slept',
#   'with',
#   'my',
#   'entire',
#   'harem',
#   'already'],
#  ['gt',
#   'sophistication',
#   'and',
#   'femininity',
#   'are',
#   'not',
#   'related',
#   'at',
#   'all',
#   'neither',
#   'are',
#   'sexuality',
#   'and',
#   'masculinity'],
#  ['i',
#   'actually',
#   'have',
#   'nt',
#   'watched',
#   'the',
#   'second',
#   'season',
#   'yet',
#   'and',
#   'it',
#   's',
#   'been',
#   'about',
#   'a',
#   'year',
#   'and',
#   'a',
#   'half',
#   'since',
#   'i',
#   'watched',
#   'the',
#   'first',
#   'season',
#   'so',
#   'this',
#   'is',
#   'good',
#   'for',
#   'me'],
#  ['finally', 'i', 'am', 'excited'],
#  ['did', 'nt', 'we', 'have', 'one', 'relatively', 'recently'],
#  ['deadpool',
#   'will',
#   'do',
#   'that',
#   'and',
#   'more',
#   'it',
#   'd',
#   'be',
#   'fun',
#   'to',
#   'see',
#   'him',
#   'break',
#   'the',
#   '4th',
#   'wall',
#   'so',
#   'hard',
#   'that',
#   'he',
#   'ends',
#   'up',
#   'in',
#   'actual',
#   'japan',
#   'or',
#   'even',
#   'in',
#   'other',
#   'anime',
#   'entirely'],
#  ['it',
#   's',
#   'supposed',
#   'to',
#   'be',
#   'one',
#   'of',
#   'her',
#   'cute',
#   'character',
#   'quirks'],
#  ['just',
#   'got',
#   'through',
#   'most',
#   'of',
#   'it',
#   'a',
#   'few',
#   'days',
#   'ago',
#   'but',
#   'for',
#   'some',
#   'reason',
#   'i',
#   've',
#   'been',
#   'holding',
#   'off',
#   'the',
#   'last',
#   'episode',
#   'of',
#   'season',
#   'two',
#   'i',
#   'guess',
#   'i',
#   'just',
#   'hate',
#   'that',
#   'there',
#   'will',
#   'likely',
#   'never',
#   'be',
#   'a',
#   'season',
#   'three',
#   'and',
#   'i',
#   'do',
#   'nt',
#   'want',
#   'the',
#   'story',
#   'to',
#   'end',
#   'with',
#   'the',
#   'rewatch',
#   'happening',
#   'i',
#   'guess',
#   'i',
#   'll',
#   'finish',
#   'it',
#   'tonight',
#   'and',
#   'watch',
#   'the',
#   'specials',
# ...
#   'saolog',
#   'horizon',
#   'then',
#   'the',
#   'twist',
#   'comes',
#   'about',
#   'once',
#   'the',
#   'players',
#   'realize',
#   'that',
#   'the',
#   'characters',
#   'they',
#   'are',
#   'playing',
#   'are',
#   'actually',
#   'real',
#   'and',
#   'sentient',
#   'and',
#   'it',
#   's',
#   'up',
#   'to',
#   'their',
#   'choices',
#   'and',
#   'decisions',
#   'to',
#   'save',
#   'them',
#   'lot',
#   'of',
#   'theological',
#   'amp',
#   'philosophical',
#   'questions',
#   'while',
#   'also',
#   'watching',
#   'cute',
#   'girls',
#   'play',
#   'damp',
#   'd'],
#  ['mizore', 'best', 'girl'],
#  ['i',
#   'd',
#   'go',
#   'so',
#   'far',
#   'as',
#   'to',
#   'single',
#   'out',
#   'the',
#   'final',
#   'five',
#   'minutes',
#   'of',
#   'the',
#   'first',
#   'episode',
#   'of',
#   'aldnoah',
#   'zero',
#   'season',
#   '1',
#   'its',
#   'just',
#   'perfect',
#   'and',
#   'i',
#   've',
#   'watched',
#   'it',
#   'multiple',
#   'times',
#   'even',
#   'if',
#   'i',
#   'do',
#   'not',
#   'greatly',
#   'like',
#   'the',
#   'series',
#   'as',
#   'a',
#   'whole'],
#  ['captain', 'earth', 'last', 'episode'],
#  ['what', 'are', 'some', 'good', 'mystery', 'anime'],
#  ['i',
#   'love',
#   'girls',
#   'that',
#   'insult',
#   'the',
#   'main',
#   'character',
#   'with',
#   'a',
#   'straight',
#   'face',
#   'they',
#   're',
#   'always',
#   'the',
#   'best',
#   'girls',
#   'in',
#   'their',
#   'given',
#   'anime',
#   'i',
#   'also',
#   'love',
#   'traps',
#   'they',
#   're',
#   'neither',
#   'male',
#   'nor',
#   'female',
#   'trap',
#   'is',
#   'a',
#   'whole',
#   'other',
#   'gender',
#   'i',
#   'm',
#   'the',
#   'reason',
#   'anime',
#   'was',
#   'a',
#   'mistake'],
#  ['best',
#   'girl',
#   'makes',
#   'me',
#   'happy',
#   'http',
#   'iimgurcomdnzh9fmjpg',
#   'maybe',
#   'she',
#   'll',
#   'be',
#   'animated',
#   'someday',
#   'elsieqq',
#   'other',
#   'anime',
#   'things',
#   'i',
#   'love',
#   '1',
#   'the',
#   'acchi',
#   'kocchi',
#   'op',
#   'https',
#   'wwwyoutubecomwatch',
#   'v',
#   '0bmjtnnsa6y',
#   '1',
#   'final',
#   'scene',
#   'of',
#   'medaka',
#   'box',
#   'abnormal',
#   'https',
#   'wwwyoutubecomwatch',
#   'v',
#   '3rmwobkyiae',
#   '1',
#   'the',
#   'beginner',
#   'insert',
#   'song',
#   'scene',
#   'https',
#   'streamablecomu1qv',
#   'in',
#   'akb0048',
#   '2',
#   'the',
#   'achannel',
#   'ed',
#   'https',
#   'wwwyoutubecomwatch',
#   'v',
#   'lfj4il2qh8',
#   'nonanime',
#   'things',
#   'i',
#   'love',
#   'that',
#   'i',
#   'also',
#   'want',
#   'to',
#   'share',
#   '1',
#   'tfs',
#   's',
#   'drunklstiltskin',
#   'streams',
#   'where',
#   'they',
#   'try',
#   'and',
#   'play',
#   'bloodborne',
#   'and',
#   'drink',
#   'when',
#   'they',
#   'die',
#   'you',
#   'get',
#   'moments',
#   'like',
#   '1',
#   'duel',
#   'of',
#   'the',
#   'drunks',
#   'https',
#   'wwwyoutubecomwatch',
#   'v',
#   'stzk3ksxg18',
#   '2',
#   'bird',
#   'pit',
#   'https',
#   'wwwyoutubecomwatch',
#   'v',
#   'xao3a7omlwkamp',
#   't',
#   '136m35s',
#   '3',
#   'dogs',
#   'and',
#   'doors',
#   'https',
#   'wwwyoutubecomwatch',
#   'v',
#   '49ft439lsl4amp',
#   't',
#   '16m25s',
#   '4',
#   'the',
#   'elevator',
#   'boss',
#   'watch',
#   'this',
#   'one',
#   'for',
#   'a',
#   'while',
#   'it',
#   'just',
#   'gets',
#   'better',
#   'and',
#   'better',
#   'https',
#   'wwwyoutubecomwatch',
#   'v',
#   '0zrooeft8gwamp',
#   't',
#   '125m40s',
#   '2',
#   'ricky',
#   'gervais',
#   'and',
#   'steve',
#   'merchant',
#   'discuss',
#   'polar',
#   'bears',
#   'and',
#   'nighttime',
#   'https',
#   'wwwyoutubecomwatch',
#   'v',
#   'r8wvzeauheamp',
#   't',
#   '10m7s'],
#  ['kisaragi',
#   'chihaya',
#   'http',
#   'staticzerochannetkisaragichihayafull1495321jpg',
#   'chihaya',
#   'singing',
#   'http',
#   '33mediatumblrcom73689550908fc0f5cf5b2196b40a303ftumblrncc58pjefp1s4qvrdo1500gif',
#   'chihaya',
#   'badass',
#   'http',
#   'pa1narviicom566679015a133badba46e68c61d76d719ebb25477a59hqgif',
#   'chihaya',
#   'gaming',
#   'http',
#   '38mediatumblrcome8bb0f17f565d4d3259bfaf9bf30f853tumblrn7p6ta3ils1rifd3ao1250gif',
#   'chihaya',
#   'drinking',
#   'https',
#   'uboachannetotsrc1404236701828png',
#   'edit',
#   'the',
#   'idolm',
#   'ster',
#   'spoilers',
#   'yakusoku',
#   'https',
#   'mymixtapemoegzwdxfwebm'],
#  ['holo', 'and', 'winter', 'http', 'iimgurcomrs9w2ujjpg'],
#  ['steins', 'gate', 'http', 'staticzerochannetsteins', '3bgatefull513912jpg'],
#  ['haruhi',
#   'and',
#   'nagato',
#   'rocking',
#   'out',
#   'with',
#   'god',
#   'knows',
#   'https',
#   'youtubewwb01iumvza'],
#  ['the', 'best', 'nnb', 'character', 'http', 'imgurcomgmcjbgp'],
#  ['a', 'certain', 'tiger'],
#  ['naruto', 'and', 'really', 'original', 'anime', 'ideas', 'like', 'rakugo'],
#  ['do',
#   'nt',
#   'really',
#   'know',
#   'what',
#   'it',
#   's',
#   'called',
#   'but',
#   'i',
#   'love',
#   'the',
#   'cutesmall',
#   'characters',
#   'being',
#   'stronger',
#   'then',
#   'they',
#   'look',
#   'to',
#   'be',
#   'ex',
#   'shiro',
#   'http',
#   'myanimelistnetcharacter82525shiro',
#   'chamo',
#   'http',
#   'myanimelistnetcharacter88653chamorosso',
#   'koneko',
#   'http',
#   'myanimelistnetcharacter51343konekotoujou',
#   'there',
#   's',
#   'other',
#   'better',
#   'examples',
#   'even',
#   'some',
#   'males',
#   'i',
#   'just',
#   'have',
#   'bad',
#   'memory',
#   'and',
#   'the',
#   'above',
#   'are',
#   'the',
#   'only',
#   'ones',
#   'on',
#   'my',
#   'mal',
#   'another',
#   'would',
#   'be',
#   'the',
#   'female',
#   'dressingacting',
#   'male',
#   'for',
#   'reasons',
#   'ex',
#   'yukimura',
#   'http',
#   'myanimelistnetcharacter38941yukimurakusunoki',
#   'konoe',
#   'http',
#   'myanimelistnetcharacter41374subarukonoe',
#   'tsugumi',
#   'http',
#   'myanimelistnetcharacter58885seishiroutsugumi'],
#  ['moe', 'lt', '3', 'https', 'wwwyoutubecomwatch', 'v', '2ac7gnuuy80'],
#  ['random',
#   'stuff',
#   'f',
#   'https',
#   'wwwredditcomranimecomments3pzb6fspoilerwhatflclmeansforme',
#   'l',
#   'https',
#   'wwwyoutubecomwatch',
#   'v',
#   'umutbscxux8',
#   'c',
#   'https',
#   'wwwyoutubecomwatch',
#   'v',
#   'g6nxzbvt0oo',
#   'l',
#   'https',
#   'wwwyoutubecomwatch',
#   'v',
#   'vxqgnxlgona',
#   'lt',
#   'spoilers',
#   'in',
#   'every',
#   'link',
#   'except',
#   'for',
#   'the',
#   'third',
#   'hiroyuki',
#   'imaishi',
#   's',
#   'animation',
#   'https',
#   'wwwyoutubecomwatch',
#   'v',
#   'scnfi4p8uc0',
#   'lt',
#   'expect',
#   'spoilers',
#   'for',
#   'various',
#   'series',
#   'this',
#   'ttgl',
#   'review',
#   'http',
#   'myanimelistnetreviewsphp',
#   'id',
#   '207124',
#   'heats',
#   'https',
#   'wwwyoutubecomwatch',
#   'v',
#   'ehoptvbfpgm',
#   'some',
#   'of',
#   'watanabe',
#   'keisuke',
#   's',
#   'animation',
#   'https',
#   'wwwyoutubecomwatch',
#   'v',
#   'xsf3qibkbssamp',
#   't',
#   '1m43s',
#   'lt',
#   'expect',
#   'spoilers',
#   'for',
#   'various',
#   'series',
#   'ngebohemian',
#   'rhapsody',
#   'spoilers',
#   'https',
#   'wwwyoutubecomwatch',
#   'v',
#   'ryjv3amydme',
#   'memetic',
#   'developments',
#   'infernocopu',
#   'the',
#   'amazing',
#   'garzey',
#   's',
#   'wing',
#   'dub',
#   'https',
#   'wwwyoutubecomwatch',
#   'v',
#   'nwru5o07ji',
#   'porn',
#   'sakamoto',
#   's',
#   'character',
#   'song',
#   'https',
#   'wwwyoutubecomwatch',
#   'v',
#   'dmtdllzhduw',
#   'baccano',
#   's',
#   'theme',
#   'https',
#   'wwwyoutubecomwatch',
#   'v',
#   'si76ws6tlks',
#   'this',
#   'fucking',
#   'ed',
#   'https',
#   'wwwyoutubecomwatch',
#   'v',
#   'lfuwtqbam28',
#   'ranime',
#   's',
#   'lm',
#   'a',
#   's',
#   'o'],
#  ['erased', 'meets', 'steins', 'gate', 'meets', 'shoujo'],
#  ['wow',
#   'this',
#   'is',
#   'great',
#   'i',
#   'never',
#   'finished',
#   'the',
#   'manga',
#   'i',
#   'think',
#   'it',
#   'was',
#   'nt',
#   'finished',
#   'yet',
#   'when',
#   'i',
#   'was',
#   'reading',
#   'it',
#   'but',
#   'i',
#   'm',
#   'super',
#   'excited',
#   'for',
#   'this'],
#  ['o',
#   'r',
#   'a',
#   'n',
#   'g',
#   'e',
#   'r',
#   'a',
#   'n',
#   'g',
#   'e',
#   'h',
#   'y',
#   'p',
#   'e',
#   'y',
#   'p',
#   'e'],
#  ['i', 'm', 'ready', 'to', 'cry', 'my', 'fucking', 'eyes', 'out'],
#  ['now', 'i', 'can', 'die', 'in', 'peace'],
#  ['holy',
#   'shit',
#   'yes',
#   'this',
#   'manga',
#   'is',
#   'to',
#   'good',
#   'to',
#   'not',
#   'get',
#   'a',
#   'anime'],
#  ['savinganimeexe'],
#  ['hype',
#   'i',
#   'thought',
#   'it',
#   'would',
#   'never',
#   'happen',
#   'considering',
#   'there',
#   'was',
#   'a',
#   'live',
#   'action',
#   'adaptation',
#   'released',
#   'already'],
#  ['it', 's', 'about', 'time', 'orangekun', 'got', 'his', 'own', 'anime'],
#  ['get', 'ready', 'for', 'feel', 'train'],
#  ['isnt',
#   'this',
#   'higher',
#   'ranked',
#   'than',
#   'boku',
#   'dake',
#   's',
#   'manga',
#   'seems',
#   'like',
#   'another',
#   'challenger',
#   'for',
#   'mal',
#   's',
#   '1',
#   'throne',
#   'has',
#   'appeared',
#   'the',
#   'only',
#   'question',
#   'is',
#   'how',
#   'well',
#   'this',
#   'candidate',
#   'fares'],
#  ['hype',
#   'is',
#   'real',
#   'i',
#   'was',
#   'hoping',
#   'this',
#   'would',
#   'get',
#   'an',
#   'adaption'],
#  ['yaaay',
#   'lt',
#   '3',
#   'omfg',
#   'i',
#   'ca',
#   'nt',
#   'believe',
#   'this',
#   'is',
#   'happening',
#   'i',
#   'm',
#   'about',
#   'to',
#   'cry',
#   'tttt',
#   'orange',
#   'manga',
#   'is',
#   'being',
#   'adapted',
#   'd'],
#  ['orange', 'boy', 'has', 'arrived', 'loyalty', 'or', 'death'],
#  ['time', 'travel', 'udastales', 'will', 'hate', 'it'],
#  ['did',
#   'anyone',
#   'see',
#   'the',
#   'live',
#   'action',
#   'film',
#   'for',
#   'this',
#   'was',
#   'it',
#   'any',
#   'good',
#   'and',
#   'how',
#   'much',
#   'of',
#   'the',
#   'manga',
#   'did',
#   'it',
#   'cover'],
#  ['oreun', 'ji', 'no', 'ni', 'hayaku'],
#  ['what', 'is', 'this', 'anime', 'even', 'about'],
#  ['sypnosis', 'sounds', 'interesting'],
#  ['i',
#   'just',
#   'bought',
#   'the',
#   'first',
#   'volume',
#   'from',
#   'japan',
#   'that',
#   '3',
#   'year',
#   'hiatus',
#   'was',
#   'the',
#   'death',
#   'of',
#   'me'],
#  ['it',
#   's',
#   'one',
#   'of',
#   'my',
#   '1010s',
#   'too',
#   'and',
#   'i',
#   'think',
#   'the',
#   'biggest',
#   'difference',
#   'for',
#   'why',
#   'i',
#   'loved',
#   'it',
#   'when',
#   'cowboy',
#   'bebop',
#   'was',
#   'so',
#   'mediocre',
#   'to',
#   'me',
#   'is',
#   'because',
#   'while',
#   'they',
#   're',
#   'both',
#   'extremely',
#   'episodic',
#   'to',
#   'the',
#   'point',
#   'where',
#   'some',
#   'episodes',
#   'leave',
#   '0',
#   'consequenceszombies',
#   'for',
#   'the',
#   'next',
#   'one',
#   'samurai',
#   'champloo',
#   'at',
#   'least',
#   'had',
#   'this',
#   'meandering',
#   'direction',
#   'to',
#   'it',
#   'which',
#   'kept',
#   'me',
#   'invested',
#   'spike',
#   'is',
#   'a',
#   'great',
#   'character',
#   'but',
#   'it',
#   'took',
#   'me',
#   'forever',
#   'to',
#   'complete',
#   'the',
#   'show',
#   'because',
#   'i',
#   'just',
#   'did',
#   'nt',
#   'care',
#   'about',
#   'the',
#   'situations',
#   'he',
#   'was',
#   'placed',
#   'in'],
#  ['champloo',
#   'is',
#   'also',
#   'one',
#   'of',
#   'my',
#   '1010s',
#   'and',
#   'in',
#   'my',
#   'top',
#   '3',
#   'shows',
#   'ever',
#   'it',
#   'just',
#   'did',
#   'everything',
#   'so',
#   'right'],
#  ['this',
#   'might',
#   'be',
#   'interesting',
#   'to',
#   'you',
#   'https',
#   'wikipuellamaginetmathematicsofmadokamagica'],
#  ['does',
#   'this',
#   'count',
#   'paranoia',
#   'agent',
#   'https',
#   'wwwyoutubecomwatch',
#   'v',
#   's94zvlhnyha'],
#  ['i',
#   've',
#   'been',
#   'trying',
#   'to',
#   'look',
#   'for',
#   'this',
#   'anime',
#   'for',
#   'a',
#   'while',
#   'now',
#   'and',
#   'i',
#   've',
#   'come',
#   'across',
#   'nothing',
#   'even',
#   'when',
#   'i',
#   'try',
#   'and',
#   'search',
#   'for',
#   'it',
#   'in',
#   'japanese',
#   'all',
#   'that',
#   'seems',
#   'to',
#   'exist',
#   'of',
#   'this',
#   'is',
#   'the',
#   'page',
#   'on',
#   'mal',
#   'that',
#   'has',
#   'been',
#   'created',
#   'http',
#   'myanimelistnetanime22055gakkounokaidanrecaps',
#   'anyone',
#   'have',
#   'any',
#   'idea',
#   'of',
#   'its',
#   'existence',
#   'or',
#   'is',
#   'this',
#   'a',
#   'made',
#   'up',
#   'title'],
#  ['after',
#   'finishing',
#   'part',
#   '4',
#   'i',
#   'now',
#   'realize',
#   'why',
#   'part',
#   '4',
#   'stand',
#   'name',
#   's',
#   'super',
#   'fly',
#   'had',
#   'that',
#   'name'],
#  ['woot', 'its', 'happening'],
#  ['roy',
#   'and',
#   'riza',
#   'spoilers',
#   'for',
#   'fma',
#   'brotherhood',
#   'i',
#   'guess',
#   'http',
#   'imgurcomzvxthzi'],
#  ['these',
#   'were',
#   'made',
#   'on',
#   'a',
#   'a',
#   'few',
#   'years',
#   'ago',
#   'gaijinkun',
#   'http',
#   'imgurcomaskpmf',
#   'it',
#   's',
#   'about',
#   'an',
#   'american',
#   'exchange',
#   'student',
#   'who',
#   'comes',
#   'to',
#   'japan',
#   'does',
#   'it',
#   'even',
#   'need',
#   'any',
#   'pitching'],
#  ['the',
#   'whole',
#   'thing',
#   'with',
#   'amuro',
#   'and',
#   'char',
#   'this',
#   'episode',
#   'was',
#   'a',
#   'little',
#   'confusing',
#   'i',
#   'do',
#   'nt',
#   'really',
#   'see',
#   'what',
#   'the',
#   'encounter',
#   'was',
#   'trying',
#   'to',
#   'accomplish',
#   'i',
#   'really',
#   'loved',
#   'when',
#   'char',
#   'blew',
#   'up',
#   'the',
#   'last',
#   'zabi',
#   'for',
#   'garma',
#   'heh',
#   'rip',
#   'white',
#   'base',
#   'the',
#   'kids',
#   'lt',
#   '333',
#   'i',
#   'love',
#   'those',
#   'little',
#   'rascals',
#   'it',
#   'was',
#   'a',
#   'fun',
#   'ride',
#   'watching',
#   'the',
#   'series',
#   'with',
#   'all',
#   'the',
#   'participants',
#   'it',
#   'did',
#   'nt',
#   'end',
#   'as',
#   'expected',
#   'but',
#   'it',
#   'was',
#   'still',
#   'a',
#   'satisfying',
#   'ending',
#   'looking',
#   'forward',
#   'to',
#   'the',
#   'rest',
#   'of',
#   'the',
#   'rewatch'],
#  ['what',
#   'if',
#   'you',
#   'took',
#   'all',
#   'of',
#   'the',
#   'good',
#   'standout',
#   'characters',
#   'from',
#   'otherwise',
#   'bad',
#   'shows',
#   'and',
#   'put',
#   'them',
#   'into',
#   'their',
#   'own',
#   'show',
#   'what',
#   'would',
#   'happen'],
#  ['what', 'tripleq', 'got', 'axed', 'when', 'did', 'this', 'happen', 'what'],
#  ['now', 'do', 'one', 'with', 'his', 'goofy', 'face'],
#  ['are', 'you', 'same', 'person', 'that', 'did', 'the', 'tf2', 'busts'],
#  ['one',
#   'of',
#   'my',
#   'favorite',
#   'shows',
#   'ever',
#   'just',
#   'wait',
#   'till',
#   'episode',
#   '4',
#   'of',
#   'the',
#   'repeat',
#   'the',
#   'repeat',
#   'in',
#   'general',
#   'is',
#   'even',
#   'better',
#   'than',
#   'the',
#   'original',
#   'series'],
#  ['yeah',
#   'i',
#   'really',
#   'liked',
#   'that',
#   'anime',
#   'i',
#   'never',
#   'watched',
#   'repeat',
#   'though'],
#  ['well', 'unzips'],
#  ['a', 'news', 'app', 'http', 'myanimelistnetanime30721hackadolltheanimation'],
#  ['wow',
#   'this',
#   'amv',
#   'is',
#   'amazing',
#   'the',
#   'sync',
#   'is',
#   'on',
#   'point',
#   'and',
#   'the',
#   'ending',
#   'is',
#   'exuberating'],
#  ['that', 'was', 'awesome'],
#  ['let',
#   's',
#   'get',
#   'the',
#   'monogatari',
#   'hype',
#   'train',
#   'on',
#   'the',
#   'road'],
#  ['can',
#   'someone',
#   'who',
#   's',
#   'seen',
#   'terra',
#   'etowards',
#   'the',
#   'terra',
#   'give',
#   'me',
#   'their',
#   'opinion',
#   'on',
#   'it'],
#  ['at', 'least', 'steampunkish', 'or', 'steampunk', 'influenced', 'also'],
#  ['http', 'iimgurcom4yfewbapng'],
#  ['could',
#   'valkyrie',
#   'chronicles',
#   'count',
#   'it',
#   's',
#   'more',
#   'of',
#   'an',
#   'alternate',
#   'ww1'],
#  ['this',
#   'was',
#   'posted',
#   'over',
#   'at',
#   'rstarvstheforcesofevil',
#   'and',
#   'i',
#   'thought',
#   'ranime',
#   'might',
#   'like',
#   'it',
#   'link',
#   'http',
#   'illeitydeviantartcomarthappyvalentinesdaystarbutterfly591063220'],
#  [],
#  ['amazing',
#   'article',
#   'a',
#   'lot',
#   'of',
#   'the',
#   'points',
#   'are',
#   'the',
#   'reasons',
#   'why',
#   'i',
#   'love',
#   'one',
#   'piece',
#   'so',
#   'much'],
#  ['i',
#   'was',
#   'in',
#   'a',
#   'skype',
#   'call',
#   'with',
#   'a',
#   'few',
#   'friends',
#   'whilst',
#   'applying',
#   'for',
#   'jobs',
#   'and',
#   'one',
#   'of',
#   'the',
#   'questions',
#   'in',
#   'the',
#   'application',
#   'was',
#   'asking',
#   'about',
#   'fluency',
#   'in',
#   'other',
#   'languages',
#   'i',
#   'then',
#   'proceeded',
#   'to',
#   'proclaim',
#   'to',
#   'my',
#   'friends',
#   'that',
#   'i',
#   'was',
#   'fluent',
#   'in',
#   'japanese',
#   'because',
#   'i',
#   'watch',
#   'anime',
#   'i',
#   'outweebed',
#   'myself',
#   'that',
#   'day'],
#  ['i',
#   'do',
#   'nt',
#   'know',
#   'if',
#   'this',
#   'counts',
#   'but',
#   'i',
#   'was',
#   'really',
#   'thinking',
#   'about',
#   'buying',
#   'the',
#   'lelouch',
#   'figure',
#   'for',
#   'either',
#   '200',
#   'or',
#   '350',
#   'it',
#   's',
#   'way',
#   'too',
#   'much',
#   'money',
#   'for',
#   'a',
#   'plastic',
#   'figure',
#   'and',
#   'i',
#   've',
#   'never',
#   'bought',
#   'anything',
#   'like',
#   'that',
#   'before',
#   'but',
#   'it',
#   'looks',
#   'so',
#   'damn',
#   'good'],
#  ['you',
#   'mean',
#   'besides',
#   'singing',
#   'all',
#   'the',
#   'jojo',
#   'openings',
#   'while',
#   'washing',
#   'dishes',
#   'and',
#   'doing',
#   'jojo',
#   'poses',
#   'every',
#   'chance',
#   'i',
#   'get'],
#  ['buy', 'a', 'santa', 'super', 'sonico', 'figure', 'no', 'ragrets'],
#  ['made', 'a', 'magical', 'girl', 'team', 'in', 'xcom', '2', 'i', 'guess'],
#  ...]

# %%
print corpus
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
import re
def tokenise():
    input_file = open("anime.txt","r")
    file_content=input_file.readlines()
    corpus=[]

    for line in file_content:
        regex = re.compile('[a-zA-Z0-9]+')
        #regex = re.compile("http[s]?[\s]?:[\s]?//[a-zA-Z0-9/\.]+")
        line=re.sub('[^a-zA-Z0-9 ]', '', line)
        tokens=regex.findall(line)
        corpus.append(tokens)
    input_file.close()
    #print corpus
    return corpus

def sort_dict(d):
    return sorted(d.items(), key = lambda x : x[1], reverse = True)

def get_unigrams(corpus):
    unigrams = {}
    for sentence in corpus:
        for word in sentence:
            if word not in unigrams:
                unigrams[word] = 0
            unigrams[word] += 1
    unigrams_prob = {}
    N = sum(unigrams.values())
    for word in unigrams:
        unigrams_prob[word] = round( (unigrams[word]) / float(N), 15)
    #print unigrams
    return unigrams,unigrams_prob

def get_bigrams(corpus,unigrams):
    bigrams = {}
    for sentence in corpus:
        for index, word in enumerate(sentence):
            if index > 0:
                pair  = (sentence[index - 1], word)
                if pair not in bigrams:
                    bigrams[pair] =0
                bigrams[pair] += 1
    bigrams_prob={}
    for pair in bigrams:
        #print bigrams[pair],unigrams[pair[0]]
        bigrams_prob[pair] = round( (bigrams[pair]) / float(unigrams[pair[0]]),  15)
    #print bigrams
    return bigrams,bigrams_prob

def get_trigrams(corpus, bigrams):
    trigrams = {}
    for sentence in corpus:
        for index, word in enumerate(sentence):
            if index > 1:
                pair  = (sentence[index - 2],sentence[index - 1], word)
                if pair not in trigrams:
                    trigrams[pair] =0
                trigrams[pair] += 1
    trigrams_prob={}
    for pair in trigrams:
        trigrams_prob[pair] = round((trigrams[pair]) / float( bigrams[( pair[0],pair[1]) ] ), 15)
    #print "trigrams_prob->",sum(trigrams_prob.values())
    return trigrams,trigrams_prob

def get_laplace_unigrams(unigrams,V):
    laplace_unigrams_prob = {}
    N = sum(unigrams.values())
    for word in unigrams:
        laplace_unigrams_prob[word] = round((unigrams[word] + 1)/ float(N+V), 15)
        #new_unigrams[word] = math.log((unigrams[word] + 1)/ float(N+V))
    #print "laplace_unigrams_prob->",sum(laplace_unigrams_prob.values())
    return laplace_unigrams_prob


def get_laplace_bigrams(unigrams,bigrams,V):
    laplace_bigrams_prob = {}
    N = sum(unigrams.values())
    for word1 in unigrams:
        for word2 in unigrams:
            pair=(word1,word2)
            if pair not in bigrams:
                laplace_bigrams_prob[pair] = round( (1) / float(unigrams[word1]+V), 15)
            else:
                laplace_bigrams_prob[pair] = round((bigrams[pair] + 1)/ float(unigrams[word1]+V), 15)
                #new_unigrams[word] = math.log((unigrams[word] + 1)/ float(N+V))
    #print laplace_bigrams_prob
    return laplace_bigrams_prob

def get_laplace_trigrams(unigrams,bigrams,trigrams,V):
    laplace_trigrams_prob = {}
    N = sum(unigrams.values())
    for word1 in unigrams:
        for word2 in unigrams:
            for word3 in unigrams:
                pair=(word1,word2,word3)
                pairi=(word1,word2)
                if pairi in bigrams:
                    var=bigrams[pairi]
                else:
                    var=0
                if pair not in trigrams:
                    laplace_trigrams_prob[pair] = round( (1) / float(var+V), 15)
                else:
                    laplace_trigrams_prob[pair] = round((trigrams[pair] + 1)/ float(var+V), 15)
                    #new_unigrams[word] = math.log((unigrams[word] + 1)/ float(N+V))
    #print laplace_trigrams_prob
    return laplace_trigrams_prob

def get_wittenbell_unigrams(unigrams,unigrams_prob,V):
    wittenbell_unigrams_prob = {}
    N = sum(unigrams.values())
    T = len(unigrams.keys())
    for word in unigrams:
        var= (N/float(N+T))
        wittenbell_unigrams_prob[word] = (var * unigrams_prob[word]) + (1-var)/V
        wittenbell_unigrams_prob[word] = round(wittenbell_unigrams_prob[word], 15)
    #print sum(wittenbell_unigrams_prob.values()),wittenbell_unigrams_prob
    return wittenbell_unigrams_prob

def get_wittenbell_bigrams_variables(bigrams,word):
    distinct_1_in_1_bigrams=0
    total_1_in_1_bigrams=0
    for pair in bigrams:
        if word==pair[0]:
            distinct_1_in_1_bigrams+=1
            total_1_in_1_bigrams+=bigrams[pair]
    return distinct_1_in_1_bigrams,total_1_in_1_bigrams

def get_wittenbell_bigrams(unigrams,bigrams,unigrams_prob,wittenbell_unigrams_prob):
    wittenbell_bigrams_prob = {}
    n = len(unigrams)**2

    for word1 in unigrams:
        for word2 in unigrams:
            n-=1
            print n,'\r',
            
            pair=(word1,word2)
            distinct_1_in_1_bigrams,total_1_in_1_bigrams = get_wittenbell_bigrams_variables(bigrams,pair[0])
            if distinct_1_in_1_bigrams!=0:
                x=round(distinct_1_in_1_bigrams/float(distinct_1_in_1_bigrams+total_1_in_1_bigrams), 15)
                if pair in bigrams:
                    wittenbell_bigrams_prob[pair] = (1-x) * bigrams_prob[pair] + x * wittenbell_unigrams_prob[pair[0]]
                else:
                    wittenbell_bigrams_prob[pair] =  x * wittenbell_unigrams_prob[pair[0]]
            else:
                wittenbell_bigrams_prob[pair] = wittenbell_unigrams_prob[pair[0]]

    #print wittenbell_bigrams_prob
    return wittenbell_bigrams_prob

def get_wittenbell_trigrams_variables(trigrams,word):
    distinct_1_2_trigrams=0
    total_1_2_trigrams=0
    for pair in trigrams:
        if word[0]==pair[0] and word[1]==pair[1]:
            distinct_1_2_trigrams+=1
            total_1_2_trigrams+=trigrams[pair]
    return distinct_1_2_trigrams,total_1_2_trigrams


def get_wittenbell_trigrams(unigrams,trigrams,trigrams_prob,wittenbell_bigrams_prob):
    wittenbell_trigrams_prob = {}
    for word1 in unigrams:
        for word2 in unigrams:
            for word3 in unigrams:
                pair=(word1,word2,word3)
                pairi=(word1,word2)
                distinct_1_2_trigrams,total_1_2_trigrams = get_wittenbell_trigrams_variables(trigrams,pair)
                if distinct_1_2_trigrams!=0:
                    x=round(distinct_1_2_trigrams/float(distinct_1_2_trigrams+total_1_2_trigrams), 15)
                    if pair in trigrams:
                        wittenbell_trigrams_prob[pair] = (1-x) * trigrams_prob[pair] + x * wittenbell_bigrams_prob[pairi]
                    else:
                        wittenbell_trigrams_prob[pair]= x * wittenbell_bigrams_prob[pairi]
                else:
                    wittenbell_trigrams_prob[pair]=wittenbell_bigrams_prob[pairi]

    #print wittenbell_trigrams_prob
    return wittenbell_trigrams_prob

def get_kn_unigrams(unigrams,V):
    kn_unigrams_prob={}
    d=0.75
    N=sum(unigrams.values())
    for word in unigrams:
        kn_unigrams_prob[word] = (max(unigrams[word]-d, 0)/float(N)) + (d/float(V)) * ()


def get_kn_bigrams_variables(bigrams,pair):
    bigrams_with_first_term=0
    bigrams_with_last_term=0
    for words in bigrams:
        if words[0]==pair[0]:
            bigrams_with_first_term+=1
        if words[1]==pair[1]:
            bigrams_with_last_term+=1
    return bigrams_with_first_term,bigrams_with_last_term

def get_kn_bigrams(unigrams,bigrams):
    kn_bigrams_prob={}
    d=0.75
    total_bigrams=len(bigrams.keys())
    for word1 in unigrams:
        for word2 in unigrams:
            pair = (word1,word2)
            bigrams_with_first_term,bigrams_with_last_term=get_kn_bigrams_variables(bigrams,pair)
            if pair in bigrams:
                kn_bigrams_prob[pair]= ( max(bigrams[pair]-d,0) / float(unigrams[pair[0]]) ) + d * (bigrams_with_first_term/float(unigrams[pair[0]]) ) * ( bigrams_with_last_term/float(total_bigrams))
            else:
                kn_bigrams_prob[pair]= d * ( bigrams_with_first_term/float(unigrams[pair[0]]) )*( bigrams_with_last_term/float(total_bigrams))
            kn_bigrams_prob[pair] = round(kn_bigrams_prob[pair], 15)
    kn_bigrams_prob=sort_dict(kn_bigrams_prob)
    print kn_bigrams_prob
    return kn_bigrams_prob

def get_kn_trigrams_variables(bigrams,trigrams,pair):
    trigrams_1_2_term=0
    trigrams_2_3_term=0
    trigrams_2_term=0
    bigrams_2_in_1_term=0
    bigrams_3_in_2_term=0
    for words in trigrams:
        if words[0]==pair[0] and words[1]==pair[1]:
            trigrams_1_2_term+=1
        if words[1]==pair[1] and words[2]==pair[2]:
            trigrams_2_3_term+=1
        if words[1]==pair[1]:
            trigrams_2_term+=1
    for words in bigrams:
        if words[0]==pair[1]:
            bigrams_2_in_1_term+=1
        if words[1]==pair[2]:
            bigrams_3_in_2_term+=1
    return trigrams_1_2_term,trigrams_2_3_term,trigrams_2_term,bigrams_2_in_1_term,bigrams_3_in_2_term


def get_kn_trigrams(unigrams,bigrams,trigrams):
    kn_trigrams_prob={}
    d=0.75
    total_bigrams=len(bigrams.keys())
    for word1 in unigrams:
        for word2 in unigrams:
            for word3 in unigrams:
                pair = (word1,word2,word3)
                pairi= (word1,word2)
                trigrams_1_2_term,trigrams_2_3_term,trigrams_2_term,bigrams_2_in_1_term,bigrams_3_in_2_term=get_kn_trigrams_variables(bigrams,trigrams,pair)
                if pair in trigrams:
                    var = max(trigrams[pair]-d,0)
                else:
                    var=0
                kn_trigrams_prob[pair]= ( var / float(bigrams[pairi]) ) + d*(trigrams_1_2_term/float(bigrams[pairi]) )*( ( max(trigrams_2_3_term-d,0)/float(trigrams_2_term) ) + d * (bigrams_2_in_1_term/float(trigrams_2_term))*(bigrams_3_in_2_term/float(total_bigrams)) )
                kn_trigrams_prob[pair] = round(kn_trigrams_prob[pair], 15)
    kn_trigrams_prob=sort_dict(kn_trigrams_prob)
    print kn_trigrams_prob
    return kn_trigrams_prob

# %%
corpus=tokenise()

# %%
unigrams,unigrams_prob=get_unigrams(corpus)

# %%
laplace_unigrams_prob = get_laplace_unigrams(unigrams,200)
wittenbell_unigrams_prob = get_wittenbell_unigrams(unigrams,unigrams_prob,200)

# %%
bigrams,bigrams_prob = get_bigrams(corpus,unigrams)

# %%
laplace_bigrams_prob = get_laplace_bigrams(unigrams,bigrams,200)

# %%
wittenbell_bigrams_prob = get_wittenbell_bigrams(unigrams,bigrams,unigrams_prob,wittenbell_unigrams_prob)
# Out:
# 14587001
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-a3d570c10908> in <module>()
# ----> 1 wittenbell_bigrams_prob = get_wittenbell_bigrams(unigrams,bigrams,unigrams_prob,wittenbell_unigrams_prob)
#
# <ipython-input-16-1e8f41e16a26> in get_wittenbell_bigrams(unigrams, bigrams, unigrams_prob, wittenbell_unigrams_prob)
#     137
#     138             pair=(word1,word2)
# --> 139             distinct_1_in_1_bigrams,total_1_in_1_bigrams = get_wittenbell_bigrams_variables(bigrams,pair[0])
#     140             if distinct_1_in_1_bigrams!=0:
#     141                 x=round(distinct_1_in_1_bigrams/float(distinct_1_in_1_bigrams+total_1_in_1_bigrams), 15)
#
# <ipython-input-16-1e8f41e16a26> in get_wittenbell_bigrams_variables(bigrams, word)
#     121     distinct_1_in_1_bigrams=0
#     122     total_1_in_1_bigrams=0
# --> 123     for pair in bigrams:
#     124         if word==pair[0]:
#     125             distinct_1_in_1_bigrams+=1
#
# KeyboardInterrupt:

# %%
import re
import matplotlib.pyplot as plt
import math
import random
corpus2=[]
unigrams2={}
bigrams2={}
laplace_unigrams_prob2={}
trigrams2={}
def tokenise(file):
    corpus=[]
    input_file = open(file,"r")
    #input_file = open("movies.txt","r")
    #input_file = open("news.txt","r")
    file_content=input_file.readlines()
    
    for line in file_content:
        
        #regex = re.compile("http[s]?[\s]?:[\s]?//[a-zA-Z0-9/\.]+")
        line=re.sub('[^a-zA-Z0-9 ]', '', line)
        regex = re.compile('[a-zA-Z0-9]+')
        tokens=regex.findall(line)
        corpus2.append(tokens)
        corpus.append(tokens)
    printvalues(corpus)
    input_file.close()
    #print corpus
    return corpus
def printvalues(value):
    # print value
    pass
def sort_dict(d):
    return sorted(d.items(), key = lambda x : x[1], reverse = True)

def get_unigrams(corpus):
    printvalues(corpus)
    unigrams = {}
    for sentence in corpus:
        for word in sentence:
            printvalues(word)
            if word not in unigrams:
                unigrams[word] = 0
                unigrams2[word] = 0
                printvalues(word)
            unigrams[word] += 1
            unigrams2[word] += 1
        printvalues(sentence)

    unigrams_prob = {}
    N = sum(unigrams.values())
    for word in unigrams:
        unigrams_prob[word] = round( (unigrams[word]) / float(N), 15)
        printvalues(unigrams_prob[word])
    printvalues(sort_dict(unigrams))
    #plot(sort_dict(unigrams_prob))
    #plot_log_log1(sort_dict(unigrams_prob))
    return unigrams,unigrams_prob

def get_bigrams(corpus,unigrams):
    bigrams = {}
    for sentence in corpus:
        printvalues(sentence)
        for index, word in enumerate(sentence):
            if index > 0:
                pair  = (sentence[index - 1], word)
                printvalues(pair)
                if pair not in bigrams:
                    printvalues(pair)
                    bigrams[pair] =0
                    bigrams2[pair] =0
                bigrams[pair] += 1
                bigrams2[pair] +=1
                printvalues(pair)
    bigrams_prob={}
    for pair in bigrams:
        bigrams_prob[pair] = round( (bigrams[pair]) / float(unigrams[pair[0]]),  15)
    printvalues(sort_dict(bigrams))
    #plot(sort_dict(bigrams_prob))
    #plot_log_log(sort_dict(bigrams_prob))
    return bigrams,bigrams_prob

def get_trigrams(corpus, bigrams):
    trigrams = {}
    for sentence in corpus:
        printvalues(sentence)
        for index, word in enumerate(sentence):
            if index > 1:
                pair  = (sentence[index - 2],sentence[index - 1], word)
                printvalues(pair)
                if pair not in trigrams:
                    trigrams[pair] =0
                    trigrams2[pair]=0
                trigrams[pair] += 1
                trigrams2[pair] +=1
                printvalues(trigrams2[pair])
    trigrams_prob={}
    for pair in trigrams:
        bigrampair = float( bigrams[( pair[0],pair[1]) ] )
        trigrams_prob[pair] = round((trigrams[pair]) / bigrampair, 15)

        printvalues(trigrams_prob[pair])
    #print sort_dict(trigrams_prob)
    #plot(sort_dict(trigrams_prob))
    #plot_log_log(sort_dict(trigrams_prob))
    return trigrams,trigrams_prob

def get_laplace_unigrams(unigrams,V):
    laplace_unigrams_prob = {}

    N = sum(unigrams.values())
    printvalues(N)
    for word in unigrams:
        laplace_unigrams_prob[word] = (unigrams[word] + 1)/ float(N+V)
        laplace_unigrams_prob[word] = round(laplace_unigrams_prob[word], 15)
        printvalues(laplace_unigrams_prob[word])
    printvalues(sort_dict(laplace_unigrams_prob))
    #plot(sort_dict(laplace_unigrams_prob))
    #plot_log_log(sort_dict(laplace_unigrams_prob))
    return laplace_unigrams_prob


def get_laplace_bigrams(unigrams,bigrams,V):
    laplace_bigrams_prob = {}
    N = sum(unigrams.values())
    printvalues(N)
    for pair in bigrams:
        laplace_bigrams_prob[pair] = (bigrams[pair] + 1)/ float(unigrams[pair[0]]+V)
        laplace_bigrams_prob[pair] = round(laplace_bigrams_prob[pair], 15)
        printvalues(laplace_bigrams_prob[pair])
    printvalues(sort_dict(laplace_bigrams_prob))
    return laplace_bigrams_prob

def get_laplace_trigrams(unigrams,bigrams,trigrams,V):
    laplace_trigrams_prob = {}
    N = sum(unigrams.values())
    printvalues(N)
    for pair in trigrams:
        pairi=(pair[0],pair[1])
        laplace_trigrams_prob[pair] = (trigrams[pair] + 1)/ float(bigrams[pairi]+V)
        laplace_trigrams_prob[pair] = round(laplace_trigrams_prob[pair], 15)
        printvalues(laplace_trigrams_prob[pair])
    printvalues(sort_dict(laplace_trigrams_prob))
    return laplace_trigrams_prob

def get_wittenbell_unigrams(unigrams,unigrams_prob,V):
    wittenbell_unigrams_prob = {}
    N = sum(unigrams.values())
    T = len(unigrams.keys())
    printvalues(T)
    for word in unigrams:
        var= (N/float(N+T))
        wittenbell_unigrams_prob[word] = (var * unigrams_prob[word])
        wittenbell_unigrams_prob[word] = wittenbell_unigrams_prob[word] + (1-var)/V
        wittenbell_unigrams_prob[word] = round(wittenbell_unigrams_prob[word], 15)
        printvalues(wittenbell_unigrams_prob[word])
    printvalues(sort_dict(wittenbell_unigrams_prob))
    return wittenbell_unigrams_prob

def get_wittenbell_bigrams_variables(bigrams,word):
    printvalues(bigrams)
    distinct_1_in_1_bigrams=0
    total_1_in_1_bigrams=0
    printvalues(bigrams)
    for pair in bigrams:
        if word==pair[0]:
            printvalues(pair)
            distinct_1_in_1_bigrams+=1
            total_1_in_1_bigrams+=bigrams[pair]
            printvalues(bigrams[pair])
    return distinct_1_in_1_bigrams,total_1_in_1_bigrams

def get_wittenbell_bigrams(unigrams,bigrams,unigrams_prob,wittenbell_unigrams_prob):
    printvalues(unigrams)
    wittenbell_bigrams_prob = {}
    for pair in bigrams:
        printvalues(pair)
        distinct_1_in_1_bigrams,total_1_in_1_bigrams = get_wittenbell_bigrams_variables(bigrams,pair[0])
        x=distinct_1_in_1_bigrams/float(distinct_1_in_1_bigrams+total_1_in_1_bigrams)
        x=round(x, 15)
        wittenbell_bigrams_prob[pair] = (1-x) * bigrams_prob[pair]
        wittenbell_bigrams_prob[pair] += x * wittenbell_unigrams_prob[pair[0]]
    printvalues(sort_dict(wittenbell_bigrams_prob))
    return wittenbell_bigrams_prob

def get_wittenbell_trigrams_variables(trigrams,word):
    distinct_1_2_trigrams=0
    total_1_2_trigrams=0
    printvalues(trigrams)
    for pair in trigrams:
        if word[0]==pair[0] and word[1]==pair[1]:
            printvalues(pair)
            distinct_1_2_trigrams+=1
            total_1_2_trigrams+=trigrams[pair]
            printvalues(trigrams[pair])
    return distinct_1_2_trigrams,total_1_2_trigrams


def get_wittenbell_trigrams(unigrams,trigrams,trigrams_prob,wittenbell_bigrams_prob):
    printvalues(unigrams)
    wittenbell_trigrams_prob = {}
    for pair in trigrams:
        printvalues(pair)
        pairi=(pair[0],pair[1])
        distinct_1_2_trigrams,total_1_2_trigrams = get_wittenbell_trigrams_variables(trigrams,pair)
        printvalues(distinct_1_2_trigrams)
        x=distinct_1_2_trigrams/float(distinct_1_2_trigrams+total_1_2_trigrams)
        x=round(x, 15)
        wittenbell_trigrams_prob[pair] = (1-x) * trigrams_prob[pair] 
        wittenbell_trigrams_prob[pair] += x * wittenbell_bigrams_prob[pairi]
    printvalues(sort_dict(wittenbell_trigrams_prob))
    return wittenbell_trigrams_prob

def get_kn_unigrams(unigrams,V):
    kn_unigrams_prob={}
    d=0.75
    N=sum(unigrams.values())
    printvalues(N)
    for word in unigrams:
        kn_unigrams_prob[word] = (max(unigrams[word]-d, 0)/float(N)) 
        kn_unigrams_prob[word] += (d/float(V))
    printvalues(sort_dict(kn_unigrams_prob))
    return kn_unigrams_prob

def get_kn_bigrams_variables(bigrams,pair):
    bigrams_with_first_term=0
    bigrams_with_last_term=0
    for words in bigrams:
        printvalues(words)
        if words[0]==pair[0]:
            bigrams_with_first_term+=1
            printvalues(bigrams_with_first_term)
        if words[1]==pair[1]:
            bigrams_with_last_term+=1
    printvalues(bigrams_with_first_term)
    printvalues(bigrams_with_last_term)
    return bigrams_with_first_term,bigrams_with_last_term

def get_kn_bigrams(unigrams,bigrams):
    kn_bigrams_prob={}
    d=0.75
    printvalues(unigrams)
    total_bigrams=len(bigrams.keys())
    for pair in bigrams:
        printvalues(pair)
        bigrams_with_first_term,bigrams_with_last_term=get_kn_bigrams_variables(bigrams,pair)
        value1 = max(bigrams[pair]-d,0) / float(unigrams[pair[0]])
        value2 = bigrams_with_first_term/float(unigrams[pair[0]])
        value3 = bigrams_with_last_term/float(total_bigrams)
        kn_bigrams_prob[pair]= ( value1 ) + d * ( value2) * ( value3 )
        kn_bigrams_prob[pair] = round(kn_bigrams_prob[pair], 15)

    printvalues(sort_dict(kn_bigrams_prob))
    return kn_bigrams_prob

def get_kn_trigrams_variables(bigrams,trigrams,pair):
    trigrams_1_2_term=0
    trigrams_2_3_term=0
    trigrams_2_term=0
    printvalues(trigrams_2_term)
    bigrams_2_in_1_term=0
    bigrams_3_in_2_term=0
    printvalues(bigrams_3_in_2_term)
    for words in trigrams:
        if words[0]==pair[0] and words[1]==pair[1]:
            trigrams_1_2_term+=1
        if words[1]==pair[1] and words[2]==pair[2]:
            trigrams_2_3_term+=1
        if words[1]==pair[1]:
            trigrams_2_term+=1
        printvalues(words)
    for words in bigrams:
        if words[0]==pair[1]:
            bigrams_2_in_1_term+=1
        if words[1]==pair[2]:
            bigrams_3_in_2_term+=1
        printvalues(words)
    return trigrams_1_2_term,trigrams_2_3_term,trigrams_2_term,bigrams_2_in_1_term,bigrams_3_in_2_term


def get_kn_trigrams(unigrams,bigrams,trigrams):
    printvalues(unigrams)
    kn_trigrams_prob={}
    d=0.75
    total_bigrams=len(bigrams.keys())
    printvalues(total_bigrams)
    for pair in trigrams:
        pairi=(pair[0],pair[1])
        printvalues(pair)
        trigrams_1_2_term,trigrams_2_3_term,trigrams_2_term,bigrams_2_in_1_term,bigrams_3_in_2_term=get_kn_trigrams_variables(bigrams,trigrams,pair)
        value1 = max(trigrams[pair]-d,0) / float(bigrams[pairi])
        value2 = trigrams_1_2_term/float(bigrams[pairi])
        value3 = ( max(trigrams_2_3_term-d,0)/float(trigrams_2_term) )
        value4 = ( max(trigrams_2_3_term-d,0)/float(trigrams_2_term) )
        kn_trigrams_prob[pair]= ( value1 ) + d*(value2 )*( value3 + d * value4*(bigrams_3_in_2_term/float(total_bigrams)) )
        kn_trigrams_prob[pair] = round(kn_trigrams_prob[pair], 15)
    printvalues(sort_dict(kn_trigrams_prob))
    return kn_trigrams_prob


def plot(dict1,dict2,dict3,dict4,l1,l2,l3,l4,name):
    x1 = []
    y1 = []
    printvalues(len(dict1))
    for i in range(len(dict1)):
        y1.append((dict1[i][1]))
        printvalues(y1)
        x1.append((i))
        printvalues(x1)
        
    plt.plot(x1,y1,label=l1)

    x2 = []
    y2 = []
    printvalues(len(dict2))
    for i in range(len(dict2)):
        y2.append((dict2[i][1]))
        printvalues(y2)
        x2.append((i))
        printvalues(x2)
    plt.plot(x2,y2,label=l2)

    x3 = []
    y3 = []
    printvalues(len(dict3))
    for i in range(len(dict3)):
        y3.append((dict3[i][1]))
        printvalues(y3)
        x3.append((i))
        printvalues(x3)
    plt.plot(x3,y3,label=l3)

    x4 = []
    y4 = []
    printvalues(len(dict4))
    for i in range(len(dict4)):
        y4.append((dict4[i][1]))
        printvalues(y4)
        x4.append((i))
        printvalues(x4)
    plt.plot(x4,y4,label=l4)

    plt.title(name)

    plt.legend()
    plt.show()

def plot_log_log1(dicti):
    new_ticks = []
    x = []
    y = []
    printvalues(len(dicti))
    for i in range(1,len(dicti)):
        new_ticks.append(dicti[i][0])
        y.append(math.log(dicti[i][1]))
        x.append(math.log(i))
        
    printvalues(x,y)
    plt.plot(x,y)
    #plt.xticks(x, new_ticks)
    plt.show()



def plot_log_log(dict1,dict2,dict3,dict4,l1,l2,l3,l4,name):
    printvalues(len(dict1))
    x1 = []
    y1 = []

    for i in range(len(dict1)):
    	if  i>=1:
            y1.append(math.log(dict1[i][1]))
            printvalues(y1)
            x1.append(math.log(i))
            printvalues(x1)
    plt.plot(x1,y1,label=l1)

    x2 = []
    y2 = []
    printvalues(len(dict2))
    for i in range(len(dict2)):
    	if  i>=1:
            y2.append(math.log(dict2[i][1]))
            printvalues(y2)
            x2.append(math.log(i))
            printvalues(x2)
    plt.plot(x2,y2,label=l2)

    x3 = []
    y3 = []
    printvalues(len(dict3))
    for i in range(len(dict3)):
    	if  i>=1:
            y3.append(math.log(dict3[i][1]))
            printvalues(y3)
            x3.append(math.log(i))
            printvalues(x3)
    plt.plot(x3,y3,label=l3)

    x4 = []
    y4 = []
    printvalues(len(dict4))
    for i in range(len(dict4)):
    	if  i>=1:
            y4.append(math.log(dict4[i][1]))
            printvalues(y4)
            x4.append(math.log(i))
            printvalues(x4)
    plt.plot(x4,y4,label=l4)
    plt.title(name)
    plt.legend()
    plt.show()
def estimated_count_wb(unigrams, bigrams, trigrams, prob_wb_unigrams, prob_wb_bigrams, prob_wb_trigrams):
    #For unigrams
    printvalues(unigrams)
    count_wb_unigrams={}
    N = sum(unigrams.values())
    for i in unigrams:
        count_wb_unigrams[i] = prob_wb_unigrams[i]
        count_wb_unigrams[i] = count_wb_unigrams[i] * N

    printvalues(count_wb_unigrams)
    #For bigrams
    count_wb_bigrams={}
    for (i,j) in bigrams:
        count_wb_bigrams[(i,j)] = prob_wb_bigrams[(i,j)] 
        count_wb_bigrams[(i,j)] = count_wb_bigrams[(i,j)]* unigrams[i]
    printvalues(count_wb_bigrams)

    #For trigrams
    count_wb_trigrams={}
    for (i, j, k) in trigrams:
        count_wb_trigrams[(i,j,k)] = prob_wb_trigrams[(i,j,k)] 
        count_wb_trigrams[(i,j,k)] = count_wb_trigrams[(i,j,k)]* bigrams[(i,j)]
    printvalues(count_wb_trigrams)

    return count_wb_unigrams, count_wb_bigrams, count_wb_trigrams


def estimated_count_laplace(unigrams, bigrams, trigrams, prob_smoothed_unigram_2000, prob_smoothed_bigram_2000, prob_smoothed_trigram_2000):

    #For unigrams
    count_laplace_unigrams = {}
    printvalues(unigrams)
    N = sum(unigrams.values())
    for i in unigrams:
        count_laplace_unigrams[i] = prob_smoothed_unigram_2000[i]
        count_laplace_unigrams[i] = count_laplace_unigrams[i] * N
    printvalues(count_laplace_unigrams)
    #For bigrams
    count_laplace_bigrams={}
    for (i,j) in bigrams:
        count_laplace_bigrams[(i,j)] = prob_smoothed_bigram_2000[(i,j)] 
        count_laplace_bigrams[(i,j)] = count_laplace_bigrams[(i,j)]* unigrams[i]
    printvalues(count_laplace_bigrams)
    #For trigrams
    count_laplace_trigrams={}
    for (i,j,k) in trigrams:
        count_laplace_trigrams[(i,j,k)] = prob_smoothed_trigram_2000[(i,j,k)] 
        count_laplace_trigrams[(i,j,k)] = count_laplace_trigrams[(i,j,k)] * bigrams[(i,j)]
    printvalues(count_laplace_trigrams)

    return count_laplace_unigrams, count_laplace_bigrams, count_laplace_trigrams
def estimated_count_kn(unigrams, bigrams, trigrams, prob_smoothed_unigram_2000, prob_smoothed_bigram_2000, prob_smoothed_trigram_2000):

    #For unigrams
    count_laplace_unigrams = {}
    N = sum(unigrams.values())
    for i in unigrams:
        count_laplace_unigrams[i] = prob_smoothed_unigram_2000[i]
        count_laplace_unigrams[i] = count_laplace_unigrams[i] * N
    printvalues(count_laplace_unigrams)
    #For bigrams
    count_laplace_bigrams={}
    for (i,j) in bigrams:
        count_laplace_bigrams[(i,j)] = prob_smoothed_bigram_2000[(i,j)] 
        count_laplace_bigrams[(i,j)] = count_laplace_bigrams[(i,j)]* unigrams[i]
    printvalues(count_laplace_bigrams)
    #For trigrams
    count_laplace_trigrams={}
    for (i,j,k) in trigrams:
        count_laplace_trigrams[(i,j,k)] = prob_smoothed_trigram_2000[(i,j,k)] 
        count_laplace_trigrams[(i,j,k)] = count_laplace_trigrams[(i,j,k)] * bigrams[(i,j)]
    printvalues(count_laplace_trigrams)

    return count_laplace_unigrams, count_laplace_bigrams, count_laplace_trigrams

def get_kn_trigrams_laplace(unigrams,bigrams,trigrams,unigrams_lap,bigrams_lap,trigrams_lap):
    kn_trigrams_prob={}
    d=0.75
    total_bigrams=len(bigrams.keys())
    for pair in trigrams:
        pairi=(pair[0],pair[1])
        trigrams_1_2_term,trigrams_2_3_term,trigrams_2_term,bigrams_2_in_1_term,bigrams_3_in_2_term=get_kn_trigrams_variables(bigrams,trigrams,pair)
        value1 = ( max(trigrams_lap[pair]-d,0) / float(bigrams_lap[pairi]) )
        value2 = trigrams_1_2_term/float(bigrams[pairi])
        value3 =( max(trigrams_2_3_term-d,0)/float(trigrams_2_term) )
        value4 =bigrams_2_in_1_term/float(trigrams_2_term)
        value5 = bigrams_3_in_2_term/float(total_bigrams)
        kn_trigrams_prob[pair]= value1 + d*(value2 )*( value3 + d * (value4)*(value5) )
        kn_trigrams_prob[pair] = round(kn_trigrams_prob[pair], 15)
        printvalues(kn_trigrams_prob[pair])
    printvalues(sort_dict(kn_trigrams_prob))
    return kn_trigrams_prob

def get_kn_bigrams_laplace(unigrams,bigrams,unigrams_lap,bigrams_lap):
    kn_bigrams_prob={}
    d=0.75
    total_bigrams=len(bigrams.keys())
    for pair in bigrams:
        bigrams_with_first_term,bigrams_with_last_term=get_kn_bigrams_variables(bigrams,pair)
        value1 = max(bigrams_lap[pair]-d,0) / float(unigrams_lap[pair[0]])
        value2 = (bigrams_with_first_term/float(unigrams[pair[0]]) )
        value3 = ( bigrams_with_last_term/float(total_bigrams))
        kn_bigrams_prob[pair]= ( value1 ) + d * value2 * value3
        kn_bigrams_prob[pair] = round(kn_bigrams_prob[pair], 15)

    printvalues(sort_dict(kn_bigrams_prob))
    return kn_bigrams_prob

def get_kn_unigrams_laplace(unigrams,V,unigrams_lap):
    kn_unigrams_prob={}
    d=0.75
    N=sum(unigrams.values())
    printvalues(N)
    for word in unigrams:
        kn_unigrams_prob[word] = (max(unigrams_lap[word]-d, 0)/float(N)) 
        kn_unigrams_prob[word] += (d/float(V))
    printvalues(sort_dict(kn_unigrams_prob))
    return kn_unigrams_prob

def cond_bigrams(bigrams, key):
    
    joint = {k[1] : v for k, v in bigrams.items() if k[0] == key}
    sum_count = sum(joint.values())
    return {k : v / float(sum_count) for k, v in joint.items() }

def generate_bigrams(unigrams, bigrams, length=5, first_word = None):
    words = []
    if first_word == None:
        first_word = list(unigrams.keys())[random.randrange(0, len(unigrams))]
    words.append(first_word)
    for i in range(length - 1):
        prev = words[i]
        prev_dict = cond_bigrams(bigrams, prev)
        
        next_word = sorted(prev_dict.items(), key = lambda x : x[1], reverse = True)[0]
        words.append(next_word[0])
    return words
def cond_trigrams(trigrams, key):
    
    joint = {k[2] : v for k, v in trigrams.items() if (k[0] == key[0] and k[1] == key[1])}
    sum_count = sum(joint.values())
    return {k : v / float(sum_count) for k, v in joint.items() }

def generate_trigrams(unigrams, bigrams,trigrams, length=5, first_word = None):
    words = []
    if first_word == None:
        first_word = list(bigrams.keys())[random.randrange(0, len(bigrams))]
    words=(list(first_word))
    print words
    for i in range(length - 2):
        prev = words[i+1]
        prev2 = words[i]
        prev_dict = cond_trigrams(trigrams, [prev2,prev])
        
        next_word = sorted(prev_dict.items(), key = lambda x : x[1], reverse = True)[0]
        words.append(next_word[0])
    return words

# %%
corpus=tokenise()

unigrams,unigrams_prob=get_unigrams(corpus)

laplace_unigrams_prob = get_laplace_unigrams(unigrams,200)
printvalues(laplace_unigrams_prob)
laplace_unigrams_prob2 = get_laplace_unigrams(unigrams,2000)
printvalues(laplace_unigrams_prob2)
laplace_unigrams_prob3 = get_laplace_unigrams(unigrams,len(unigrams))
printvalues(laplace_unigrams_prob3)
#wittenbell_unigrams_prob = get_wittenbell_unigrams(unigrams,unigrams_prob,200)
#plot(sort_dict(wittenbell_unigrams_prob1),sort_dict(wittenbell_unigrams_prob2),sort_dict(wittenbell_unigrams_prob3),sort_dict(wittenbell_unigrams_prob4),"200","2000",len(unigrams),10*len(unigrams),"zipf_unigrams_diff_voc_witten_anime")
#plot_log_log(sort_dict(laplace_unigrams_prob1),sort_dict(laplace_unigrams_prob2),sort_dict(laplace_unigrams_prob3),sort_dict(laplace_unigrams_prob4),"200","2000",len(unigrams),10*len(unigrams),"log_unigrams_diff_voc_news")
kn_unigrams_prob = get_kn_unigrams(unigrams,200)


bigrams,bigrams_prob = get_bigrams(corpus,unigrams)
#printvalues(bigrams)
#printvalues(bigrams_prob)
#laplace_bigrams_prob1 = get_laplace_bigrams(unigrams,bigrams,200)
laplace_bigrams_prob2 = get_laplace_bigrams(unigrams,bigrams,2000)
#printvalues(laplace_bigrams_prob2)
laplace_bigrams_prob3 = get_laplace_bigrams(unigrams,bigrams,len(unigrams))
#printvalues(laplace_bigrams_prob3)
#laplace_bigrams_prob4 = get_laplace_bigrams(unigrams,bigrams,10*len(unigrams))
#wittenbell_bigrams_prob = get_wittenbell_bigrams(unigrams,bigrams,unigrams_prob,wittenbell_unigrams_prob)
#plot(sort_dict(laplace_bigrams_prob1),sort_dict(laplace_bigrams_prob2),sort_dict(laplace_bigrams_prob3),sort_dict(laplace_bigrams_prob4),"200","2000",len(unigrams),10*len(unigrams),"zipf_bigrams_diff_voc_anime")
#plot_log_log(sort_dict(laplace_bigrams_prob1),sort_dict(laplace_bigrams_prob2),sort_dict(laplace_bigrams_prob3),sort_dict(laplace_bigrams_prob4),"200","2000",len(unigrams),10*len(unigrams),"log_bigrams_diff_voc_anime")
kn_bigrams_prob =  get_kn_bigrams(unigrams,bigrams)
#printvalues(kn_bigrams_prob)


trigrams,trigrams_prob = get_trigrams(corpus,bigrams)
#printvalues(trigrams)
#laplace_trigrams_prob1 = get_laplace_trigrams(unigrams,bigrams,trigrams,200)
#laplace_trigrams_prob2 = get_laplace_trigrams(unigrams,bigrams,trigrams,2000)
#printvalues(laplace_trigrams_prob2)
#laplace_trigrams_prob3 = get_laplace_trigrams(unigrams,bigrams,trigrams,len(unigrams))
#laplace_trigrams_prob4 = get_laplace_trigrams(unigrams,bigrams,trigrams,10*len(unigrams))
#wittenbell_trigrams_prob = get_wittenbell_trigrams(unigrams,trigrams,trigrams_prob,wittenbell_bigrams_prob)
#plot(sort_dict(laplace_bigrams_prob3),sort_dict(wittenbell_bigrams_prob),sort_dict(kn_bigrams_prob),sort_dict(laplace_bigrams_prob4),"laplace","wittenbell","kneney","laplacefinal","zipf_trigrams_diff_voc_anime")
#plot_log_log(sort_dict(laplace_trigrams_prob1),sort_dict(laplace_trigrams_prob2),sort_dict(laplace_trigrams_prob3),sort_dict(laplace_trigrams_prob4),"200","2000",len(unigrams),10*len(unigrams),"log_trigrams_diff_voc_anime")
kn_trigrams_prob =  get_kn_trigrams(unigrams,bigrams,trigrams)
#printvalues(kn_trigrams_prob)

kn_unigrams,kn_bigrams,kn_trigrams=estimated_count_kn(unigrams, bigrams, trigrams, kn_unigrams_prob, kn_bigrams_prob, kn_trigrams_prob)

# %%
print generate_trigrams(kn_unigrams, kn_bigrams,kn_trigrams, length=10, first_word = None)
# Out:
# ['man', 'am']
# ['man', 'am', 'i', 'the', 'only', 'one', 'of', 'my', 'favorite', 'anime']

# %%
{k[2] : v for k, v in trigrams.items()}
# Out:
# {'breaker': 50,
#  'dynamic': 50,
#  'gugure': 50,
#  'araragi': 49,
#  'catch': 50,
#  'sleep': 50,
#  'hanging': 50,
#  'dere': 50,
#  'hate': 50,
#  'youtubecdjcuhuosci': 50,
#  'votes': 50,
#  'masaodidnothingwrong': 50,
#  'themes': 50,
#  'xf2ynhaeqvk': 100,
#  'bike': 50,
#  'voted': 50,
#  'under': 50,
#  'sorry': 50,
#  'ergo': 50,
#  'worth': 50,
#  'kyuubu': 50,
#  'merchant': 50,
#  'iimgurcomovtqunopng': 50,
#  'prodigy': 50,
#  'rise': 50,
#  'g6nxzbvt0oo': 49,
#  'hanekawa': 50,
#  'glasseskun': 50,
#  'every': 50,
#  'updates': 50,
#  'nervegear': 100,
#  'encounter': 50,
#  'school': 50,
#  'jotaro': 49,
#  'infernocopu': 49,
#  'solution': 50,
#  'correct': 50,
#  'samurai': 50,
#  '8dkljqhcsoe': 50,
#  'red': 50,
#  'soundtracks': 50,
#  'stereotypical': 50,
#  'heading': 50,
#  'clothes': 49,
#  'enjoy': 50,
#  'animemanga': 50,
#  'force': 50,
#  'tired': 50,
#  'hating': 50,
#  'comedysol': 50,
#  'japanese': 50,
#  'second': 100,
#  'fabulous': 50,
#  'smugpoint': 50,
#  '10s': 50,
#  'aw6wfuwuog': 50,
#  'enwikipediaorgwikibrightnessreef': 50,
#  'saijaku': 50,
#  'even': 50,
#  'faye': 50,
#  'mudamudamuda': 50,
#  'wreck': 49,
#  'saved': 50,
#  'avicii': 50,
#  'above': 50,
#  'new': 50,
#  'ever': 49,
#  'imganimebracketcom10wrjpg': 100,
#  'afterward': 50,
#  'hero': 50,
#  'rakugo': 50,
#  'never': 50,
#  'meh': 50,
#  'here': 50,
#  'studio': 49,
#  'achannel': 50,
#  'parenting': 50,
#  '100': 50,
#  'buddy': 50,
#  'dry': 50,
#  '333': 50,
#  'kids': 50,
#  'daughter': 50,
#  'rekt': 50,
#  'items': 50,
#  'k': 50,
#  'changed': 50,
#  'itunes': 49,
#  'military': 50,
#  'aka': 50,
#  'settled': 50,
#  'likeable': 50,
#  'golden': 50,
#  'fantastic': 49,
#  'yamada': 50,
#  'campaign': 50,
#  'iimgurcomgvzpanspng': 50,
#  'latifah': 50,
#  'replace': 50,
#  'psychological': 50,
#  'ippo': 50,
#  'myanimelistnetcharacter38941yukimurakusunoki': 50,
#  'counts': 50,
#  'total': 50,
#  'forums': 50,
#  'brb': 50,
#  'plot': 50,
#  'would': 50,
#  'browse': 50,
#  'kawaisou': 50,
#  'jumpscares': 50,
#  'insult': 50,
#  'yocq1g5uc5s': 49,
#  'maes': 50,
#  'mightiest': 50,
#  'call': 50,
#  'calm': 50,
#  'recommend': 50,
#  'strike': 50,
#  'preview': 50,
#  'type': 50,
#  'tell': 50,
#  'holy': 50,
#  'advance': 50,
#  'successful': 49,
#  'brings': 50,
#  'haha': 50,
#  'wars': 50,
#  'gaijinkun': 50,
#  '99': 50,
#  'phone': 50,
#  'hanamonogatari': 50,
#  'rip': 50,
#  'excellent': 50,
#  'blocking': 50,
#  'must': 50,
#  'me': 50,
#  '1990': 50,
#  'myanimelistnetanimelistedward979797': 50,
#  'join': 50,
#  'wore': 100,
#  'mc': 50,
#  'player': 50,
#  'iimgurcomwpovkuwjpg': 50,
#  'eclipse': 50,
#  'regrets': 50,
#  'duckhue': 50,
#  'umaruchan': 50,
#  'ms': 50,
#  'akio': 50,
#  'wot': 50,
#  'root': 50,
#  'example': 50,
#  'fortress': 50,
#  'orignal': 50,
#  'give': 50,
#  'bomberman': 50,
#  '7amp': 50,
#  'vash': 50,
#  'ready': 50,
#  'kiseijuu': 50,
#  'want': 49,
#  'keep': 50,
#  'uplift': 50,
#  'absolute': 50,
#  'motion': 50,
#  'end': 50,
#  '49ft439lsl4amp': 50,
#  'thing': 50,
#  'travel': 50,
#  'egyptian': 50,
#  'fullmetal': 50,
#  'osu': 50,
#  'how': 50,
#  'amazing': 50,
#  'hitman': 50,
#  'answer': 50,
#  'gate': 49,
#  'beach': 50,
#  'shichinin': 50,
#  'wallpapers': 50,
#  'gaming': 50,
#  'stzk3ksxg18': 50,
#  'faq': 50,
#  'beauty': 50,
#  'funny': 50,
#  'believers': 50,
#  'ssj3': 50,
#  'wwwanimenewsnetworkcomnews20160209spiceandwolflightnovelseriesgetssequelon10thanniversary98489': 50,
#  'loyalty': 50,
#  'iimgurcomqlaggq2gifv': 50,
#  'streamablecomu1qv': 50,
#  'wrong': 50,
#  'president': 50,
#  'arch': 50,
#  'fanservice': 50,
#  'effective': 49,
#  'wins': 50,
#  'appreciate': 50,
#  'childhood': 50,
#  'owari': 100,
#  'green': 50,
#  'ultimate': 50,
#  'keeps': 50,
#  'iimgurcomumvndzngifv': 50,
#  'worst': 50,
#  'detective': 99,
#  'danna': 50,
#  'order': 50,
#  'greed': 100,
#  'jack': 50,
#  'emotion': 49,
#  'jelous': 50,
#  'feedback': 50,
#  'jordy': 50,
#  'over': 50,
#  'bleach': 50,
#  'imganimebracketcomzstjpg': 50,
#  'daisuke': 50,
#  'nsfw': 50,
#  'myanimelistnetanime12531sakamichinoapollon': 49,
#  'japan': 50,
#  'rebellion': 50,
#  'adolescence': 49,
#  'newthis': 50,
#  'fit': 50,
#  'musiclike': 50,
#  'adaption': 50,
#  'hashi': 50,
#  'writing': 50,
#  'better': 50,
#  'trabantamp': 50,
#  'shinsengumi': 50,
#  'carve': 50,
#  'hidden': 50,
#  'easier': 50,
#  'then': 50,
#  'them': 50,
#  'iimgurcomwocyegzpng': 50,
#  'kurogane': 50,
#  'break': 50,
#  'they': 50,
#  'yourself': 50,
#  'sayan': 50,
#  'iimgurcomxdxqh48gif': 50,
#  'zetsubou': 50,
#  'backgrounds': 50,
#  'l': 49,
#  'goddamn': 50,
#  'sasuke': 50,
#  'each': 50,
#  'addicted': 50,
#  'haruhi': 50,
#  'went': 50,
#  'side': 50,
#  'mean': 50,
#  'zabi': 50,
#  '49mediatumblrcomdb96f7a6ba9fe32cabdf1fe5ba73ad97tumblrn3513hdqgg1s079ezo1400gif': 50,
#  'battoru': 50,
#  'series': 50,
#  'stronger': 50,
#  'joined': 50,
#  'taught': 50,
#  'forgot': 50,
#  'ring': 50,
#  'gon': 50,
#  'driving': 50,
#  'god': 50,
#  'psychic': 50,
#  'tomorrow': 50,
#  're': 50,
#  '20stylekawaii': 100,
#  'reader': 50,
#  'got': 50,
#  'ro': 50,
#  'hana': 50,
#  'flashy': 50,
#  'inou': 50,
#  'perception': 50,
#  'turning': 50,
#  'cutest': 50,
#  'written': 50,
#  'gotoku': 50,
#  'eternal': 50,
#  'given': 50,
#  'free': 50,
#  'mourning': 50,
#  'gahhh': 50,
#  'masterpiece': 50,
#  'struggle': 50,
#  'voteblocked': 50,
#  'bakana': 50,
#  'wanted': 50,
#  'myanimelistnetanimelistmillapede': 50,
#  'ange': 50,
#  'myanimelistnetanimelistamb1d3x': 50,
#  'slice': 50,
#  'created': 50,
#  'youtubewnkipydwzy': 50,
#  'starts': 50,
#  'days': 50,
#  'descriptive': 50,
#  'redline': 50,
#  'heck': 50,
#  'signature': 49,
#  'reupload': 50,
#  'koneko': 50,
#  'onto': 50,
#  'tomodachi': 50,
#  'myanimelistnetanime6547angelbeats': 50,
#  'already': 50,
#  'magica': 50,
#  'nhk': 150,
#  'hearing': 50,
#  'lovable': 50,
#  'fantasy': 50,
#  'philosophical': 50,
#  'brynhildr': 50,
#  'another': 50,
#  'spoilerish': 50,
#  'instagram': 50,
#  'toy': 50,
#  'service': 50,
#  'top': 50,
#  'girls': 50,
#  'fml': 50,
#  'elevator': 50,
#  'acchi': 50,
#  'needed': 50,
#  'ton': 50,
#  'listed': 50,
#  'satoru': 50,
#  'john': 50,
#  'dogs': 50,
#  'listen': 49,
#  'centered': 50,
#  'serve': 50,
#  'took': 48,
#  'direct': 50,
#  'digi': 49,
#  'clannad': 50,
#  'practiced': 50,
#  'mizutani': 50,
#  '1k': 50,
#  'sakuga': 49,
#  'picky': 50,
#  'spoiler': 50,
#  'trek': 50,
#  'episodic': 48,
#  'showed': 50,
#  'ryouran': 50,
#  'heshe': 49,
#  'likely': 50,
#  'tackles': 50,
#  'project': 50,
#  'painful': 50,
#  'iron': 50,
#  'recency': 50,
#  'gives': 50,
#  'ran': 50,
#  '10th': 50,
#  'mind': 50,
#  'mine': 50,
#  'iimgurcomixzjdampng': 50,
#  'talking': 50,
#  'seed': 50,
#  'corny': 50,
#  'seen': 50,
#  'seem': 50,
#  'hentai': 50,
#  'ray': 50,
#  'kayo': 50,
#  'oregairu': 50,
#  'emptiness': 50,
#  'genuine': 49,
#  'thoroughly': 50,
#  'latter': 49,
#  'sakamoto': 49,
#  'eagerly': 50,
#  'vegeeeeetaaaa': 50,
#  'recommended': 50,
#  'defiantly': 50,
#  'doors': 50,
#  'hum': 50,
#  'nonmusical': 49,
#  'kakyoin': 49,
#  'shipments': 50,
#  'solbits': 50,
#  'incapable': 50,
#  'though': 50,
#  'bruce': 50,
#  'iimgurcomqi1n3m7gif': 50,
#  'gyoyoh68xes': 50,
#  'mouth': 50,
#  'resonated': 50,
#  'thriller': 50,
#  'majo': 50,
#  'episode': 50,
#  'speeddraw': 50,
#  'weebing': 50,
#  'usual': 49,
#  'trapped': 50,
#  'definitely': 50,
#  'xo': 100,
#  'myanimelistnetanime14227tonarinokaibutsukun': 50,
#  'akb0048': 50,
#  'entertaining': 50,
#  'voting': 49,
#  'came': 50,
#  'marvel': 50,
#  'saying': 50,
#  'desktops': 50,
#  'scryed': 50,
#  'gosick': 50,
#  'saga': 48,
#  'random': 49,
#  'ending': 100,
#  'colors': 50,
#  'abstain': 50,
#  'hisoka': 50,
#  'seasonally': 50,
#  '200': 50,
#  'lessons': 50,
#  'busy': 50,
#  'layout': 50,
#  'op2': 50,
#  '1c1prfeencz551cz551amp': 50,
#  'cousins': 50,
#  'explain': 50,
#  'appreciated': 50,
#  'theme': 49,
#  'imganimebracketcomzvvjpg': 100,
#  'gangsta': 50,
#  'araki': 49,
#  'sieg': 49,
#  'jetters': 50,
#  'personality': 50,
#  'ranma': 50,
#  'do': 50,
#  'mouths': 49,
#  'watch': 50,
#  'da': 50,
#  'despite': 50,
#  'iimgurcom7fg9on1gif': 50,
#  'shirayuki': 50,
#  'dr': 50,
#  'learned': 49,
#  'thumbnails': 50,
#  'cagalli': 50,
#  'imganimebracketcomzrkjpg': 50,
#  'countries': 50,
#  'jikan': 50,
#  '49mediatumblrcomf9d2f812a20f7847e1d7611c753cbe2etumblrmu4eked3kt1s5f9ado1500gif': 50,
#  'method': 50,
#  'bad': 50,
#  'gears': 50,
#  'ghoul': 100,
#  'ears': 50,
#  'dldropboxusercontentcomu41845835mal': 100,
#  'blew': 50,
#  'mandatory': 50,
#  'imganimebracketcom10ijjpg': 100,
#  'prett': 50,
#  '10m7s': 50,
#  'decided': 49,
#  'bleh': 50,
#  'best': 100,
#  'enwikipediaorgwikistartiderising': 50,
#  'said': 50,
#  'saic': 50,
#  'sentient': 50,
#  'lots': 50,
#  'konoe': 50,
#  'g8nsved12ly': 50,
#  'iirc': 50,
#  'amagami': 50,
#  'seitokia': 50,
#  'iimgurcomfhtavk8gif': 50,
#  'mug': 50,
#  'r': 100,
#  'discovers': 50,
#  'hopefully': 50,
#  'ira': 50,
#  'wwwgoogleczsearch': 50,
#  'repost': 50,
#  'encounters': 49,
#  'smediacacheak0pinimgcomoriginals874f28874f28279f34de3bc97d5cd4903d1e6fgif': 50,
#  'gravestone': 50,
#  'obito': 50,
#  'we': 50,
#  'men': 50,
#  'pariston': 50,
#  'wears': 49,
#  'wa': 50,
#  'womanizer': 50,
#  'wo': 50,
#  'weak': 50,
#  'however': 50,
#  'boss': 50,
#  'toothbrush': 50,
#  'myanimelistnet': 50,
#  'extent': 50,
#  'iimgurcomgwhu236jpg': 50,
#  'suggested': 50,
#  'accident': 50,
#  'triggers': 50,
#  '25mediatumblrcoma7ec0ccb2bb01399dd247bbeca29e3e4tumblrmo549t5ase1s1lza6o1500gif': 50,
#  'ill': 50,
#  'yukimura': 50,
#  'tracks': 50,
#  'against': 50,
#  'iimgurcomu3w7xdwpng': 50,
#  'players': 50,
#  'und': 50,
#  'myanimelistnetanimelistnobutora312': 50,
#  'installments': 50,
#  'threads': 50,
#  'kuuderes': 50,
#  'adapted': 50,
#  'asked': 50,
#  'con': 50,
#  'wwwredditcomrjapancomments464491themythologybehindringulookingformovies': 50,
#  'nikki': 50,
#  'tone': 50,
#  'myanimelistnetanimelistmercylas': 50,
#  'appeared': 50,
#  'had': 50,
#  'myanimelistnetanimelistdarkhunter94': 50,
#  'smithereens': 50,
#  'karen': 49,
#  'yelling': 50,
#  'myanimelistnetcharacter82525shiro': 50,
#  'trust': 49,
#  'hitler': 50,
#  'san': 50,
#  'proceeded': 50,
#  'puts': 49,
#  'binge': 50,
#  'three': 50,
#  'been': 100,
#  'mediagiphycommediavg8q3b2he72qogiphygif': 50,
#  'confident': 50,
#  'much': 50,
#  'interest': 50,
#  '37mediatumblrcom6e8b0a4fe2ed73f321636c244764db2ctumblrnapwf1xq7o1smxh7ao2250gif': 50,
#  'expected': 50,
#  'japani': 50,
#  'threw': 49,
#  'website': 50,
#  'life': 99,
#  'deeper': 50,
#  'mushroom': 50,
#  'drugs': 48,
#  'imgurcomgallerycwqr3qv': 50,
#  'prison': 50,
#  'personally': 50,
#  'shimotsuki': 50,
#  'mcs': 50,
#  'censored': 49,
#  'ant': 50,
#  'has': 50,
#  'adaptations': 49,
#  'tastes': 50,
#  'air': 50,
#  'suppose': 50,
#  'hates': 50,
#  'alchemist': 50,
#  'stopping': 49,
#  'haganaiboku': 50,
#  'voice': 50,
#  'chilling': 50,
#  'mistake': 50,
#  'seven': 50,
#  'existence': 50,
#  'played': 50,
#  'is': 50,
#  'iimgurcomrs9w2ujjpg': 50,
#  'it': 50,
#  'myanimelistnetanime16hachimitsutoclover': 49,
#  'ii': 49,
#  'skipping': 50,
#  'straits': 50,
#  'im': 50,
#  'imganimebracketcomzqpjpg': 100,
#  'in': 50,
#  'exile': 50,
#  'gervais': 50,
#  'id': 49,
#  'disappear': 50,
#  'if': 50,
#  'friendshipplaying': 49,
#  'alien': 50,
#  'things': 100,
#  'make': 50,
#  'format': 50,
#  'kirei': 50,
#  'shingeki': 50,
#  'sakura': 50,
#  '2bpblogspotcomicdg0dtryt8vjexc38rliiaaaaaaaadckzh4cgi1ykt4s1600welcometomcrpng': 50,
#  'yuna': 50,
#  'showing': 50,
#  'zeon': 49,
#  'meets': 50,
#  'dmtdllzhduw': 49,
#  'shinda': 100,
#  'rain': 50,
#  'characters': 50,
#  'moka': 49,
#  'adopting': 50,
#  'thoughts': 50,
#  'kid': 50,
#  'mentioning': 50,
#  'tsukihi': 50,
#  'iimgurcomvbfhfhtgif': 50,
#  'kept': 50,
#  'scenario': 50,
#  'cdnmyanimelistnetimagescharacters11242945jpg': 49,
#  'changes': 50,
#  'kamina': 50,
#  'eps': 50,
#  'tho': 50,
#  'academia': 50,
#  'aisu': 50,
#  'mother': 50,
#  'hearts': 50,
#  'the': 50,
#  '45mediatumblrcom298585422f9d7304e65f7a1d507e1d10tumblrnbowokk6aj1slfw0xo1500gif': 50,
#  'yamato': 50,
#  'slightly': 50,
#  'left': 50,
#  'etiquette': 49,
#  'just': 50,
#  'gawking': 50,
#  'imganimebracketcomzw3jpg': 100,
#  'laptop': 50,
#  'yey': 50,
#  'fighters': 100,
#  'meta': 50,
#  'thanks': 50,
#  'human': 50,
#  'hajimemashita': 50,
#  'yes': 50,
#  'bahamut': 50,
#  'yet': 50,
#  'previous': 50,
#  'hai': 50,
#  'jigen': 50,
#  'danmachi': 50,
#  'dialogues': 50,
#  'thankfully': 50,
#  'candidate': 50,
#  'furry': 48,
#  'character': 50,
#  'potential': 50,
#  'board': 50,
#  'easy': 50,
#  'sukunai': 50,
#  'fares': 50,
#  'openings': 50,
#  'hat': 50,
#  'laying': 50,
#  'gave': 50,
#  'unfitting': 50,
#  'imganimebracketcom10f8jpg': 100,
#  'possible': 49,
#  'possibly': 50,
#  'orphan': 50,
#  'suffering': 50,
#  'background': 50,
#  'opm': 50,
#  'shadow': 50,
#  'poses': 50,
#  'souma': 100,
#  'apart': 50,
#  'bro': 50,
#  'nevermind': 50,
#  'pedoro': 50,
#  '50': 49,
#  'xbox': 50,
#  'specific': 50,
#  'fangirls': 49,
#  'night': 50,
#  'myanimelistnetanimelistbakaneko': 50,
#  'right': 50,
#  'old': 49,
#  'deal': 50,
#  'people': 50,
#  'crown': 49,
#  'dead': 50,
#  'webm': 50,
#  'nwru5o07ji': 49,
#  'born': 50,
#  'poolside': 50,
#  'advertise': 49,
#  'guess': 50,
#  'tripped': 50,
#  'nobleman': 50,
#  'chorus': 50,
#  'humor': 48,
#  'clash': 50,
#  'for': 50,
#  'eater': 50,
#  'purple': 49,
#  'everything': 50,
#  'asking': 50,
#  'hurt': 50,
#  'adorable': 49,
#  'christmas': 50,
#  'theological': 50,
#  'shakes': 50,
#  'pls': 50,
#  'burn': 50,
#  'plz': 50,
#  'myanimelistnetanimelistwingsoflight': 50,
#  'shifting': 50,
#  'post': 49,
#  'wryyy': 50,
#  'super': 50,
#  'takes': 49,
#  'kakaru': 50,
#  'eat': 50,
#  'cowboy': 50,
#  'attacks': 50,
#  'months': 50,
#  'o': 50,
#  'catchy': 50,
#  'cliche': 50,
#  'plus': 50,
#  'anime': 50,
#  'horizon': 49,
#  'maoyuu': 50,
#  'commit': 50,
#  'drunks': 50,
#  'automatically': 50,
#  'alucard': 50,
#  'subs': 50,
#  'iimgurcomdnzh9fmjpg': 50,
#  'oneshot': 50,
#  'ahn': 50,
#  'sol': 48,
#  'smediacacheak0pinimgcomoriginalsaa44caaa44ca7651149ae59d742209cb259862gif': 50,
#  'down': 50,
#  'sou': 50,
#  'capped': 50,
#  'carving': 50,
#  'lewd': 50,
#  'rounds': 50,
#  'often': 50,
#  'animeadaptation': 50,
#  'wan': 50,
#  'iimgurcomq9xjv4pjpg': 50,
#  'suffice': 49,
#  'flying': 50,
#  'transform': 50,
#  'murrue': 50,
#  'raped': 50,
#  'gig': 50,
#  'gif': 50,
#  'fought': 50,
#  'editor': 49,
#  'way': 49,
#  'zoldycks': 50,
#  'music': 49,
#  'factions': 50,
#  'was': 49,
#  'war': 50,
#  'happy': 50,
#  'head': 50,
#  'proudly': 49,
#  'teehee': 50,
#  '6': 50,
#  'landing': 49,
#  'fansubbed': 50,
#  'kamisama': 50,
#  'failure': 49,
#  'gifs': 50,
#  'hear': 50,
#  'youtubefww6cqybdcw': 50,
#  'iimgurcomrzlkbx4jpg': 50,
#  'duel': 50,
#  'masuzu': 50,
#  'sugiru': 50,
#  'renge': 50,
#  'versions': 50,
#  'myanimelistnetanime11933odanobunanoyabou': 50,
#  'inside': 50,
#  'profissional': 50,
#  'until': 50,
#  'myanimelistnetcharacter51343konekotoujou': 50,
#  'myanimelistnetanime7465evenojikanmovie': 50,
#  'more': 50,
#  'trigonometry': 50,
#  'trio': 50,
#  'shooter': 50,
#  'sticks': 48,
#  'classic': 50,
#  'kuudere': 50,
#  'tournament': 50,
#  'nnb': 50,
#  'covers': 50,
#  'thanksgiving': 50,
#  'exist': 50,
#  'marksman': 50,
#  'mediocre': 48,
#  'annoying': 49,
#  'mold': 50,
#  'check': 50,
#  'shit': 50,
#  'physical': 50,
#  'ni': 50,
#  'saber': 50,
#  'no': 50,
#  'na': 50,
#  'excel': 48,
#  'actor': 49,
#  'reality': 50,
#  '61mediatumblrcom085c1da04a5c644a941d57d6823ab22atumblrmyo3ov1i7i1qbesk0o1500png': 50,
#  'setting': 49,
#  'ambitious': 50,
#  'tie': 50,
#  'enemies': 50,
#  'nt': 99,
#  'realize': 50,
#  'noriaki': 49,
#  'picture': 50,
#  'incestuous': 50,
#  'boku': 50,
#  'models': 50,
#  'why': 50,
#  'welcome': 50,
#  'update': 50,
#  'brief': 50,
#  'journey': 49,
#  'invested': 48,
#  'magnificence': 50,
#  'aware': 50,
#  'weekend': 49,
#  'holo': 50,
#  'progresses': 50,
#  'back': 50,
#  'longer': 50,
#  'mediagiphycommedianjp4i0kv2u3tigiphygif': 50,
#  'normally': 50,
#  'rs938pbsrccomalbumsad222kimberlyfarron23gifsangelbeatsescapegif': 50,
#  'imganimebracketcomzuhjpg': 50,
#  'together': 50,
#  'myanimelistnetanimelistlordofsushi': 50,
#  'warm': 49,
#  'lagann': 50,
#  'reception': 50,
#  'time': 50,
#  'serious': 50,
#  'surprised': 50,
#  'wwwpixivnetmemberillustphp': 50,
#  'stick': 50,
#  'slope': 49,
#  'atleat': 49,
#  'evilrickdeviantartcomartdeadpoolandnanohaissue2210631066': 50,
#  'themed': 50,
#  'dance': 50,
#  'activated': 50,
#  'ost': 50,
#  'laura': 50,
#  'theaters': 50,
#  'jarring': 50,
#  'battle': 50,
#  'manlytears': 50,
#  'djooljxfvo': 50,
#  'jiji': 50,
#  'grape': 50,
#  'ouran': 50,
#  'fsn': 49,
#  'decim': 50,
#  'father': 50,
#  'suzumiya': 50,
#  'environment': 50,
#  '0': 48,
#  'finally': 50,
#  'cliched': 50,
#  'terror': 50,
#  'elkfdg6qyxw': 50,
#  'sing': 50,
#  'screen': 50,
#  'machi': 50,
#  'results': 50,
#  'masculinity': 31,
#  'jerk': 50,
#  'tanks': 50,
#  'ma': 50,
#  'airing': 50,
#  'blast': 50,
#  'hachi': 50,
#  'minute': 50,
#  'cool': 50,
#  'dio': 49,
#  'eden': 50,
#  'level': 50,
#  'did': 50,
#  'die': 50,
#  'suprised': 50,
#  'gum': 49,
#  'specials': 50,
#  'p': 50,
#  'kazuma': 50,
#  'team': 49,
#  'freecss': 50,
#  'guy': 50,
#  'teenager': 50,
#  'round': 50,
#  'application': 50,
#  'work': 50,
#  'porn': 49,
#  'bravo': 50,
#  'staticzerochannetkisaragichihayafull1495321jpg': 50,
#  'prediction': 50,
#  'cyber': 50,
#  'blue': 50,
#  'cost': 50,
#  'oldcurrent': 49,
#  'ww1': 50,
#  'iimgurcomx1ur8yapng': 50,
#  'twintails': 50,
#  'baka': 50,
#  'stands': 50,
#  'movies': 50,
#  'filler': 50,
#  '207124': 49,
#  'minamike': 50,
#  'realizing': 49,
#  'shares': 50,
#  'uniform': 49,
#  'current': 50,
#  '300': 50,
#  'goes': 50,
#  'imganimebracketcomzpxjpg': 50,
#  'hajime': 50,
#  'nagi': 50,
#  '1010': 50,
#  'myanimelistnetanimelistbuzzardslicer': 50,
#  'nakamura': 50,
#  'outweebed': 50,
#  '29defaultdesigndefaultdesignhtml': 100,
#  'dweller': 50,
#  'iimgurcomflbquyggif': 50,
#  'v': 2388,
#  'gintamathispleasesme': 50,
#  'water': 49,
#  'downloaded': 49,
#  'femininity': 31,
#  'myanimelistnetanime790ergoproxy': 50,
#  'witch': 50,
#  'c200': 50,
#  'wildkurisufileswordpresscom201503vashshootinggif': 50,
#  'based': 49,
#  'along': 50,
#  'change': 50,
#  'wait': 50,
#  'box': 50,
#  'boy': 50,
#  'jwhjqdspw5g': 50,
#  'standout': 50,
#  'redemption': 50,
#  'brilliant': 50,
#  'my': 50,
#  'guilty': 49,
#  'boi': 50,
#  'usually': 50,
#  'weird': 50,
#  'evangelion': 50,
#  'myanimelistnetanimelistgrakara': 50,
#  'love': 50,
#  'killlua': 50,
#  'extra': 50,
#  'inducing': 50,
#  'krillin': 50,
#  'prefer': 50,
#  'niichan': 50,
#  'moar': 50,
#  'fake': 50,
#  'myanimelistnetanime2593karanokyoukai1fukanfuukei': 50,
#  'fudge': 50,
#  'kyoni': 50,
#  'exuberating': 50,
#  'everybody': 50,
#  'working': 50,
#  'meshi': 50,
#  'dude': 50,
#  'myanimelistnetanimelistdarthnick426': 50,
#  'intense': 49,
#  'live': 50,
#  'kiryuu': 50,
#  'https': 50,
#  'memory': 50,
#  'msg': 50,
#  '55227875': 50,
#  'angels': 50,
#  'today': 50,
#  'loving': 50,
#  'wwwanimecharactersdatabasecomuploadschars5092242321200jpg': 50,
#  'sharing': 100,
#  ...}

# %%
print generate_trigrams(kn_unigrams, kn_bigrams,kn_trigrams, length=5, first_word = None)
# Out:
# ['identity', 'it']
# ['identity', 'it', 'is', 'nt', 'this']

# %%
corpus_anime = tokenise("anime.txt")
corpus_movies = tokenise("movies.txt")
corpus_news = tokenise("news.txt")

# %%
unigrams_anime,unigrams_prob_anime = get_unigrams(corpus_anime)
bigrams_anime,bigrams_prob_anime = get_bigrams(corpus_anime,unigrams_anime)
trigrams_anime,trigrams_prob_anime = get_trigrams(corpus_anime,bigrams_anime)

unigrams_movies,unigrams_prob_movies = get_unigrams(corpus_movies)
bigrams_movies,bigrams_prob_movies = get_bigrams(corpus_movies,unigrams_movies)
trigrams_movies,trigrams_prob_movies = get_trigrams(corpus_movies,bigrams_movies)

unigrams_news,unigrams_prob_news = get_unigrams(corpus_news)
bigrams_news,bigrams_prob_news = get_bigrams(corpus_news,unigrams_news)
trigrams_news,trigrams_prob_news = get_trigrams(corpus_news,bigrams_news)

plot(sort_dict(unigrams_anime),sort_dict(unigrams_movies),sort_dict(unigrams_news),{},"anime_uni","movies_uni","news_uni","none","Unigrams Zipfs")

# %%
plot(sort_dict(bigrams_anime),sort_dict(bigrams_movies),sort_dict(bigrams_news),{},"anime_bi","movies_bi","news_bi","none","Bigrams Zipfs")

# %%
plot(sort_dict(trigrams_anime),sort_dict(trigrams_movies),sort_dict(trigrams_news),{},"anime_tri","movies_tri","news_tri","none","Trigrams Zipfs")
